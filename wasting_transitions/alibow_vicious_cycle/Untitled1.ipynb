# %%
import pandas as pd, numpy as np
from vivarium import Artifact
from get_draws.api import get_draws

# %%
age_ids = [2,3,388,389, 238, 34]

# %%
incidence_2020 = get_draws(gbd_round_id=7,
                          year_id=2020,
                           location_id=179,
                          age_group_id=age_ids,
                          gbd_id_type='cause_id',
                          gbd_id=302,
                          measure_id=6,
                          source='como',
                          decomp_step='iterative')
incidence_2020
# Out:
#     age_group_id  cause_id    draw_0    draw_1   draw_10  draw_100  draw_101  \
# 0              2       302  3.169600  3.502426  3.701505  3.558419  3.710797
# 1              3       302  3.067380  3.388745  3.570799  3.423549  3.569380
# 2             34       302  1.120415  1.339049  1.131388  1.123293  1.120080
# 3            238       302  1.924657  2.188107  1.997446  1.813127  1.811473
# 4            388       302  2.837726  3.142923  3.235716  3.052673  3.166558
# 5            389       302  2.426878  2.704062  2.624624  2.371982  2.424614
# 6              2       302  3.357927  3.366346  3.767335  3.401799  3.780372
# 7              3       302  3.241641  3.251788  3.610566  3.277092  3.631071
# 8             34       302  1.173984  1.319575  1.199582  1.183228  1.055403
# 9            238       302  2.114548  2.071617  1.936742  1.894361  1.749740
# 10           388       302  2.989875  2.970199  3.166430  2.930041  3.197415
# ...

# %%
prevalence_2020 = get_draws(gbd_round_id=7,
                          year_id=2020,
                            location_id=179,
                          age_group_id=age_ids,
                          gbd_id_type='cause_id',
                          gbd_id=302,
                          measure_id=5,
                          source='como',
                          decomp_step='iterative')
prevalence_2020
# Out:
#     age_group_id  cause_id    draw_0    draw_1   draw_10  draw_100  draw_101  \
# 0              2       302  0.017933  0.019333  0.019986  0.019554  0.019991
# 1              3       302  0.038569  0.040448  0.040937  0.040593  0.040695
# 2             34       302  0.018333  0.019398  0.018005  0.019137  0.019184
# 3            238       302  0.028247  0.031483  0.034565  0.027824  0.029432
# 4            388       302  0.041087  0.043413  0.044618  0.042714  0.042973
# 5            389       302  0.035642  0.039338  0.042893  0.036493  0.037573
# 6              2       302  0.019231  0.018661  0.020834  0.018710  0.020376
# 7              3       302  0.041797  0.039213  0.043653  0.038921  0.041439
# 8             34       302  0.020390  0.020819  0.020481  0.019695  0.018637
# 9            238       302  0.030741  0.031030  0.033739  0.027955  0.028090
# 10           388       302  0.044436  0.041928  0.047100  0.041036  0.043363
# ...

# %%
incidence_2020.set_index([c for c in incidence_2020 if 'draw' not in c]) * (4.3/365)
# Out:
#                                                                          draw_0  \
# age_group_id cause_id location_id measure_id sex_id year_id metric_id
# 2            302      179         6          1      2020    3          0.037340
# 3            302      179         6          1      2020    3          0.036136
# 34           302      179         6          1      2020    3          0.013199
# 238          302      179         6          1      2020    3          0.022674
# 388          302      179         6          1      2020    3          0.033431
# 389          302      179         6          1      2020    3          0.028591
# 2            302      179         6          2      2020    3          0.039559
# 3            302      179         6          2      2020    3          0.038189
# 34           302      179         6          2      2020    3          0.013830
# 238          302      179         6          2      2020    3          0.024911
# ...

# %%
prevalence_2020.set_index([c for c in prevalence_2020 if 'draw' not in c])
# Out:
#                                                                          draw_0  \
# age_group_id cause_id location_id measure_id sex_id year_id metric_id
# 2            302      179         5          1      2020    3          0.017933
# 3            302      179         5          1      2020    3          0.038569
# 34           302      179         5          1      2020    3          0.018333
# 238          302      179         5          1      2020    3          0.028247
# 388          302      179         5          1      2020    3          0.041087
# 389          302      179         5          1      2020    3          0.035642
# 2            302      179         5          2      2020    3          0.019231
# 3            302      179         5          2      2020    3          0.041797
# 34           302      179         5          2      2020    3          0.020390
# 238          302      179         5          2      2020    3          0.030741
# ...
