# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
pd.set_option('display.max_rows', 8)

from scipy import stats
import collections

import warnings
# warnings.filterwarnings('ignore')
from matplotlib.backends.backend_pdf import PdfPages

from pathlib import Path

import db_queries as db
import vivarium_helpers.id_helper as idh
import gbd_mapping
from vivarium import Artifact

# Add the repo directory vivarium_research_ciff_sam/ to sys.path
import os, sys
repo_path = os.path.abspath('..')
sys.path.append(repo_path)
print("pwd:")
# !pwd
print(f"{repo_path=}")

# Assumes vivarium_research_ciff_sam/ is in sys.path
# import model_validation.vivarium_transformed_output as vto
# import model_validation.vivarium_raw_output as vro
import model_validation.vivarium_output_processing as vp
import model_validation.ciff_sam_results as csr
import model_validation.ciff_sam_plots as csp

# %load_ext autoreload
# %autoreload 2

# !whoami
# !date
# Out:
# pwd:
# /ihme/homes/ndbs/vivarium_research_ciff_sam/results
# repo_path='/ihme/homes/ndbs/vivarium_research_ciff_sam'
# ndbs
# Mon Oct 25 16:10:23 PDT 2021

# %% [markdown]
# # Goal: Calculate reduction in prevalence of MAM, SAM, and MAM+SAM in the two intervention scenarios
#
# # 0. Load data

# %%
results = csr.VivariumResults.cleaned_from_model_spec(4.1)
results.table_names()
# Out:
# ['wasting_transition_count',
#  'wasting_state_person_time',
#  'deaths',
#  'stunting_state_person_time',
#  'population',
#  'ylls',
#  'ylds',
#  'person_time',
#  'cause_state_person_time',
#  'cause_transition_count']

# %% [markdown]
# # 1. Compute wasting prevalence among all ages and all years post-intervention

# %%
results.wasting_state_person_time
# Out:
#           sex  year                 wasting_state            measure  \
# 0      female  2022            mild_child_wasting  state_person_time
# 1      female  2022            mild_child_wasting  state_person_time
# 2      female  2022            mild_child_wasting  state_person_time
# 3      female  2022            mild_child_wasting  state_person_time
# ...       ...   ...                           ...                ...
# 34556    male  2026  susceptible_to_child_wasting  state_person_time
# 34557    male  2026  susceptible_to_child_wasting  state_person_time
# 34558    male  2026  susceptible_to_child_wasting  state_person_time
# 34559    male  2026  susceptible_to_child_wasting  state_person_time
#
#        input_draw           scenario          value     sq_lns  \
# 0              29           baseline       0.000000    covered
# 1              29           baseline       0.000000    covered
# 2              29           baseline     201.939767  uncovered
# ...

# %%
wasting_prevalence_post_intervention = csr.get_prevalence(
    results,
    state_variable='wasting_state',
    strata=[], # stratifying by nothing computes prevalence among all ages, sexes, and years unless prefiltered
    prefilter_query="year>'2022'", # filter out pre-intervention year
    multiplier=100, # use units of percent
)
wasting_prevalence_post_intervention
# Out:
#      input_draw           scenario                 wasting_state      value  \
# 0            29           baseline            mild_child_wasting  21.471650
# 1            29           baseline   moderate_acute_malnutrition   8.004558
# 2            29           baseline     severe_acute_malnutrition   1.947800
# 3            29           baseline  susceptible_to_child_wasting  68.575993
# ..          ...                ...                           ...        ...
# 140         946  wasting_treatment            mild_child_wasting  22.320811
# 141         946  wasting_treatment   moderate_acute_malnutrition   6.996664
# 142         946  wasting_treatment     severe_acute_malnutrition   1.611424
# 143         946  wasting_treatment  susceptible_to_child_wasting  69.071101
#
#      numerator_measure denominator_measure  multiplier     measure
# 0    state_person_time   state_person_time         100  prevalence
# 1    state_person_time   state_person_time         100  prevalence
# ...

# %% [markdown]
# # 2. Compute prevalence of MAM+SAM
#
# I'll add two aggregate "super-states" to the `'wasting_state'` column of the prevalence dataframe, one for SAM+MAM, and one for its complement, MILD+TMREL.

# %%
# Test to make sure I'm inverting the state-superstate map correctly:
# First list states in each superstate
superstate_to_states = {
    'acute_malnutrition': ['moderate_acute_malnutrition', 'severe_acute_malnutrition'],
    'no_acute_malnutrition': ['susceptible_to_child_wasting', 'mild_child_wasting'],
}
# Now invert the map to get the superstate of each state
state_to_superstate = {
    state: superstate for superstate, states in superstate_to_states.items() for state in states
}
state_to_superstate
# Out:
# {'moderate_acute_malnutrition': 'acute_malnutrition',
#  'severe_acute_malnutrition': 'acute_malnutrition',
#  'susceptible_to_child_wasting': 'no_acute_malnutrition',
#  'mild_child_wasting': 'no_acute_malnutrition'}

# %%
def aggregate_wasting_states(df, append=False):
    """"""
    superstate_to_states = {
        'acute_malnutrition': ['moderate_acute_malnutrition', 'severe_acute_malnutrition'],
        'no_acute_malnutrition': ['susceptible_to_child_wasting', 'mild_child_wasting'],
    }
    state_to_superstate = {
        state: superstate for superstate, states in superstate_to_states.items() for state in states
    }
    aggregated_df = (
        df.rename(columns={'wasting_state':'orig_wasting_state'})
        .assign(wasting_state=lambda df: df['orig_wasting_state'].map(state_to_superstate))
        .pipe(vp.marginalize, 'orig_wasting_state')
    )
    if append:
        return df.append(aggregated_df, ignore_index=True)
    else:
        return aggregated_df

# Test with append=False
aggregate_wasting_states(wasting_prevalence_post_intervention)
# Out:
#    denominator_measure  input_draw     measure  multiplier  numerator_measure  \
# 0    state_person_time          29  prevalence         100  state_person_time
# 1    state_person_time          29  prevalence         100  state_person_time
# 2    state_person_time          29  prevalence         100  state_person_time
# 3    state_person_time          29  prevalence         100  state_person_time
# ..                 ...         ...         ...         ...                ...
# 68   state_person_time         946  prevalence         100  state_person_time
# 69   state_person_time         946  prevalence         100  state_person_time
# 70   state_person_time         946  prevalence         100  state_person_time
# 71   state_person_time         946  prevalence         100  state_person_time
#
#              scenario          wasting_state      value
# 0            baseline     acute_malnutrition   9.952358
# 1            baseline  no_acute_malnutrition  90.047642
# ...

# %%
# Test with append=True
aggregate_wasting_states(wasting_prevalence_post_intervention, append=True)
# Out:
#      input_draw           scenario                 wasting_state      value  \
# 0            29           baseline            mild_child_wasting  21.471650
# 1            29           baseline   moderate_acute_malnutrition   8.004558
# 2            29           baseline     severe_acute_malnutrition   1.947800
# 3            29           baseline  susceptible_to_child_wasting  68.575993
# ..          ...                ...                           ...        ...
# 212         946              sqlns            acute_malnutrition   7.743763
# 213         946              sqlns         no_acute_malnutrition  92.256237
# 214         946  wasting_treatment            acute_malnutrition   8.608088
# 215         946  wasting_treatment         no_acute_malnutrition  91.391912
#
#      numerator_measure denominator_measure  multiplier     measure
# 0    state_person_time   state_person_time         100  prevalence
# 1    state_person_time   state_person_time         100  prevalence
# ...

# %%
144+72 # check that rows add up correctly
# Out:
# 216

# %% [markdown]
# ## Append prevalence of aggregated superstates to dataframe, and display mean prevalence of each wasting state or superstate

# %%
# Append prevalence of the "superstates" 'acute_malnutrition' and 'no_acute_malnutrition'
wasting_prevalence_post_intervention = aggregate_wasting_states(
    wasting_prevalence_post_intervention, append=True)

# %%
# Order the wasting states and scenarios to automatically display in desired order
csr.to_ordered_categoricals(wasting_prevalence_post_intervention, inplace=True)
# Compute mean prevalence of each wasting state
vp.describe(wasting_prevalence_post_intervention)['mean'].unstack('wasting_state').round(1)
# Out:
# wasting_state                                                                  severe_acute_malnutrition  \
# denominator_measure measure    multiplier numerator_measure scenario
# state_person_time   prevalence 100        state_person_time baseline                                 1.9
#                                                             wasting_treatment                        1.6
#                                                             sqlns                                    1.5
#
# wasting_state                                                                  moderate_acute_malnutrition  \
# denominator_measure measure    multiplier numerator_measure scenario
# state_person_time   prevalence 100        state_person_time baseline                                   8.0
#                                                             wasting_treatment                          6.9
# ...

# %% [markdown]
# # 3. Compute reduction in wasting prevalence
#
# Use the `averted` function in my `vivarium_output_processing` module to subtract the prevalence in each intervention scenario from the prevalence in baseline.

# %%
# Compute reduction in prevalence of all wasting states
wasting_prevalence_reduction = vp.averted(
    wasting_prevalence_post_intervention, baseline_scenario='baseline')
wasting_prevalence_reduction
# Out:
#      input_draw                 wasting_state  numerator_measure  \
# 0            29            acute_malnutrition  state_person_time
# 1            29            acute_malnutrition  state_person_time
# 2            29            mild_child_wasting  state_person_time
# 3            29            mild_child_wasting  state_person_time
# ..          ...                           ...                ...
# 140         946     severe_acute_malnutrition  state_person_time
# 141         946     severe_acute_malnutrition  state_person_time
# 142         946  susceptible_to_child_wasting  state_person_time
# 143         946  susceptible_to_child_wasting  state_person_time
#
#     denominator_measure  multiplier     measure           scenario  \
# 0     state_person_time         100  prevalence              sqlns
# 1     state_person_time         100  prevalence  wasting_treatment
# 2     state_person_time         100  prevalence              sqlns
# ...

# %%
csr.to_ordered_categoricals(wasting_prevalence_reduction, inplace=True)
vp.describe(wasting_prevalence_reduction)['mean'].unstack('wasting_state')
# Out:
# wasting_state                                                                                  severe_acute_malnutrition  \
# denominator_measure measure    multiplier numerator_measure scenario          subtracted_from
# state_person_time   prevalence 100        state_person_time wasting_treatment baseline                          0.286138
#                                                             sqlns             baseline                          0.427486
#
# wasting_state                                                                                  moderate_acute_malnutrition  \
# denominator_measure measure    multiplier numerator_measure scenario          subtracted_from
# state_person_time   prevalence 100        state_person_time wasting_treatment baseline                            1.047874
#                                                             sqlns             baseline                            1.806088
#
# ...

# %% [markdown]
# # 4. Compute percent reduction from baseline
#
# Unfortunately, most functions in my `vivarium_output_processing` module are designed to do computations within a single scenario rather than to compare things between scenarios (the exception is the `averted` function and the more general `difference` function)...
#
# ## The desired computation doesn't work with my existing `ratio` function because numerator and denominator are automatically matched on `'scenario'` column (as well as `'input_draw'` column)

# %% [raw]
# vp.ratio(
#     wasting_prevalence_reduction.rename(columns={'scenario': 'numerator_scenario'}),
#     (wasting_prevalence_post_intervention
#      .query("scenario=='baseline'")
#      .rename(columns={'scenario': 'denominator_scenario'})),
#     strata=[],
#     numerator_broadcast = 'numerator_scenario',
#     denominator_broadcast = 'denominator_scenario',
#     multiplier = 100,
# )
#
# # Fails with KeyError: 'scenario'
# # because 'scenario' is in the global index columns

# %% [markdown]
# But we can use the awesomeness of Python to come up with a generic solution! See https://realpython.com/primer-on-python-decorators/
#
# ## To solve the above problem, write a function wrapper to temporarily reset the global index columns so I can compare scenarios with the `ratio` function

# %%
def use_custom_index(func, index_cols):
    """"""
    def custom_index_wrapped_function(*args, **kwargs):
        orig_index_cols = vp.INDEX_COLUMNS
        vp.set_global_index_columns(vp.list_columns(index_cols))
        try:
            return func(*args, **kwargs)
        finally:
            # Make sure we reset the global index columns to their original values even if an error is raised
            vp.set_global_index_columns(orig_index_cols)
    return custom_index_wrapped_function

# %%
print(vp.INDEX_COLUMNS)
# Use DRAW_COLUMN as the only index column since the draw is all that we want
# implicitly matched between numerator and denominator
wasting_prevalence_percent_reduction = use_custom_index(vp.ratio, vp.DRAW_COLUMN)(
    wasting_prevalence_reduction,
    (wasting_prevalence_post_intervention
     .query("scenario=='baseline'")
     .rename(columns={'scenario': 'reference_scenario'})),
    strata=['wasting_state'],
    numerator_broadcast = 'scenario',
    denominator_broadcast = 'reference_scenario',
    multiplier = 100,
)
print(vp.INDEX_COLUMNS) # Make sure INDEX_COLUMNS got reset to correct value
wasting_prevalence_percent_reduction
# Out:
# ['input_draw', 'scenario']
# ['input_draw', 'scenario']
#                     wasting_state  input_draw           scenario  \
# 0              acute_malnutrition          29  wasting_treatment
# 1              acute_malnutrition          29              sqlns
# 2              acute_malnutrition         223  wasting_treatment
# 3              acute_malnutrition         223              sqlns
# ..                            ...         ...                ...
# 140  susceptible_to_child_wasting         829  wasting_treatment
# 141  susceptible_to_child_wasting         829              sqlns
# 142  susceptible_to_child_wasting         946  wasting_treatment
# 143  susceptible_to_child_wasting         946              sqlns
#
#     reference_scenario      value numerator_measure denominator_measure  \
# 0             baseline  14.338396        prevalence          prevalence
# 1             baseline  25.239740        prevalence          prevalence
# ...

# %%
csr.to_ordered_categoricals(wasting_prevalence_percent_reduction, inplace=True)
vp.describe(wasting_prevalence_percent_reduction)['mean'].unstack('wasting_state')
# Out:
# wasting_state                                                                          severe_acute_malnutrition  \
# denominator_measure multiplier numerator_measure reference_scenario scenario
# prevalence          100        prevalence        baseline           wasting_treatment                  15.025312
#                                                                     sqlns                              22.514591
#
# wasting_state                                                                          moderate_acute_malnutrition  \
# denominator_measure multiplier numerator_measure reference_scenario scenario
# prevalence          100        prevalence        baseline           wasting_treatment                    13.175274
#                                                                     sqlns                                22.698299
#
# wasting_state                                                                          mild_child_wasting  \
# ...

# %%
vp.describe(wasting_prevalence_percent_reduction)[['mean', '2.5%', '97.5%']].unstack('wasting_state')
# Out:
#                                                                                                            mean  \
# wasting_state                                                                         severe_acute_malnutrition
# denominator_measure multiplier numerator_measure reference_scenario scenario
# prevalence          100        prevalence        baseline           wasting_treatment                 15.025312
#                                                                     sqlns                             22.514591
#
#                                                                                                                    \
# wasting_state                                                                         moderate_acute_malnutrition
# denominator_measure multiplier numerator_measure reference_scenario scenario
# prevalence          100        prevalence        baseline           wasting_treatment                   13.175274
# ...

# %% [markdown]
# # 5. Filter to the desired states (SAM, MAM, SAM+MAM) and display results

# %%
states_of_interest = ['severe_acute_malnutrition', 'moderate_acute_malnutrition', 'acute_malnutrition']
vp.describe(
    wasting_prevalence_percent_reduction.query("wasting_state in @states_of_interest")
)['mean'].unstack('wasting_state').round(1)
# Out:
# wasting_state                                                                          severe_acute_malnutrition  \
# denominator_measure multiplier numerator_measure reference_scenario scenario
# prevalence          100        prevalence        baseline           wasting_treatment                       15.0
#                                                                     sqlns                                   22.5
#
# wasting_state                                                                          moderate_acute_malnutrition  \
# denominator_measure multiplier numerator_measure reference_scenario scenario
# prevalence          100        prevalence        baseline           wasting_treatment                         13.2
#                                                                     sqlns                                     22.7
#
# wasting_state                                                                          acute_malnutrition
# ...

# %%
vp.describe(
    wasting_prevalence_percent_reduction.query("wasting_state in @states_of_interest")
)[['mean', '2.5%', '97.5%']].round(1)
# Out:
#                                                                                                                    mean  \
# denominator_measure multiplier numerator_measure reference_scenario scenario          wasting_state
# prevalence          100        prevalence        baseline           wasting_treatment severe_acute_malnutrition    15.0
#                                                                                       moderate_acute_malnutrition  13.2
#                                                                                       acute_malnutrition           13.5
#                                                                     sqlns             severe_acute_malnutrition    22.5
#                                                                                       moderate_acute_malnutrition  22.7
#                                                                                       acute_malnutrition           22.7
#
# ...

# %%
# Calculate % reduction in SAM using rounded mean prevalence values - it's slightly higer than the real value
((1.9+8.0)-(1.5+6.1)) / (1.9+8.0)
# Out:
# 0.23232323232323238

# %%
# Also check the percent change in the other states
vp.describe(
    wasting_prevalence_percent_reduction.query("wasting_state not in @states_of_interest")
)[['mean', '2.5%', '97.5%']].round(1)
# Out:
#                                                                                                                     mean  \
# denominator_measure multiplier numerator_measure reference_scenario scenario          wasting_state
# prevalence          100        prevalence        baseline           wasting_treatment mild_child_wasting            -4.1
#                                                                                       susceptible_to_child_wasting  -0.6
#                                                                                       no_acute_malnutrition         -1.5
#                                                                     sqlns             mild_child_wasting            -7.0
#                                                                                       susceptible_to_child_wasting  -1.1
#                                                                                       no_acute_malnutrition         -2.5
#
# ...

# %% [markdown]
# # Now repeat all the above steps but for ages 6-59 months in year 2026
#
# Steps:
#
# 1. Compute wasting state prevalence for desired strata
# 2. Append prevalence of superstates 'acute_malnutrition' and 'no_acute_malnutrition'
# 3. Compute reduction in prevalence of each wasting (super)state in each intervention scenario
# 4. Compute the percent reduction of each wasting (super)state from baseline
# 5. Filter to desired states and display results

# %% [markdown]
# ## 1. Compute wasting state prevalence

# %%
# Get the list of age groups over 6 months
under_6mo, over_6mo, all_ages = map(list, csr.get_age_group_bins('6-11_months', 'all_ages'))
over_6mo
# Out:
# ['6-11_months', '12_to_23_months', '2_to_4']

# %%
wasting_prevalence_over_6mo_2026 = csr.get_prevalence(
    results,
    state_variable='wasting_state',
    strata='year',
    prefilter_query=f"year=='2026' and age in {over_6mo}",
    multiplier=100
)
wasting_prevalence_over_6mo_2026
# Out:
#      year  input_draw           scenario                 wasting_state  \
# 0    2026          29           baseline            mild_child_wasting
# 1    2026          29           baseline   moderate_acute_malnutrition
# 2    2026          29           baseline     severe_acute_malnutrition
# 3    2026          29           baseline  susceptible_to_child_wasting
# ..    ...         ...                ...                           ...
# 140  2026         946  wasting_treatment            mild_child_wasting
# 141  2026         946  wasting_treatment   moderate_acute_malnutrition
# 142  2026         946  wasting_treatment     severe_acute_malnutrition
# 143  2026         946  wasting_treatment  susceptible_to_child_wasting
#
#          value  numerator_measure denominator_measure  multiplier     measure
# 0    21.596737  state_person_time   state_person_time         100  prevalence
# 1     7.910050  state_person_time   state_person_time         100  prevalence
# ...

# %% [markdown]
# ## 2. Append superstates and display mean prevalence of each (super)state

# %%
wasting_prevalence_over_6mo_2026 = aggregate_wasting_states(wasting_prevalence_over_6mo_2026, append=True)
wasting_prevalence_over_6mo_2026
# Out:
#      year  input_draw           scenario                 wasting_state  \
# 0    2026          29           baseline            mild_child_wasting
# 1    2026          29           baseline   moderate_acute_malnutrition
# 2    2026          29           baseline     severe_acute_malnutrition
# 3    2026          29           baseline  susceptible_to_child_wasting
# ..    ...         ...                ...                           ...
# 212  2026         946              sqlns            acute_malnutrition
# 213  2026         946              sqlns         no_acute_malnutrition
# 214  2026         946  wasting_treatment            acute_malnutrition
# 215  2026         946  wasting_treatment         no_acute_malnutrition
#
#          value  numerator_measure denominator_measure  multiplier     measure
# 0    21.596737  state_person_time   state_person_time         100  prevalence
# 1     7.910050  state_person_time   state_person_time         100  prevalence
# ...

# %%
csr.to_ordered_categoricals(wasting_prevalence_over_6mo_2026, inplace=True)
vp.describe(wasting_prevalence_over_6mo_2026)['mean'].unstack('wasting_state').round(1)
# Out:
# wasting_state                                                                       severe_acute_malnutrition  \
# denominator_measure measure    multiplier numerator_measure scenario          year
# state_person_time   prevalence 100        state_person_time baseline          2026                        1.8
#                                                             wasting_treatment 2026                        1.4
#                                                             sqlns             2026                        1.2
#
# wasting_state                                                                       moderate_acute_malnutrition  \
# denominator_measure measure    multiplier numerator_measure scenario          year
# state_person_time   prevalence 100        state_person_time baseline          2026                          7.9
#                                                             wasting_treatment 2026                          6.6
# ...

# %%
vp.describe(wasting_prevalence_over_6mo_2026)[['mean', '2.5%', '97.5%']].unstack('wasting_state').round(1)
# Out:
#                                                                                                         mean  \
# wasting_state                                                                      severe_acute_malnutrition
# denominator_measure measure    multiplier numerator_measure scenario          year
# state_person_time   prevalence 100        state_person_time baseline          2026                       1.8
#                                                             wasting_treatment 2026                       1.4
#                                                             sqlns             2026                       1.2
#
#                                                                                                                 \
# wasting_state                                                                      moderate_acute_malnutrition
# denominator_measure measure    multiplier numerator_measure scenario          year
# ...

# %% [markdown]
# ## 3-4. Compute reduction and relative reduction in prevalence of each wasting (super)state
#
# ### Write a general function to compute the relative reduction in a given measure

# %%
def relative_reduction(measure_df, strata, baseline_scenario, scenario_col='scenario', **kwargs):
    """Compute the relative reduction of a measure from baseline scenario to each intervention scenario."""
    reduction_from_baseline = vp.averted(measure_df, baseline_scenario, scenario_col)
    baseline_measure = (
        measure_df.query(f"{scenario_col}=={baseline_scenario!r}")
        .rename(columns={'scenario': 'reference_scenario'}))
    kwargs['numerator_broadcast'] = vp.list_columns(
        'scenario', kwargs.get('numerator_broadcast'), default=[])
    kwargs['denominator_broadcast'] = vp.list_columns(
        'reference_scenario', kwargs.get('denominator_broadcast'), default=[])
    relative_reduction = use_custom_index(vp.ratio, vp.DRAW_COLUMN)(
        reduction_from_baseline,
        baseline_measure,
        strata=strata,
        **kwargs
    )
    return relative_reduction

# %%
wasting_prevalence_over_6mo_2026_percent_reduction = relative_reduction(
    wasting_prevalence_over_6mo_2026,
    strata=['wasting_state'],
    baseline_scenario='baseline',
    multiplier=100,
)
wasting_prevalence_over_6mo_2026_percent_reduction
# Out:
# {'multiplier': 100, 'numerator_broadcast': ['scenario'], 'denominator_broadcast': ['reference_scenario']}
#                     wasting_state  input_draw           scenario  \
# 0              acute_malnutrition          29  wasting_treatment
# 1              acute_malnutrition          29              sqlns
# 2              acute_malnutrition         223  wasting_treatment
# 3              acute_malnutrition         223              sqlns
# ..                            ...         ...                ...
# 140  susceptible_to_child_wasting         829  wasting_treatment
# 141  susceptible_to_child_wasting         829              sqlns
# 142  susceptible_to_child_wasting         946  wasting_treatment
# 143  susceptible_to_child_wasting         946              sqlns
#
#     reference_scenario      value numerator_measure denominator_measure  \
# 0             baseline  17.267884        prevalence          prevalence
# ...

# %% [markdown]
# ## 5. Filter to desired states (SAM, MAM, SAM+MAM) and display results

# %%
csr.to_ordered_categoricals(wasting_prevalence_over_6mo_2026_percent_reduction, inplace=True)
vp.describe(
    wasting_prevalence_over_6mo_2026_percent_reduction.query("wasting_state in @states_of_interest")
)['mean'].unstack('wasting_state').round(1)
# Out:
# wasting_state                                                                          severe_acute_malnutrition  \
# denominator_measure multiplier numerator_measure reference_scenario scenario
# prevalence          100        prevalence        baseline           wasting_treatment                       19.2
#                                                                     sqlns                                   28.9
#
# wasting_state                                                                          moderate_acute_malnutrition  \
# denominator_measure multiplier numerator_measure reference_scenario scenario
# prevalence          100        prevalence        baseline           wasting_treatment                         15.7
#                                                                     sqlns                                     26.9
#
# wasting_state                                                                          acute_malnutrition
# ...

# %%
vp.describe(
    wasting_prevalence_over_6mo_2026_percent_reduction.query("wasting_state in @states_of_interest")
)[['mean', '2.5%', '97.5%']].round(1)
# Out:
#                                                                                                                    mean  \
# denominator_measure multiplier numerator_measure reference_scenario scenario          wasting_state
# prevalence          100        prevalence        baseline           wasting_treatment severe_acute_malnutrition    19.2
#                                                                                       moderate_acute_malnutrition  15.7
#                                                                                       acute_malnutrition           16.3
#                                                                     sqlns             severe_acute_malnutrition    28.9
#                                                                                       moderate_acute_malnutrition  26.9
#                                                                                       acute_malnutrition           27.3
#
# ...

# %%
# Also check results for the other 3 states
vp.describe(
    wasting_prevalence_over_6mo_2026_percent_reduction.query("wasting_state not in @states_of_interest")
)[['mean', '2.5%', '97.5%']].round(1)
# Out:
#                                                                                                                     mean  \
# denominator_measure multiplier numerator_measure reference_scenario scenario          wasting_state
# prevalence          100        prevalence        baseline           wasting_treatment mild_child_wasting            -4.1
#                                                                                       susceptible_to_child_wasting  -1.0
#                                                                                       no_acute_malnutrition         -1.7
#                                                                     sqlns             mild_child_wasting            -6.9
#                                                                                       susceptible_to_child_wasting  -1.7
#                                                                                       no_acute_malnutrition         -2.9
#
# ...
