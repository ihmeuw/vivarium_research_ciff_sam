# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
pd.set_option('display.max_rows', 8)

from scipy import stats
import collections

import warnings
# warnings.filterwarnings('ignore')
from matplotlib.backends.backend_pdf import PdfPages

from pathlib import Path

import db_queries as db
import vivarium_helpers.id_helper as idh
import gbd_mapping
from vivarium import Artifact

# Add the repo directory vivarium_research_ciff_sam/ to sys.path
import os, sys
repo_path = os.path.abspath('../..')
sys.path.append(repo_path)
# Assumes vivarium_research_ciff_sam/ is in sys.path
# import model_validation.vivarium_transformed_output as vto
# import model_validation.vivarium_raw_output as vro
import model_validation.vivarium_output_processing as vp
import model_validation.ciff_sam_results as csr
import model_validation.ciff_sam_plots as csp

# %load_ext autoreload
# %autoreload 2

# !pwd
# !whoami
# !date
# Out:
# /ihme/homes/ndbs/vivarium_research_ciff_sam/model_validation/model4
# ndbs
# Thu Oct 14 15:23:36 PDT 2021

# %% [markdown]
# # Load data and set global index columns

# %%
results = csr.VivariumResults.cleaned_from_model_spec('4.5.2')
results.table_names()
# Out:
# ['wasting_transition_count',
#  'wasting_state_person_time',
#  'deaths',
#  'stunting_state_person_time',
#  'population',
#  'ylls',
#  'ylds',
#  'person_time',
#  'cause_state_person_time',
#  'cause_transition_count']

# %%
vp.set_global_index_columns(vp.INDEX_COLUMNS+['x_factor_effect'])
vp.INDEX_COLUMNS
# Out:
# ['input_draw', 'scenario', 'x_factor_effect']

# %% [markdown]
# # Test new `assert_cause_person_time_equal` function

# %%
csr.assert_cause_person_time_equal(results)

# %% [markdown]
# # Work on computing incidence rate ratio for X-factor

# %%
results.wasting_transition_count
# Out:
#            sex  year           measure  input_draw           scenario  \
# 0       female  2022  transition_count          29           baseline
# 1       female  2022  transition_count          29           baseline
# 2       female  2022  transition_count          29           baseline
# 3       female  2022  transition_count          29           baseline
# ...        ...   ...               ...         ...                ...
# 604796    male  2026  transition_count         946  wasting_treatment
# 604797    male  2026  transition_count         946  wasting_treatment
# 604798    male  2026  transition_count         946  wasting_treatment
# 604799    male  2026  transition_count         946  wasting_treatment
#
#         x_factor_effect   value x_factor     sq_lns wasting_treatment  \
# 0                   1.1     0.0     cat2    covered           covered
# 1                   1.1     0.0     cat1    covered           covered
# 2                   1.1     0.0     cat2    covered         uncovered
# 3                   1.1     0.0     cat1    covered         uncovered
# ...                 ...     ...      ...        ...               ...
# 604796              1.5  1629.0     cat2  uncovered           covered
# 604797              1.5   483.0     cat1  uncovered           covered
# 604798              1.5   167.0     cat2  uncovered         uncovered
# 604799              1.5    60.0     cat1  uncovered         uncovered
#
#                    age                                         transition  \
# 0       early_neonatal  mild_child_wasting_to_moderate_acute_malnutrition
# 1       early_neonatal  mild_child_wasting_to_moderate_acute_malnutrition
# 2       early_neonatal  mild_child_wasting_to_moderate_acute_malnutrition
# 3       early_neonatal  mild_child_wasting_to_moderate_acute_malnutrition
# ...                ...                                                ...
# 604796          2_to_4  susceptible_to_child_wasting_to_mild_child_was...
# 604797          2_to_4  susceptible_to_child_wasting_to_mild_child_was...
# 604798          2_to_4  susceptible_to_child_wasting_to_mild_child_was...
# 604799          2_to_4  susceptible_to_child_wasting_to_mild_child_was...
#
#                           from_state                     to_state
# 0                 mild_child_wasting  moderate_acute_malnutrition
# 1                 mild_child_wasting  moderate_acute_malnutrition
# 2                 mild_child_wasting  moderate_acute_malnutrition
# 3                 mild_child_wasting  moderate_acute_malnutrition
# ...                              ...                          ...
# 604796  susceptible_to_child_wasting           mild_child_wasting
# 604797  susceptible_to_child_wasting           mild_child_wasting
# 604798  susceptible_to_child_wasting           mild_child_wasting
# 604799  susceptible_to_child_wasting           mild_child_wasting
#
# [604800 rows x 14 columns]

# %%
results.wasting_state_person_time
# Out:
#            sex  year                 wasting_state            measure  \
# 0       female  2022            mild_child_wasting  state_person_time
# 1       female  2022            mild_child_wasting  state_person_time
# 2       female  2022            mild_child_wasting  state_person_time
# 3       female  2022            mild_child_wasting  state_person_time
# ...        ...   ...                           ...                ...
# 345596    male  2026  susceptible_to_child_wasting  state_person_time
# 345597    male  2026  susceptible_to_child_wasting  state_person_time
# 345598    male  2026  susceptible_to_child_wasting  state_person_time
# 345599    male  2026  susceptible_to_child_wasting  state_person_time
#
#         input_draw           scenario  x_factor_effect         value x_factor  \
# 0               29           baseline              1.1      0.000000     cat2
# 1               29           baseline              1.1      0.000000     cat1
# 2               29           baseline              1.1      0.000000     cat2
# 3               29           baseline              1.1      0.000000     cat1
# ...            ...                ...              ...           ...      ...
# 345596         946  wasting_treatment              1.5  16475.270363     cat2
# 345597         946  wasting_treatment              1.5   3419.826146     cat1
# 345598         946  wasting_treatment              1.5   1704.976044     cat2
# 345599         946  wasting_treatment              1.5    384.646133     cat1
#
#            sq_lns wasting_treatment             age
# 0         covered           covered  early_neonatal
# 1         covered           covered  early_neonatal
# 2         covered         uncovered  early_neonatal
# 3         covered         uncovered  early_neonatal
# ...           ...               ...             ...
# 345596  uncovered           covered          2_to_4
# 345597  uncovered           covered          2_to_4
# 345598  uncovered         uncovered          2_to_4
# 345599  uncovered         uncovered          2_to_4
#
# [345600 rows x 12 columns]

# %% [markdown]
# # Find the 3 transitions representing wasting state incidence rates

# %%
results.wasting_transition_count.transition.unique()
# Out:
# array(['mild_child_wasting_to_moderate_acute_malnutrition',
#        'mild_child_wasting_to_susceptible_to_child_wasting',
#        'moderate_acute_malnutrition_to_mild_child_wasting',
#        'moderate_acute_malnutrition_to_severe_acute_malnutrition',
#        'severe_acute_malnutrition_to_mild_child_wasting',
#        'severe_acute_malnutrition_to_moderate_acute_malnutrition',
#        'susceptible_to_child_wasting_to_mild_child_wasting'], dtype=object)

# %%
wasting_incidence_transitions = [
    'susceptible_to_child_wasting_to_mild_child_wasting',
    'mild_child_wasting_to_moderate_acute_malnutrition',
    'moderate_acute_malnutrition_to_severe_acute_malnutrition',
]

# %% [markdown]
# # Check that transition counts are 0 for late neonatal
#
# They should be 0 for all age groups under 6 months.

# %%
results.wasting_transition_count.query("age == 'late_neonatal'")
# Out:
#            sex  year           measure  input_draw           scenario  \
# 8       female  2022  transition_count          29           baseline
# 9       female  2022  transition_count          29           baseline
# 10      female  2022  transition_count          29           baseline
# 11      female  2022  transition_count          29           baseline
# ...        ...   ...               ...         ...                ...
# 604764    male  2026  transition_count         946  wasting_treatment
# 604765    male  2026  transition_count         946  wasting_treatment
# 604766    male  2026  transition_count         946  wasting_treatment
# 604767    male  2026  transition_count         946  wasting_treatment
#
#         x_factor_effect  value x_factor     sq_lns wasting_treatment  \
# 8                   1.1    0.0     cat2    covered           covered
# 9                   1.1    0.0     cat1    covered           covered
# 10                  1.1    0.0     cat2    covered         uncovered
# 11                  1.1    0.0     cat1    covered         uncovered
# ...                 ...    ...      ...        ...               ...
# 604764              1.5    0.0     cat2  uncovered           covered
# 604765              1.5    0.0     cat1  uncovered           covered
# 604766              1.5    0.0     cat2  uncovered         uncovered
# 604767              1.5    0.0     cat1  uncovered         uncovered
#
#                   age                                         transition  \
# 8       late_neonatal  mild_child_wasting_to_moderate_acute_malnutrition
# 9       late_neonatal  mild_child_wasting_to_moderate_acute_malnutrition
# 10      late_neonatal  mild_child_wasting_to_moderate_acute_malnutrition
# 11      late_neonatal  mild_child_wasting_to_moderate_acute_malnutrition
# ...               ...                                                ...
# 604764  late_neonatal  susceptible_to_child_wasting_to_mild_child_was...
# 604765  late_neonatal  susceptible_to_child_wasting_to_mild_child_was...
# 604766  late_neonatal  susceptible_to_child_wasting_to_mild_child_was...
# 604767  late_neonatal  susceptible_to_child_wasting_to_mild_child_was...
#
#                           from_state                     to_state
# 8                 mild_child_wasting  moderate_acute_malnutrition
# 9                 mild_child_wasting  moderate_acute_malnutrition
# 10                mild_child_wasting  moderate_acute_malnutrition
# 11                mild_child_wasting  moderate_acute_malnutrition
# ...                              ...                          ...
# 604764  susceptible_to_child_wasting           mild_child_wasting
# 604765  susceptible_to_child_wasting           mild_child_wasting
# 604766  susceptible_to_child_wasting           mild_child_wasting
# 604767  susceptible_to_child_wasting           mild_child_wasting
#
# [100800 rows x 14 columns]

# %%
(results.wasting_transition_count.query("age == 'late_neonatal'").value==0).all()
# Out:
# True

# %% [markdown]
# # Get age group bins for over 6mo and under 6mo

# %%
csr.get_age_group_bins('6-11_months', 'all_ages')
# Out:
# (['early_neonatal', 'late_neonatal', '1-5_months']
#  Categories (7, object): ['early_neonatal' < 'late_neonatal' < '1-5_months' < '6-11_months' < '12_to_23_months' < '2_to_4' < 'all_ages'],
#  ['6-11_months', '12_to_23_months', '2_to_4']
#  Categories (7, object): ['early_neonatal' < 'late_neonatal' < '1-5_months' < '6-11_months' < '12_to_23_months' < '2_to_4' < 'all_ages'],
#  ['all_ages']
#  Categories (7, object): ['early_neonatal' < 'late_neonatal' < '1-5_months' < '6-11_months' < '12_to_23_months' < '2_to_4' < 'all_ages'])

# %%
under_6mo, over_6mo, all_ages = map(list, csr.get_age_group_bins('6-11_months', 'all_ages'))
print(under_6mo, over_6mo, all_ages)
# Out:
# ['early_neonatal', 'late_neonatal', '1-5_months'] ['6-11_months', '12_to_23_months', '2_to_4'] ['all_ages']

# %% [markdown]
# # Test `get_transition_rates` function after refactoring

# %%
transition_rates_by_age_year = csr.get_transition_rates(results, 'wasting', ['age', 'year'])
transition_rates_by_age_year
# Out:
#                  age  year                    from_state  input_draw  \
# 0         1-5_months  2022            mild_child_wasting          29
# 1         1-5_months  2022            mild_child_wasting          29
# 2         1-5_months  2022            mild_child_wasting          29
# 3         1-5_months  2022            mild_child_wasting          29
# ...              ...   ...                           ...         ...
# 37796  late_neonatal  2026  susceptible_to_child_wasting         946
# 37797  late_neonatal  2026  susceptible_to_child_wasting         946
# 37798  late_neonatal  2026  susceptible_to_child_wasting         946
# 37799  late_neonatal  2026  susceptible_to_child_wasting         946
#
#                 scenario  x_factor_effect  \
# 0               baseline              1.1
# 1               baseline              1.1
# 2               baseline              1.2
# 3               baseline              1.2
# ...                  ...              ...
# 37796  wasting_treatment              1.2
# 37797  wasting_treatment              1.3
# 37798  wasting_treatment              1.4
# 37799  wasting_treatment              1.5
#
#                                               transition  \
# 0      mild_child_wasting_to_moderate_acute_malnutrition
# 1      mild_child_wasting_to_susceptible_to_child_was...
# 2      mild_child_wasting_to_moderate_acute_malnutrition
# 3      mild_child_wasting_to_susceptible_to_child_was...
# ...                                                  ...
# 37796  susceptible_to_child_wasting_to_mild_child_was...
# 37797  susceptible_to_child_wasting_to_mild_child_was...
# 37798  susceptible_to_child_wasting_to_mild_child_was...
# 37799  susceptible_to_child_wasting_to_mild_child_was...
#
#                            to_state  value numerator_measure  \
# 0       moderate_acute_malnutrition    0.0  transition_count
# 1      susceptible_to_child_wasting    0.0  transition_count
# 2       moderate_acute_malnutrition    0.0  transition_count
# 3      susceptible_to_child_wasting    0.0  transition_count
# ...                             ...    ...               ...
# 37796            mild_child_wasting    0.0  transition_count
# 37797            mild_child_wasting    0.0  transition_count
# 37798            mild_child_wasting    0.0  transition_count
# 37799            mild_child_wasting    0.0  transition_count
#
#       denominator_measure  multiplier
# 0       state_person_time           1
# 1       state_person_time           1
# 2       state_person_time           1
# 3       state_person_time           1
# ...                   ...         ...
# 37796   state_person_time           1
# 37797   state_person_time           1
# 37798   state_person_time           1
# 37799   state_person_time           1
#
# [37800 rows x 12 columns]

# %%
transition_rates_by_age_year.transition.unique()
# Out:
# array(['mild_child_wasting_to_moderate_acute_malnutrition',
#        'mild_child_wasting_to_susceptible_to_child_wasting',
#        'moderate_acute_malnutrition_to_mild_child_wasting',
#        'moderate_acute_malnutrition_to_severe_acute_malnutrition',
#        'severe_acute_malnutrition_to_mild_child_wasting',
#        'severe_acute_malnutrition_to_moderate_acute_malnutrition',
#        'susceptible_to_child_wasting_to_mild_child_wasting'], dtype=object)

# %%
transition_rates_by_age_year.isna().any().any()
# Out:
# False

# %%
transition_rates_by_age_year_x_factor = csr.get_transition_rates(results, 'wasting', ['age', 'year', 'x_factor'])
transition_rates_by_age_year_x_factor
# Out:
#                  age  year x_factor                    from_state  input_draw  \
# 0         1-5_months  2022     cat1            mild_child_wasting          29
# 1         1-5_months  2022     cat1            mild_child_wasting          29
# 2         1-5_months  2022     cat1            mild_child_wasting          29
# 3         1-5_months  2022     cat1            mild_child_wasting          29
# ...              ...   ...      ...                           ...         ...
# 75596  late_neonatal  2026     cat2  susceptible_to_child_wasting         946
# 75597  late_neonatal  2026     cat2  susceptible_to_child_wasting         946
# 75598  late_neonatal  2026     cat2  susceptible_to_child_wasting         946
# 75599  late_neonatal  2026     cat2  susceptible_to_child_wasting         946
#
#                 scenario  x_factor_effect  \
# 0               baseline              1.1
# 1               baseline              1.1
# 2               baseline              1.2
# 3               baseline              1.2
# ...                  ...              ...
# 75596  wasting_treatment              1.2
# 75597  wasting_treatment              1.3
# 75598  wasting_treatment              1.4
# 75599  wasting_treatment              1.5
#
#                                               transition  \
# 0      mild_child_wasting_to_moderate_acute_malnutrition
# 1      mild_child_wasting_to_susceptible_to_child_was...
# 2      mild_child_wasting_to_moderate_acute_malnutrition
# 3      mild_child_wasting_to_susceptible_to_child_was...
# ...                                                  ...
# 75596  susceptible_to_child_wasting_to_mild_child_was...
# 75597  susceptible_to_child_wasting_to_mild_child_was...
# 75598  susceptible_to_child_wasting_to_mild_child_was...
# 75599  susceptible_to_child_wasting_to_mild_child_was...
#
#                            to_state  value numerator_measure  \
# 0       moderate_acute_malnutrition    0.0  transition_count
# 1      susceptible_to_child_wasting    0.0  transition_count
# 2       moderate_acute_malnutrition    0.0  transition_count
# 3      susceptible_to_child_wasting    0.0  transition_count
# ...                             ...    ...               ...
# 75596            mild_child_wasting    0.0  transition_count
# 75597            mild_child_wasting    0.0  transition_count
# 75598            mild_child_wasting    0.0  transition_count
# 75599            mild_child_wasting    0.0  transition_count
#
#       denominator_measure  multiplier
# 0       state_person_time           1
# 1       state_person_time           1
# 2       state_person_time           1
# 3       state_person_time           1
# ...                   ...         ...
# 75596   state_person_time           1
# 75597   state_person_time           1
# 75598   state_person_time           1
# 75599   state_person_time           1
#
# [75600 rows x 13 columns]

# %%
transition_rates_by_age_year_x_factor.isna().any().any()
# Out:
# False

# %%
transition_rates_by_age_year_x_factor_filtered = csr.get_transition_rates(
    results,
    'wasting',
    strata=['age', 'year', 'x_factor'],
    transition_query=f"age in {over_6mo}",
    person_time_query=f"age in {over_6mo}",
)
transition_rates_by_age_year_x_factor_filtered
# Out:
#                    age  year x_factor                    from_state  \
# 0      12_to_23_months  2022     cat1            mild_child_wasting
# 1      12_to_23_months  2022     cat1            mild_child_wasting
# 2      12_to_23_months  2022     cat1            mild_child_wasting
# 3      12_to_23_months  2022     cat1            mild_child_wasting
# ...                ...   ...      ...                           ...
# 37796      6-11_months  2026     cat2  susceptible_to_child_wasting
# 37797      6-11_months  2026     cat2  susceptible_to_child_wasting
# 37798      6-11_months  2026     cat2  susceptible_to_child_wasting
# 37799      6-11_months  2026     cat2  susceptible_to_child_wasting
#
#        input_draw           scenario  x_factor_effect  \
# 0              29           baseline              1.1
# 1              29           baseline              1.1
# 2              29           baseline              1.2
# 3              29           baseline              1.2
# ...           ...                ...              ...
# 37796         946  wasting_treatment              1.2
# 37797         946  wasting_treatment              1.3
# 37798         946  wasting_treatment              1.4
# 37799         946  wasting_treatment              1.5
#
#                                               transition  \
# 0      mild_child_wasting_to_moderate_acute_malnutrition
# 1      mild_child_wasting_to_susceptible_to_child_was...
# 2      mild_child_wasting_to_moderate_acute_malnutrition
# 3      mild_child_wasting_to_susceptible_to_child_was...
# ...                                                  ...
# 37796  susceptible_to_child_wasting_to_mild_child_was...
# 37797  susceptible_to_child_wasting_to_mild_child_was...
# 37798  susceptible_to_child_wasting_to_mild_child_was...
# 37799  susceptible_to_child_wasting_to_mild_child_was...
#
#                            to_state     value numerator_measure  \
# 0       moderate_acute_malnutrition  3.023727  transition_count
# 1      susceptible_to_child_wasting  0.327570  transition_count
# 2       moderate_acute_malnutrition  3.250496  transition_count
# 3      susceptible_to_child_wasting  0.325650  transition_count
# ...                             ...       ...               ...
# 37796            mild_child_wasting  0.109266  transition_count
# 37797            mild_child_wasting  0.106740  transition_count
# 37798            mild_child_wasting  0.105301  transition_count
# 37799            mild_child_wasting  0.104250  transition_count
#
#       denominator_measure  multiplier
# 0       state_person_time           1
# 1       state_person_time           1
# 2       state_person_time           1
# 3       state_person_time           1
# ...                   ...         ...
# 37796   state_person_time           1
# 37797   state_person_time           1
# 37798   state_person_time           1
# 37799   state_person_time           1
#
# [37800 rows x 13 columns]

# %%
transition_rates_by_age_year_x_factor_filtered.isna().any().any()
# Out:
# False

# %% [markdown]
# # See if the way I'm thinking about the X-factor wasting incidence ratio makes sense
#
# ## I'm getting NaN's because the numerator is filtered to transitions representing incidence rates, whereas the denominator still includes person-time in the SAM category, from which there is no incidence

# %%
incidence_rates_by_age_year_x_factor_filtered = csr.get_transition_rates(
    results,
    'wasting',
    strata=['age', 'year', 'x_factor'],
    transition_query=f"age in {over_6mo} and transition in {wasting_incidence_transitions}",
    person_time_query=f"age in {over_6mo}"
)
incidence_rates_by_age_year_x_factor_filtered
# Out:
#                    age  year x_factor                    from_state  \
# 0      12_to_23_months  2022     cat1            mild_child_wasting
# 1      12_to_23_months  2022     cat1            mild_child_wasting
# 2      12_to_23_months  2022     cat1            mild_child_wasting
# 3      12_to_23_months  2022     cat1            mild_child_wasting
# ...                ...   ...      ...                           ...
# 21596      6-11_months  2026     cat2  susceptible_to_child_wasting
# 21597      6-11_months  2026     cat2  susceptible_to_child_wasting
# 21598      6-11_months  2026     cat2  susceptible_to_child_wasting
# 21599      6-11_months  2026     cat2  susceptible_to_child_wasting
#
#        input_draw           scenario  x_factor_effect  \
# 0              29           baseline              1.1
# 1              29           baseline              1.2
# 2              29           baseline              1.3
# 3              29           baseline              1.4
# ...           ...                ...              ...
# 21596         946  wasting_treatment              1.2
# 21597         946  wasting_treatment              1.3
# 21598         946  wasting_treatment              1.4
# 21599         946  wasting_treatment              1.5
#
#                                               transition  \
# 0      mild_child_wasting_to_moderate_acute_malnutrition
# 1      mild_child_wasting_to_moderate_acute_malnutrition
# 2      mild_child_wasting_to_moderate_acute_malnutrition
# 3      mild_child_wasting_to_moderate_acute_malnutrition
# ...                                                  ...
# 21596  susceptible_to_child_wasting_to_mild_child_was...
# 21597  susceptible_to_child_wasting_to_mild_child_was...
# 21598  susceptible_to_child_wasting_to_mild_child_was...
# 21599  susceptible_to_child_wasting_to_mild_child_was...
#
#                           to_state     value numerator_measure  \
# 0      moderate_acute_malnutrition  3.023727  transition_count
# 1      moderate_acute_malnutrition  3.250496  transition_count
# 2      moderate_acute_malnutrition  3.426161  transition_count
# 3      moderate_acute_malnutrition  3.577621  transition_count
# ...                            ...       ...               ...
# 21596           mild_child_wasting  0.109266  transition_count
# 21597           mild_child_wasting  0.106740  transition_count
# 21598           mild_child_wasting  0.105301  transition_count
# 21599           mild_child_wasting  0.104250  transition_count
#
#       denominator_measure  multiplier
# 0       state_person_time           1
# 1       state_person_time           1
# 2       state_person_time           1
# 3       state_person_time           1
# ...                   ...         ...
# 21596   state_person_time           1
# 21597   state_person_time           1
# 21598   state_person_time           1
# 21599   state_person_time           1
#
# [21600 rows x 13 columns]

# %%
# Why are there NaNs???
incidence_rates_by_age_year_x_factor_filtered.transition.unique()
# Out:
# array(['mild_child_wasting_to_moderate_acute_malnutrition',
#        'moderate_acute_malnutrition_to_severe_acute_malnutrition', nan,
#        'susceptible_to_child_wasting_to_mild_child_wasting'], dtype=object)

# %%
incidence_rates_by_age_year_x_factor_filtered.query("transition != transition")
# Out:
#                    age  year x_factor                 from_state  input_draw  \
# 360    12_to_23_months  2022     cat1  severe_acute_malnutrition          29
# 361    12_to_23_months  2022     cat1  severe_acute_malnutrition          29
# 362    12_to_23_months  2022     cat1  severe_acute_malnutrition          29
# 363    12_to_23_months  2022     cat1  severe_acute_malnutrition          29
# ...                ...   ...      ...                        ...         ...
# 21416      6-11_months  2026     cat2  severe_acute_malnutrition         946
# 21417      6-11_months  2026     cat2  severe_acute_malnutrition         946
# 21418      6-11_months  2026     cat2  severe_acute_malnutrition         946
# 21419      6-11_months  2026     cat2  severe_acute_malnutrition         946
#
#                 scenario  x_factor_effect transition to_state  value  \
# 360             baseline              1.1        NaN      NaN    NaN
# 361             baseline              1.2        NaN      NaN    NaN
# 362             baseline              1.3        NaN      NaN    NaN
# 363             baseline              1.4        NaN      NaN    NaN
# ...                  ...              ...        ...      ...    ...
# 21416  wasting_treatment              1.2        NaN      NaN    NaN
# 21417  wasting_treatment              1.3        NaN      NaN    NaN
# 21418  wasting_treatment              1.4        NaN      NaN    NaN
# 21419  wasting_treatment              1.5        NaN      NaN    NaN
#
#       numerator_measure denominator_measure  multiplier
# 360    transition_count   state_person_time           1
# 361    transition_count   state_person_time           1
# 362    transition_count   state_person_time           1
# 363    transition_count   state_person_time           1
# ...                 ...                 ...         ...
# 21416  transition_count   state_person_time           1
# 21417  transition_count   state_person_time           1
# 21418  transition_count   state_person_time           1
# 21419  transition_count   state_person_time           1
#
# [5400 rows x 13 columns]

# %%
incidence_rates_by_age_year_x_factor_filtered.isna().any().any()
# Out:
# True

# %%
incidence_rates_by_age_year_x_factor_filtered.query("transition != transition").from_state.unique()
# Out:
# array(['severe_acute_malnutrition'], dtype=object)

# %% [markdown]
# # Try to fix it...

# %%
results.wasting_state_person_time
# Out:
#            sex  year                 wasting_state            measure  \
# 0       female  2022            mild_child_wasting  state_person_time
# 1       female  2022            mild_child_wasting  state_person_time
# 2       female  2022            mild_child_wasting  state_person_time
# 3       female  2022            mild_child_wasting  state_person_time
# ...        ...   ...                           ...                ...
# 345596    male  2026  susceptible_to_child_wasting  state_person_time
# 345597    male  2026  susceptible_to_child_wasting  state_person_time
# 345598    male  2026  susceptible_to_child_wasting  state_person_time
# 345599    male  2026  susceptible_to_child_wasting  state_person_time
#
#         input_draw           scenario  x_factor_effect         value x_factor  \
# 0               29           baseline              1.1      0.000000     cat2
# 1               29           baseline              1.1      0.000000     cat1
# 2               29           baseline              1.1      0.000000     cat2
# 3               29           baseline              1.1      0.000000     cat1
# ...            ...                ...              ...           ...      ...
# 345596         946  wasting_treatment              1.5  16475.270363     cat2
# 345597         946  wasting_treatment              1.5   3419.826146     cat1
# 345598         946  wasting_treatment              1.5   1704.976044     cat2
# 345599         946  wasting_treatment              1.5    384.646133     cat1
#
#            sq_lns wasting_treatment             age
# 0         covered           covered  early_neonatal
# 1         covered           covered  early_neonatal
# 2         covered         uncovered  early_neonatal
# 3         covered         uncovered  early_neonatal
# ...           ...               ...             ...
# 345596  uncovered           covered          2_to_4
# 345597  uncovered           covered          2_to_4
# 345598  uncovered         uncovered          2_to_4
# 345599  uncovered         uncovered          2_to_4
#
# [345600 rows x 12 columns]

# %%
strata = ['age', 'year', 'x_factor']
#for colname in strata:
colname = 'age'
mask = results.wasting_state_person_time[colname].isin(incidence_rates_by_age_year_x_factor_filtered[colname])
results.wasting_state_person_time.loc[mask, colname].unique()
# Out:
# array(['6-11_months', '12_to_23_months', '2_to_4'], dtype=object)
