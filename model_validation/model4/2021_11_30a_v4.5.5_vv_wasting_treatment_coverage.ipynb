# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
pd.set_option('display.max_rows', 8)

from scipy import stats
import collections

import warnings
# warnings.filterwarnings('ignore')
from matplotlib.backends.backend_pdf import PdfPages

from pathlib import Path

import db_queries as db
import vivarium_helpers.id_helper as idh
import gbd_mapping
from vivarium import Artifact

# Add the repo directory vivarium_research_ciff_sam/ to sys.path
import os, sys
repo_path = os.path.abspath('../..')
sys.path.append(repo_path)
print("pwd:")
# !pwd
print(f"{repo_path=}")

# Assumes vivarium_research_ciff_sam/ is in sys.path
# import model_validation.vivarium_transformed_output as vto
# import model_validation.vivarium_raw_output as vro
import model_validation.vivarium_output_processing as vp
import model_validation.ciff_sam_results as csr
import model_validation.ciff_sam_plots as csp

# %load_ext autoreload
# %autoreload 2

# !whoami
# !date
# Out:
# pwd:
# /ihme/homes/ndbs/vivarium_research_ciff_sam/model_validation/model4
# repo_path='/ihme/homes/ndbs/vivarium_research_ciff_sam'
# ndbs
# Tue Nov 30 13:34:15 PST 2021

# %% [markdown]
# # Load data

# %%
results = csr.VivariumResults.cleaned_from_model_spec('4.5.5', '2021_11_23_17_59_09')
results.table_names()
# Out:
# ['wasting_transition_count',
#  'wasting_state_person_time',
#  'deaths',
#  'stunting_state_person_time',
#  'population',
#  'ylls',
#  'ylds',
#  'person_time',
#  'cause_state_person_time',
#  'cause_transition_count']

# %%
results.wasting_state_person_time
# Out:
#            sex  year                 wasting_state            measure  \
# 0       female  2022            mild_child_wasting  state_person_time
# 1       female  2022            mild_child_wasting  state_person_time
# 2       female  2022            mild_child_wasting  state_person_time
# 3       female  2022            mild_child_wasting  state_person_time
# ...        ...   ...                           ...                ...
# 138236    male  2026  susceptible_to_child_wasting  state_person_time
# 138237    male  2026  susceptible_to_child_wasting  state_person_time
# 138238    male  2026  susceptible_to_child_wasting  state_person_time
# 138239    male  2026  susceptible_to_child_wasting  state_person_time
#
#         input_draw           scenario        value x_factor     sq_lns  \
# 0               29           baseline     0.000000     cat2    covered
# 1               29           baseline     0.000000     cat1    covered
# 2               29           baseline     0.000000     cat2    covered
# 3               29           baseline     0.000000     cat1    covered
# ...            ...                ...          ...      ...        ...
# 138236         946  wasting_treatment  2511.623546     cat2  uncovered
# 138237         946  wasting_treatment  2323.058179     cat1  uncovered
# 138238         946  wasting_treatment  1075.831622     cat2  uncovered
# 138239         946  wasting_treatment   995.794661     cat1  uncovered
#
#        mam_treatment sam_treatment             age
# 0            covered       covered  early_neonatal
# 1            covered       covered  early_neonatal
# 2          uncovered       covered  early_neonatal
# 3          uncovered       covered  early_neonatal
# ...              ...           ...             ...
# 138236       covered     uncovered          2_to_4
# 138237       covered     uncovered          2_to_4
# 138238     uncovered     uncovered          2_to_4
# 138239     uncovered     uncovered          2_to_4
#
# [138240 rows x 12 columns]

# %% [markdown]
# # Create a dictionary to store figures

# %%
figs = {}

# %% [markdown]
# # Compute percent treated for SAM according to `sam_treatment` column

# %%
percent_sam_treated_by_age_year = csr.get_prevalence(
    results,
    'sam_treatment',
    strata=['age', 'year'],
    multiplier=100
)
percent_sam_treated_by_age_year
# Out:
#                 age  year  input_draw           scenario sam_treatment  \
# 0        1-5_months  2022          29           baseline       covered
# 1        1-5_months  2022          29           baseline     uncovered
# 2        1-5_months  2022          29              sqlns       covered
# 3        1-5_months  2022          29              sqlns     uncovered
# ...             ...   ...         ...                ...           ...
# 2156  late_neonatal  2026         946              sqlns       covered
# 2157  late_neonatal  2026         946              sqlns     uncovered
# 2158  late_neonatal  2026         946  wasting_treatment       covered
# 2159  late_neonatal  2026         946  wasting_treatment     uncovered
#
#           value  numerator_measure denominator_measure  multiplier     measure
# 0     49.636922  state_person_time   state_person_time         100  prevalence
# 1     50.363078  state_person_time   state_person_time         100  prevalence
# 2     49.636922  state_person_time   state_person_time         100  prevalence
# 3     50.363078  state_person_time   state_person_time         100  prevalence
# ...         ...                ...                 ...         ...         ...
# 2156  70.118025  state_person_time   state_person_time         100  prevalence
# 2157  29.881975  state_person_time   state_person_time         100  prevalence
# 2158  70.118025  state_person_time   state_person_time         100  prevalence
# 2159  29.881975  state_person_time   state_person_time         100  prevalence
#
# [2160 rows x 10 columns]

# %%
fig = csp.plot_over_time_by_column_for_each_scenario(
    percent_sam_treated_by_age_year.query("sam_treatment=='covered'"),
    colname='age',
    ylabel='prevalence (%)',
    suptitle='Percent treated for SAM by age group',
    uncertainty=True
)

# %% [markdown]
# # Compute percent treated for MAM according to `mam_treatment` column

# %%
percent_mam_treated_by_age_year = csr.get_prevalence(
    results,
    'mam_treatment',
    strata=['age', 'year'],
    multiplier=100
)
percent_mam_treated_by_age_year
# Out:
#                 age  year  input_draw           scenario mam_treatment  \
# 0        1-5_months  2022          29           baseline       covered
# 1        1-5_months  2022          29           baseline     uncovered
# 2        1-5_months  2022          29              sqlns       covered
# 3        1-5_months  2022          29              sqlns     uncovered
# ...             ...   ...         ...                ...           ...
# 2156  late_neonatal  2026         946              sqlns       covered
# 2157  late_neonatal  2026         946              sqlns     uncovered
# 2158  late_neonatal  2026         946  wasting_treatment       covered
# 2159  late_neonatal  2026         946  wasting_treatment     uncovered
#
#           value  numerator_measure denominator_measure  multiplier     measure
# 0     15.374409  state_person_time   state_person_time         100  prevalence
# 1     84.625591  state_person_time   state_person_time         100  prevalence
# 2     15.374409  state_person_time   state_person_time         100  prevalence
# 3     84.625591  state_person_time   state_person_time         100  prevalence
# ...         ...                ...                 ...         ...         ...
# 2156  69.984382  state_person_time   state_person_time         100  prevalence
# 2157  30.015618  state_person_time   state_person_time         100  prevalence
# 2158  69.984382  state_person_time   state_person_time         100  prevalence
# 2159  30.015618  state_person_time   state_person_time         100  prevalence
#
# [2160 rows x 10 columns]

# %%
fig = csp.plot_over_time_by_column_for_each_scenario(
    percent_mam_treated_by_age_year.query("mam_treatment=='covered'"),
    colname='age',
    ylabel='prevalence (%)',
    suptitle='Percent treated for MAM by age group',
    uncertainty=True
)

# %% [markdown]
# # Check the value of baseline coverage
#
# It should be 48.8% (95% CI: 37.4-60.4) for SAM -- are we using a normal distribution?
#
# We are getting 47.3% (95% UI: 34.8-56.6) for the 12 draws we picked -- that seems reasonable.

# %%
(37.4+60.4)/2
# Out:
# 48.9

# %%
vp.describe(
    percent_sam_treated_by_age_year.query(
        "sam_treatment=='covered' and scenario=='baseline' and year=='2022'")
)
# Out:
#                                                                                                          count  \
# age             denominator_measure measure    multiplier numerator_measure sam_treatment scenario year
# 1-5_months      state_person_time   prevalence 100        state_person_time covered       baseline 2022   12.0
# 12_to_23_months state_person_time   prevalence 100        state_person_time covered       baseline 2022   12.0
# 2_to_4          state_person_time   prevalence 100        state_person_time covered       baseline 2022   12.0
# 6-11_months     state_person_time   prevalence 100        state_person_time covered       baseline 2022   12.0
# early_neonatal  state_person_time   prevalence 100        state_person_time covered       baseline 2022   12.0
# late_neonatal   state_person_time   prevalence 100        state_person_time covered       baseline 2022   12.0
#
#                                                                                                               mean  \
# age             denominator_measure measure    multiplier numerator_measure sam_treatment scenario year
# 1-5_months      state_person_time   prevalence 100        state_person_time covered       baseline 2022  47.338063
# 12_to_23_months state_person_time   prevalence 100        state_person_time covered       baseline 2022  47.344138
# 2_to_4          state_person_time   prevalence 100        state_person_time covered       baseline 2022  47.340250
# 6-11_months     state_person_time   prevalence 100        state_person_time covered       baseline 2022  47.337745
# early_neonatal  state_person_time   prevalence 100        state_person_time covered       baseline 2022  47.353681
# late_neonatal   state_person_time   prevalence 100        state_person_time covered       baseline 2022  47.336214
#
#                                                                                                               std  \
# age             denominator_measure measure    multiplier numerator_measure sam_treatment scenario year
# 1-5_months      state_person_time   prevalence 100        state_person_time covered       baseline 2022  6.586690
# 12_to_23_months state_person_time   prevalence 100        state_person_time covered       baseline 2022  6.592026
# 2_to_4          state_person_time   prevalence 100        state_person_time covered       baseline 2022  6.595419
# 6-11_months     state_person_time   prevalence 100        state_person_time covered       baseline 2022  6.599886
# early_neonatal  state_person_time   prevalence 100        state_person_time covered       baseline 2022  6.612866
# late_neonatal   state_person_time   prevalence 100        state_person_time covered       baseline 2022  6.597512
#
#                                                                                                                min  \
# age             denominator_measure measure    multiplier numerator_measure sam_treatment scenario year
# 1-5_months      state_person_time   prevalence 100        state_person_time covered       baseline 2022  33.003893
# 12_to_23_months state_person_time   prevalence 100        state_person_time covered       baseline 2022  33.023940
# 2_to_4          state_person_time   prevalence 100        state_person_time covered       baseline 2022  33.013253
# 6-11_months     state_person_time   prevalence 100        state_person_time covered       baseline 2022  33.002899
# early_neonatal  state_person_time   prevalence 100        state_person_time covered       baseline 2022  33.052839
# late_neonatal   state_person_time   prevalence 100        state_person_time covered       baseline 2022  32.999114
#
#                                                                                                               2.5%  \
# age             denominator_measure measure    multiplier numerator_measure sam_treatment scenario year
# 1-5_months      state_person_time   prevalence 100        state_person_time covered       baseline 2022  34.813931
# 12_to_23_months state_person_time   prevalence 100        state_person_time covered       baseline 2022  34.820143
# 2_to_4          state_person_time   prevalence 100        state_person_time covered       baseline 2022  34.810811
# 6-11_months     state_person_time   prevalence 100        state_person_time covered       baseline 2022  34.814691
# early_neonatal  state_person_time   prevalence 100        state_person_time covered       baseline 2022  34.803665
# late_neonatal   state_person_time   prevalence 100        state_person_time covered       baseline 2022  34.787246
#
#                                                                                                                50%  \
# age             denominator_measure measure    multiplier numerator_measure sam_treatment scenario year
# 1-5_months      state_person_time   prevalence 100        state_person_time covered       baseline 2022  47.892413
# 12_to_23_months state_person_time   prevalence 100        state_person_time covered       baseline 2022  47.884139
# 2_to_4          state_person_time   prevalence 100        state_person_time covered       baseline 2022  47.894157
# 6-11_months     state_person_time   prevalence 100        state_person_time covered       baseline 2022  47.875656
# early_neonatal  state_person_time   prevalence 100        state_person_time covered       baseline 2022  47.908764
# late_neonatal   state_person_time   prevalence 100        state_person_time covered       baseline 2022  47.905430
#
#                                                                                                              97.5%  \
# age             denominator_measure measure    multiplier numerator_measure sam_treatment scenario year
# 1-5_months      state_person_time   prevalence 100        state_person_time covered       baseline 2022  56.627017
# 12_to_23_months state_person_time   prevalence 100        state_person_time covered       baseline 2022  56.640174
# 2_to_4          state_person_time   prevalence 100        state_person_time covered       baseline 2022  56.641881
# 6-11_months     state_person_time   prevalence 100        state_person_time covered       baseline 2022  56.666127
# early_neonatal  state_person_time   prevalence 100        state_person_time covered       baseline 2022  56.680070
# late_neonatal   state_person_time   prevalence 100        state_person_time covered       baseline 2022  56.594901
#
#                                                                                                                max
# age             denominator_measure measure    multiplier numerator_measure sam_treatment scenario year
# 1-5_months      state_person_time   prevalence 100        state_person_time covered       baseline 2022  57.935985
# 12_to_23_months state_person_time   prevalence 100        state_person_time covered       baseline 2022  57.957049
# 2_to_4          state_person_time   prevalence 100        state_person_time covered       baseline 2022  57.956473
# 6-11_months     state_person_time   prevalence 100        state_person_time covered       baseline 2022  57.976936
# early_neonatal  state_person_time   prevalence 100        state_person_time covered       baseline 2022  57.995362
# late_neonatal   state_person_time   prevalence 100        state_person_time covered       baseline 2022  57.891036

# %%
vp.describe(
    percent_treated_by_age_year.query(
        "wasting_treatment=='covered' and scenario=='baseline' and year=='2024'")
)
# Out:
#                                                                                                              count  \
# age             denominator_measure measure    multiplier numerator_measure scenario wasting_treatment year
# 1-5_months      state_person_time   prevalence 100        state_person_time baseline covered           2024   12.0
# 12_to_23_months state_person_time   prevalence 100        state_person_time baseline covered           2024   12.0
# 2_to_4          state_person_time   prevalence 100        state_person_time baseline covered           2024   12.0
# 6-11_months     state_person_time   prevalence 100        state_person_time baseline covered           2024   12.0
# early_neonatal  state_person_time   prevalence 100        state_person_time baseline covered           2024   12.0
# late_neonatal   state_person_time   prevalence 100        state_person_time baseline covered           2024   12.0
#
#                                                                                                                   mean  \
# age             denominator_measure measure    multiplier numerator_measure scenario wasting_treatment year
# 1-5_months      state_person_time   prevalence 100        state_person_time baseline covered           2024  47.295021
# 12_to_23_months state_person_time   prevalence 100        state_person_time baseline covered           2024  47.308353
# 2_to_4          state_person_time   prevalence 100        state_person_time baseline covered           2024  47.357994
# 6-11_months     state_person_time   prevalence 100        state_person_time baseline covered           2024  47.294527
# early_neonatal  state_person_time   prevalence 100        state_person_time baseline covered           2024  47.306441
# late_neonatal   state_person_time   prevalence 100        state_person_time baseline covered           2024  47.299980
#
#                                                                                                                   std  \
# age             denominator_measure measure    multiplier numerator_measure scenario wasting_treatment year
# 1-5_months      state_person_time   prevalence 100        state_person_time baseline covered           2024  6.588391
# 12_to_23_months state_person_time   prevalence 100        state_person_time baseline covered           2024  6.604034
# 2_to_4          state_person_time   prevalence 100        state_person_time baseline covered           2024  6.610015
# 6-11_months     state_person_time   prevalence 100        state_person_time baseline covered           2024  6.569269
# early_neonatal  state_person_time   prevalence 100        state_person_time baseline covered           2024  6.572917
# late_neonatal   state_person_time   prevalence 100        state_person_time baseline covered           2024  6.582746
#
#                                                                                                                    min  \
# age             denominator_measure measure    multiplier numerator_measure scenario wasting_treatment year
# 1-5_months      state_person_time   prevalence 100        state_person_time baseline covered           2024  32.929432
# 12_to_23_months state_person_time   prevalence 100        state_person_time baseline covered           2024  33.017643
# 2_to_4          state_person_time   prevalence 100        state_person_time baseline covered           2024  32.965861
# 6-11_months     state_person_time   prevalence 100        state_person_time baseline covered           2024  32.934272
# early_neonatal  state_person_time   prevalence 100        state_person_time baseline covered           2024  32.999571
# late_neonatal   state_person_time   prevalence 100        state_person_time baseline covered           2024  32.955330
#
#                                                                                                                   2.5%  \
# age             denominator_measure measure    multiplier numerator_measure scenario wasting_treatment year
# 1-5_months      state_person_time   prevalence 100        state_person_time baseline covered           2024  34.744238
# 12_to_23_months state_person_time   prevalence 100        state_person_time baseline covered           2024  34.786001
# 2_to_4          state_person_time   prevalence 100        state_person_time baseline covered           2024  34.777698
# 6-11_months     state_person_time   prevalence 100        state_person_time baseline covered           2024  34.734587
# early_neonatal  state_person_time   prevalence 100        state_person_time baseline covered           2024  34.814937
# late_neonatal   state_person_time   prevalence 100        state_person_time baseline covered           2024  34.782685
#
#                                                                                                                    50%  \
# age             denominator_measure measure    multiplier numerator_measure scenario wasting_treatment year
# 1-5_months      state_person_time   prevalence 100        state_person_time baseline covered           2024  47.862745
# 12_to_23_months state_person_time   prevalence 100        state_person_time baseline covered           2024  47.881363
# 2_to_4          state_person_time   prevalence 100        state_person_time baseline covered           2024  47.954989
# 6-11_months     state_person_time   prevalence 100        state_person_time baseline covered           2024  47.845968
# early_neonatal  state_person_time   prevalence 100        state_person_time baseline covered           2024  47.922421
# late_neonatal   state_person_time   prevalence 100        state_person_time baseline covered           2024  47.884778
#
#                                                                                                                  97.5%  \
# age             denominator_measure measure    multiplier numerator_measure scenario wasting_treatment year
# 1-5_months      state_person_time   prevalence 100        state_person_time baseline covered           2024  56.536725
# 12_to_23_months state_person_time   prevalence 100        state_person_time baseline covered           2024  56.617093
# 2_to_4          state_person_time   prevalence 100        state_person_time baseline covered           2024  56.694274
# 6-11_months     state_person_time   prevalence 100        state_person_time baseline covered           2024  56.501766
# early_neonatal  state_person_time   prevalence 100        state_person_time baseline covered           2024  56.566027
# late_neonatal   state_person_time   prevalence 100        state_person_time baseline covered           2024  56.564897
#
#                                                                                                                    max
# age             denominator_measure measure    multiplier numerator_measure scenario wasting_treatment year
# 1-5_months      state_person_time   prevalence 100        state_person_time baseline covered           2024  57.851824
# 12_to_23_months state_person_time   prevalence 100        state_person_time baseline covered           2024  57.918783
# 2_to_4          state_person_time   prevalence 100        state_person_time baseline covered           2024  57.989693
# 6-11_months     state_person_time   prevalence 100        state_person_time baseline covered           2024  57.786717
# early_neonatal  state_person_time   prevalence 100        state_person_time baseline covered           2024  57.902412
# late_neonatal   state_person_time   prevalence 100        state_person_time baseline covered           2024  57.898052

# %%
vp.describe(
    percent_treated_by_age_year.query(
        "wasting_treatment=='covered' and scenario=='baseline' and year=='2026'")
)
# Out:
#                                                                                                              count  \
# age             denominator_measure measure    multiplier numerator_measure scenario wasting_treatment year
# 1-5_months      state_person_time   prevalence 100        state_person_time baseline covered           2026   12.0
# 12_to_23_months state_person_time   prevalence 100        state_person_time baseline covered           2026   12.0
# 2_to_4          state_person_time   prevalence 100        state_person_time baseline covered           2026   12.0
# 6-11_months     state_person_time   prevalence 100        state_person_time baseline covered           2026   12.0
# early_neonatal  state_person_time   prevalence 100        state_person_time baseline covered           2026   12.0
# late_neonatal   state_person_time   prevalence 100        state_person_time baseline covered           2026   12.0
#
#                                                                                                                   mean  \
# age             denominator_measure measure    multiplier numerator_measure scenario wasting_treatment year
# 1-5_months      state_person_time   prevalence 100        state_person_time baseline covered           2026  47.354199
# 12_to_23_months state_person_time   prevalence 100        state_person_time baseline covered           2026  47.316229
# 2_to_4          state_person_time   prevalence 100        state_person_time baseline covered           2026  47.323335
# 6-11_months     state_person_time   prevalence 100        state_person_time baseline covered           2026  47.350260
# early_neonatal  state_person_time   prevalence 100        state_person_time baseline covered           2026  47.322615
# late_neonatal   state_person_time   prevalence 100        state_person_time baseline covered           2026  47.330772
#
#                                                                                                                   std  \
# age             denominator_measure measure    multiplier numerator_measure scenario wasting_treatment year
# 1-5_months      state_person_time   prevalence 100        state_person_time baseline covered           2026  6.579218
# 12_to_23_months state_person_time   prevalence 100        state_person_time baseline covered           2026  6.579269
# 2_to_4          state_person_time   prevalence 100        state_person_time baseline covered           2026  6.593295
# 6-11_months     state_person_time   prevalence 100        state_person_time baseline covered           2026  6.577052
# early_neonatal  state_person_time   prevalence 100        state_person_time baseline covered           2026  6.582387
# late_neonatal   state_person_time   prevalence 100        state_person_time baseline covered           2026  6.592410
#
#                                                                                                                    min  \
# age             denominator_measure measure    multiplier numerator_measure scenario wasting_treatment year
# 1-5_months      state_person_time   prevalence 100        state_person_time baseline covered           2026  32.979679
# 12_to_23_months state_person_time   prevalence 100        state_person_time baseline covered           2026  32.957140
# 2_to_4          state_person_time   prevalence 100        state_person_time baseline covered           2026  33.001421
# 6-11_months     state_person_time   prevalence 100        state_person_time baseline covered           2026  32.946590
# early_neonatal  state_person_time   prevalence 100        state_person_time baseline covered           2026  33.028717
# late_neonatal   state_person_time   prevalence 100        state_person_time baseline covered           2026  32.978803
#
#                                                                                                                   2.5%  \
# age             denominator_measure measure    multiplier numerator_measure scenario wasting_treatment year
# 1-5_months      state_person_time   prevalence 100        state_person_time baseline covered           2026  34.783360
# 12_to_23_months state_person_time   prevalence 100        state_person_time baseline covered           2026  34.774537
# 2_to_4          state_person_time   prevalence 100        state_person_time baseline covered           2026  34.787239
# 6-11_months     state_person_time   prevalence 100        state_person_time baseline covered           2026  34.764721
# early_neonatal  state_person_time   prevalence 100        state_person_time baseline covered           2026  34.813002
# late_neonatal   state_person_time   prevalence 100        state_person_time baseline covered           2026  34.776577
#
#                                                                                                                    50%  \
# age             denominator_measure measure    multiplier numerator_measure scenario wasting_treatment year
# 1-5_months      state_person_time   prevalence 100        state_person_time baseline covered           2026  47.859119
# 12_to_23_months state_person_time   prevalence 100        state_person_time baseline covered           2026  47.911036
# 2_to_4          state_person_time   prevalence 100        state_person_time baseline covered           2026  47.930804
# 6-11_months     state_person_time   prevalence 100        state_person_time baseline covered           2026  47.886580
# early_neonatal  state_person_time   prevalence 100        state_person_time baseline covered           2026  47.852554
# late_neonatal   state_person_time   prevalence 100        state_person_time baseline covered           2026  47.861575
#
#                                                                                                                  97.5%  \
# age             denominator_measure measure    multiplier numerator_measure scenario wasting_treatment year
# 1-5_months      state_person_time   prevalence 100        state_person_time baseline covered           2026  56.580491
# 12_to_23_months state_person_time   prevalence 100        state_person_time baseline covered           2026  56.550947
# 2_to_4          state_person_time   prevalence 100        state_person_time baseline covered           2026  56.612463
# 6-11_months     state_person_time   prevalence 100        state_person_time baseline covered           2026  56.537189
# early_neonatal  state_person_time   prevalence 100        state_person_time baseline covered           2026  56.619142
# late_neonatal   state_person_time   prevalence 100        state_person_time baseline covered           2026  56.606226
#
#                                                                                                                    max
# age             denominator_measure measure    multiplier numerator_measure scenario wasting_treatment year
# 1-5_months      state_person_time   prevalence 100        state_person_time baseline covered           2026  57.917357
# 12_to_23_months state_person_time   prevalence 100        state_person_time baseline covered           2026  57.903868
# 2_to_4          state_person_time   prevalence 100        state_person_time baseline covered           2026  57.908078
# 6-11_months     state_person_time   prevalence 100        state_person_time baseline covered           2026  57.837070
# early_neonatal  state_person_time   prevalence 100        state_person_time baseline covered           2026  57.970515
# late_neonatal   state_person_time   prevalence 100        state_person_time baseline covered           2026  57.955559

# %%
.488*.731
# Out:
# 0.356728

# %% [markdown]
# # Check the value of intervention coverage
#
# It should be 90% with no unceratinty. Looks good.

# %%
vp.describe(
    percent_treated_by_age_year.query(
        "wasting_treatment=='covered' and scenario=='wasting_treatment' and year=='2024'")
)
# Out:
#                                                                                                                       count  \
# age             denominator_measure measure    multiplier numerator_measure scenario          wasting_treatment year
# 1-5_months      state_person_time   prevalence 100        state_person_time wasting_treatment covered           2024   12.0
# 12_to_23_months state_person_time   prevalence 100        state_person_time wasting_treatment covered           2024   12.0
# 2_to_4          state_person_time   prevalence 100        state_person_time wasting_treatment covered           2024   12.0
# 6-11_months     state_person_time   prevalence 100        state_person_time wasting_treatment covered           2024   12.0
# early_neonatal  state_person_time   prevalence 100        state_person_time wasting_treatment covered           2024   12.0
# late_neonatal   state_person_time   prevalence 100        state_person_time wasting_treatment covered           2024   12.0
#
#                                                                                                                            mean  \
# age             denominator_measure measure    multiplier numerator_measure scenario          wasting_treatment year
# 1-5_months      state_person_time   prevalence 100        state_person_time wasting_treatment covered           2024  90.017460
# 12_to_23_months state_person_time   prevalence 100        state_person_time wasting_treatment covered           2024  89.997723
# 2_to_4          state_person_time   prevalence 100        state_person_time wasting_treatment covered           2024  89.992113
# 6-11_months     state_person_time   prevalence 100        state_person_time wasting_treatment covered           2024  90.014851
# early_neonatal  state_person_time   prevalence 100        state_person_time wasting_treatment covered           2024  90.009984
# late_neonatal   state_person_time   prevalence 100        state_person_time wasting_treatment covered           2024  90.012468
#
#                                                                                                                            std  \
# age             denominator_measure measure    multiplier numerator_measure scenario          wasting_treatment year
# 1-5_months      state_person_time   prevalence 100        state_person_time wasting_treatment covered           2024  0.043066
# 12_to_23_months state_person_time   prevalence 100        state_person_time wasting_treatment covered           2024  0.047345
# 2_to_4          state_person_time   prevalence 100        state_person_time wasting_treatment covered           2024  0.029645
# 6-11_months     state_person_time   prevalence 100        state_person_time wasting_treatment covered           2024  0.067410
# early_neonatal  state_person_time   prevalence 100        state_person_time wasting_treatment covered           2024  0.063532
# late_neonatal   state_person_time   prevalence 100        state_person_time wasting_treatment covered           2024  0.064172
#
#                                                                                                                             min  \
# age             denominator_measure measure    multiplier numerator_measure scenario          wasting_treatment year
# 1-5_months      state_person_time   prevalence 100        state_person_time wasting_treatment covered           2024  89.946129
# 12_to_23_months state_person_time   prevalence 100        state_person_time wasting_treatment covered           2024  89.931605
# 2_to_4          state_person_time   prevalence 100        state_person_time wasting_treatment covered           2024  89.958113
# 6-11_months     state_person_time   prevalence 100        state_person_time wasting_treatment covered           2024  89.882588
# early_neonatal  state_person_time   prevalence 100        state_person_time wasting_treatment covered           2024  89.891898
# late_neonatal   state_person_time   prevalence 100        state_person_time wasting_treatment covered           2024  89.894955
#
#                                                                                                                            2.5%  \
# age             denominator_measure measure    multiplier numerator_measure scenario          wasting_treatment year
# 1-5_months      state_person_time   prevalence 100        state_person_time wasting_treatment covered           2024  89.949325
# 12_to_23_months state_person_time   prevalence 100        state_person_time wasting_treatment covered           2024  89.935238
# 2_to_4          state_person_time   prevalence 100        state_person_time wasting_treatment covered           2024  89.958209
# 6-11_months     state_person_time   prevalence 100        state_person_time wasting_treatment covered           2024  89.899379
# early_neonatal  state_person_time   prevalence 100        state_person_time wasting_treatment covered           2024  89.904902
# late_neonatal   state_person_time   prevalence 100        state_person_time wasting_treatment covered           2024  89.904210
#
#                                                                                                                             50%  \
# age             denominator_measure measure    multiplier numerator_measure scenario          wasting_treatment year
# 1-5_months      state_person_time   prevalence 100        state_person_time wasting_treatment covered           2024  90.028527
# 12_to_23_months state_person_time   prevalence 100        state_person_time wasting_treatment covered           2024  89.992066
# 2_to_4          state_person_time   prevalence 100        state_person_time wasting_treatment covered           2024  89.986864
# 6-11_months     state_person_time   prevalence 100        state_person_time wasting_treatment covered           2024  90.017433
# early_neonatal  state_person_time   prevalence 100        state_person_time wasting_treatment covered           2024  90.013537
# late_neonatal   state_person_time   prevalence 100        state_person_time wasting_treatment covered           2024  90.014473
#
#                                                                                                                           97.5%  \
# age             denominator_measure measure    multiplier numerator_measure scenario          wasting_treatment year
# 1-5_months      state_person_time   prevalence 100        state_person_time wasting_treatment covered           2024  90.074445
# 12_to_23_months state_person_time   prevalence 100        state_person_time wasting_treatment covered           2024  90.071878
# 2_to_4          state_person_time   prevalence 100        state_person_time wasting_treatment covered           2024  90.041911
# 6-11_months     state_person_time   prevalence 100        state_person_time wasting_treatment covered           2024  90.108643
# early_neonatal  state_person_time   prevalence 100        state_person_time wasting_treatment covered           2024  90.100394
# late_neonatal   state_person_time   prevalence 100        state_person_time wasting_treatment covered           2024  90.109030
#
#                                                                                                                             max
# age             denominator_measure measure    multiplier numerator_measure scenario          wasting_treatment year
# 1-5_months      state_person_time   prevalence 100        state_person_time wasting_treatment covered           2024  90.076995
# 12_to_23_months state_person_time   prevalence 100        state_person_time wasting_treatment covered           2024  90.080632
# 2_to_4          state_person_time   prevalence 100        state_person_time wasting_treatment covered           2024  90.046896
# 6-11_months     state_person_time   prevalence 100        state_person_time wasting_treatment covered           2024  90.115339
# early_neonatal  state_person_time   prevalence 100        state_person_time wasting_treatment covered           2024  90.100937
# late_neonatal   state_person_time   prevalence 100        state_person_time wasting_treatment covered           2024  90.110991

# %%
vp.describe(
    percent_treated_by_age_year.query(
        "wasting_treatment=='covered' and scenario=='sqlns' and year=='2024'")
)
# Out:
#                                                                                                              count  \
# age             denominator_measure measure    multiplier numerator_measure scenario wasting_treatment year
# 1-5_months      state_person_time   prevalence 100        state_person_time sqlns    covered           2024   12.0
# 12_to_23_months state_person_time   prevalence 100        state_person_time sqlns    covered           2024   12.0
# 2_to_4          state_person_time   prevalence 100        state_person_time sqlns    covered           2024   12.0
# 6-11_months     state_person_time   prevalence 100        state_person_time sqlns    covered           2024   12.0
# early_neonatal  state_person_time   prevalence 100        state_person_time sqlns    covered           2024   12.0
# late_neonatal   state_person_time   prevalence 100        state_person_time sqlns    covered           2024   12.0
#
#                                                                                                                   mean  \
# age             denominator_measure measure    multiplier numerator_measure scenario wasting_treatment year
# 1-5_months      state_person_time   prevalence 100        state_person_time sqlns    covered           2024  90.017460
# 12_to_23_months state_person_time   prevalence 100        state_person_time sqlns    covered           2024  89.997462
# 2_to_4          state_person_time   prevalence 100        state_person_time sqlns    covered           2024  89.991973
# 6-11_months     state_person_time   prevalence 100        state_person_time sqlns    covered           2024  90.014843
# early_neonatal  state_person_time   prevalence 100        state_person_time sqlns    covered           2024  90.009984
# late_neonatal   state_person_time   prevalence 100        state_person_time sqlns    covered           2024  90.012468
#
#                                                                                                                   std  \
# age             denominator_measure measure    multiplier numerator_measure scenario wasting_treatment year
# 1-5_months      state_person_time   prevalence 100        state_person_time sqlns    covered           2024  0.043066
# 12_to_23_months state_person_time   prevalence 100        state_person_time sqlns    covered           2024  0.046934
# 2_to_4          state_person_time   prevalence 100        state_person_time sqlns    covered           2024  0.029565
# 6-11_months     state_person_time   prevalence 100        state_person_time sqlns    covered           2024  0.067343
# early_neonatal  state_person_time   prevalence 100        state_person_time sqlns    covered           2024  0.063532
# late_neonatal   state_person_time   prevalence 100        state_person_time sqlns    covered           2024  0.064172
#
#                                                                                                                    min  \
# age             denominator_measure measure    multiplier numerator_measure scenario wasting_treatment year
# 1-5_months      state_person_time   prevalence 100        state_person_time sqlns    covered           2024  89.946129
# 12_to_23_months state_person_time   prevalence 100        state_person_time sqlns    covered           2024  89.931088
# 2_to_4          state_person_time   prevalence 100        state_person_time sqlns    covered           2024  89.958204
# 6-11_months     state_person_time   prevalence 100        state_person_time sqlns    covered           2024  89.882378
# early_neonatal  state_person_time   prevalence 100        state_person_time sqlns    covered           2024  89.891898
# late_neonatal   state_person_time   prevalence 100        state_person_time sqlns    covered           2024  89.894955
#
#                                                                                                                   2.5%  \
# age             denominator_measure measure    multiplier numerator_measure scenario wasting_treatment year
# 1-5_months      state_person_time   prevalence 100        state_person_time sqlns    covered           2024  89.949325
# 12_to_23_months state_person_time   prevalence 100        state_person_time sqlns    covered           2024  89.934890
# 2_to_4          state_person_time   prevalence 100        state_person_time sqlns    covered           2024  89.958377
# 6-11_months     state_person_time   prevalence 100        state_person_time sqlns    covered           2024  89.899233
# early_neonatal  state_person_time   prevalence 100        state_person_time sqlns    covered           2024  89.904902
# late_neonatal   state_person_time   prevalence 100        state_person_time sqlns    covered           2024  89.904210
#
#                                                                                                                    50%  \
# age             denominator_measure measure    multiplier numerator_measure scenario wasting_treatment year
# 1-5_months      state_person_time   prevalence 100        state_person_time sqlns    covered           2024  90.028527
# 12_to_23_months state_person_time   prevalence 100        state_person_time sqlns    covered           2024  89.992219
# 2_to_4          state_person_time   prevalence 100        state_person_time sqlns    covered           2024  89.986271
# 6-11_months     state_person_time   prevalence 100        state_person_time sqlns    covered           2024  90.017467
# early_neonatal  state_person_time   prevalence 100        state_person_time sqlns    covered           2024  90.013537
# late_neonatal   state_person_time   prevalence 100        state_person_time sqlns    covered           2024  90.014473
#
#                                                                                                                  97.5%  \
# age             denominator_measure measure    multiplier numerator_measure scenario wasting_treatment year
# 1-5_months      state_person_time   prevalence 100        state_person_time sqlns    covered           2024  90.074445
# 12_to_23_months state_person_time   prevalence 100        state_person_time sqlns    covered           2024  90.070061
# 2_to_4          state_person_time   prevalence 100        state_person_time sqlns    covered           2024  90.041456
# 6-11_months     state_person_time   prevalence 100        state_person_time sqlns    covered           2024  90.108817
# early_neonatal  state_person_time   prevalence 100        state_person_time sqlns    covered           2024  90.100394
# late_neonatal   state_person_time   prevalence 100        state_person_time sqlns    covered           2024  90.109030
#
#                                                                                                                    max
# age             denominator_measure measure    multiplier numerator_measure scenario wasting_treatment year
# 1-5_months      state_person_time   prevalence 100        state_person_time sqlns    covered           2024  90.076995
# 12_to_23_months state_person_time   prevalence 100        state_person_time sqlns    covered           2024  90.078322
# 2_to_4          state_person_time   prevalence 100        state_person_time sqlns    covered           2024  90.046097
# 6-11_months     state_person_time   prevalence 100        state_person_time sqlns    covered           2024  90.115611
# early_neonatal  state_person_time   prevalence 100        state_person_time sqlns    covered           2024  90.100937
# late_neonatal   state_person_time   prevalence 100        state_person_time sqlns    covered           2024  90.110991

# %% [markdown]
# # Compute percent of SAM treated, stratified by wasting state
#
# Coverage is the same for all wasting states.

# %%
percent_sam_treated_by_year_wasting_state = csr.get_prevalence(
    results,
    'sam_treatment',
    strata=['year', 'wasting_state'],
    multiplier=100
)
percent_sam_treated_by_year_wasting_state
# Out:
#       year                 wasting_state  input_draw           scenario  \
# 0     2022            mild_child_wasting          29           baseline
# 1     2022            mild_child_wasting          29           baseline
# 2     2022            mild_child_wasting          29              sqlns
# 3     2022            mild_child_wasting          29              sqlns
# ...    ...                           ...         ...                ...
# 1436  2026  susceptible_to_child_wasting         946              sqlns
# 1437  2026  susceptible_to_child_wasting         946              sqlns
# 1438  2026  susceptible_to_child_wasting         946  wasting_treatment
# 1439  2026  susceptible_to_child_wasting         946  wasting_treatment
#
#      sam_treatment      value  numerator_measure denominator_measure  \
# 0          covered  49.617760  state_person_time   state_person_time
# 1        uncovered  50.382240  state_person_time   state_person_time
# 2          covered  49.617760  state_person_time   state_person_time
# 3        uncovered  50.382240  state_person_time   state_person_time
# ...            ...        ...                ...                 ...
# 1436       covered  69.995051  state_person_time   state_person_time
# 1437     uncovered  30.004949  state_person_time   state_person_time
# 1438       covered  69.995778  state_person_time   state_person_time
# 1439     uncovered  30.004222  state_person_time   state_person_time
#
#       multiplier     measure
# 0            100  prevalence
# 1            100  prevalence
# 2            100  prevalence
# 3            100  prevalence
# ...          ...         ...
# 1436         100  prevalence
# 1437         100  prevalence
# 1438         100  prevalence
# 1439         100  prevalence
#
# [1440 rows x 10 columns]

# %%
fig = csp.plot_over_time_by_column_for_each_scenario(
    percent_sam_treated_by_year_wasting_state.query("sam_treatment=='covered'"),
    colname='wasting_state',
    ylabel='prevalence (%)',
    suptitle='Percent treated SAM among all ages, by wasting state',
    uncertainty=True
)

# %% [markdown]
# # Compute percent of MAM treated, stratified by wasting state
#
# Coverage is the same for all wasting states.

# %%
percent_mam_treated_by_year_wasting_state = csr.get_prevalence(
    results,
    'mam_treatment',
    strata=['year', 'wasting_state'],
    multiplier=100
)
percent_mam_treated_by_year_wasting_state
# Out:
#       year                 wasting_state  input_draw           scenario  \
# 0     2022            mild_child_wasting          29           baseline
# 1     2022            mild_child_wasting          29           baseline
# 2     2022            mild_child_wasting          29              sqlns
# 3     2022            mild_child_wasting          29              sqlns
# ...    ...                           ...         ...                ...
# 1436  2026  susceptible_to_child_wasting         946              sqlns
# 1437  2026  susceptible_to_child_wasting         946              sqlns
# 1438  2026  susceptible_to_child_wasting         946  wasting_treatment
# 1439  2026  susceptible_to_child_wasting         946  wasting_treatment
#
#      mam_treatment      value  numerator_measure denominator_measure  \
# 0          covered  15.370043  state_person_time   state_person_time
# 1        uncovered  84.629957  state_person_time   state_person_time
# 2          covered  15.370043  state_person_time   state_person_time
# 3        uncovered  84.629957  state_person_time   state_person_time
# ...            ...        ...                ...                 ...
# 1436       covered  69.984253  state_person_time   state_person_time
# 1437     uncovered  30.015747  state_person_time   state_person_time
# 1438       covered  69.985817  state_person_time   state_person_time
# 1439     uncovered  30.014183  state_person_time   state_person_time
#
#       multiplier     measure
# 0            100  prevalence
# 1            100  prevalence
# 2            100  prevalence
# 3            100  prevalence
# ...          ...         ...
# 1436         100  prevalence
# 1437         100  prevalence
# 1438         100  prevalence
# 1439         100  prevalence
#
# [1440 rows x 10 columns]

# %%
fig = csp.plot_over_time_by_column_for_each_scenario(
    percent_mam_treated_by_year_wasting_state.query("mam_treatment=='covered'"),
    colname='wasting_state',
    ylabel='prevalence (%)',
    suptitle='Percent treated MAM among all ages, by wasting state',
    uncertainty=True
)

# %% [markdown]
# # Compute percent SAM treated by age and wasting state
#
# The patterns seem to make sense:
#
# - Before 6 months, there are no transitions between wasting states, and coverage is constant across states.
#
# - After 6 months, coverage decreases in the SAM and MAM states, and increases in the MILD and TMREL states because covered simulants are actively moved out of SAM and MAM into MILD and TMREL.

# %%
percent_sam_treated_by_year_age_wasting_state = csr.get_prevalence(
    results,
    'sam_treatment',
    strata=['year', 'age', 'wasting_state'],
    multiplier=100
)
percent_sam_treated_by_year_age_wasting_state
# Out:
#       year            age                 wasting_state  input_draw  \
# 0     2022     1-5_months            mild_child_wasting          29
# 1     2022     1-5_months            mild_child_wasting          29
# 2     2022     1-5_months            mild_child_wasting          29
# 3     2022     1-5_months            mild_child_wasting          29
# ...    ...            ...                           ...         ...
# 8636  2026  late_neonatal  susceptible_to_child_wasting         946
# 8637  2026  late_neonatal  susceptible_to_child_wasting         946
# 8638  2026  late_neonatal  susceptible_to_child_wasting         946
# 8639  2026  late_neonatal  susceptible_to_child_wasting         946
#
#                scenario sam_treatment      value  numerator_measure  \
# 0              baseline       covered  49.661647  state_person_time
# 1              baseline     uncovered  50.338353  state_person_time
# 2                 sqlns       covered  49.661647  state_person_time
# 3                 sqlns     uncovered  50.338353  state_person_time
# ...                 ...           ...        ...                ...
# 8636              sqlns       covered  70.113284  state_person_time
# 8637              sqlns     uncovered  29.886716  state_person_time
# 8638  wasting_treatment       covered  70.113284  state_person_time
# 8639  wasting_treatment     uncovered  29.886716  state_person_time
#
#      denominator_measure  multiplier     measure
# 0      state_person_time         100  prevalence
# 1      state_person_time         100  prevalence
# 2      state_person_time         100  prevalence
# 3      state_person_time         100  prevalence
# ...                  ...         ...         ...
# 8636   state_person_time         100  prevalence
# 8637   state_person_time         100  prevalence
# 8638   state_person_time         100  prevalence
# 8639   state_person_time         100  prevalence
#
# [8640 rows x 11 columns]

# %%
percent_sam_treated_by_year_age_wasting_state.age.unique()
# Out:
# array(['1-5_months', '12_to_23_months', '2_to_4', '6-11_months',
#        'early_neonatal', 'late_neonatal'], dtype=object)

# %%
csr.get_age_group_bins('all_ages')
# Out:
# (['early_neonatal', 'late_neonatal', '1-5_months', '6-11_months', '12_to_23_months', '2_to_4']
#  Categories (7, object): ['early_neonatal' < 'late_neonatal' < '1-5_months' < '6-11_months' < '12_to_23_months' < '2_to_4' < 'all_ages'],
#  ['all_ages']
#  Categories (7, object): ['early_neonatal' < 'late_neonatal' < '1-5_months' < '6-11_months' < '12_to_23_months' < '2_to_4' < 'all_ages'])

# %%
for age in csr.get_age_group_bins('all_ages')[0]:
    title = f'Percent treated SAM among age group {age}, by wasting state'
    fig = csp.plot_over_time_by_column_for_each_scenario(
        percent_sam_treated_by_year_age_wasting_state.query(
            f"sam_treatment=='covered' and age=={age!r}"),
        colname='wasting_state',
        ylabel='prevalence (%)',
        suptitle=title,
        uncertainty=True
    )
    figs[title]=fig

# %% [markdown]
# # Compute percent MAM treated by age and wasting state
#
# The patterns seem to make sense:
#
# - Before 6 months, there are no transitions between wasting states, and coverage is constant across states.
#
# - After 6 months, coverage decreases in the SAM and MAM states, and increases in the MILD and TMREL states because covered simulants are actively moved out of SAM and MAM into MILD and TMREL.

# %%
percent_mam_treated_by_year_age_wasting_state = csr.get_prevalence(
    results,
    'mam_treatment',
    strata=['year', 'age', 'wasting_state'],
    multiplier=100
)
percent_mam_treated_by_year_age_wasting_state
# Out:
#       year            age                 wasting_state  input_draw  \
# 0     2022     1-5_months            mild_child_wasting          29
# 1     2022     1-5_months            mild_child_wasting          29
# 2     2022     1-5_months            mild_child_wasting          29
# 3     2022     1-5_months            mild_child_wasting          29
# ...    ...            ...                           ...         ...
# 8636  2026  late_neonatal  susceptible_to_child_wasting         946
# 8637  2026  late_neonatal  susceptible_to_child_wasting         946
# 8638  2026  late_neonatal  susceptible_to_child_wasting         946
# 8639  2026  late_neonatal  susceptible_to_child_wasting         946
#
#                scenario mam_treatment      value  numerator_measure  \
# 0              baseline       covered  15.406215  state_person_time
# 1              baseline     uncovered  84.593785  state_person_time
# 2                 sqlns       covered  15.406215  state_person_time
# 3                 sqlns     uncovered  84.593785  state_person_time
# ...                 ...           ...        ...                ...
# 8636              sqlns       covered  69.951617  state_person_time
# 8637              sqlns     uncovered  30.048383  state_person_time
# 8638  wasting_treatment       covered  69.951617  state_person_time
# 8639  wasting_treatment     uncovered  30.048383  state_person_time
#
#      denominator_measure  multiplier     measure
# 0      state_person_time         100  prevalence
# 1      state_person_time         100  prevalence
# 2      state_person_time         100  prevalence
# 3      state_person_time         100  prevalence
# ...                  ...         ...         ...
# 8636   state_person_time         100  prevalence
# 8637   state_person_time         100  prevalence
# 8638   state_person_time         100  prevalence
# 8639   state_person_time         100  prevalence
#
# [8640 rows x 11 columns]

# %%
percent_mam_treated_by_year_age_wasting_state.age.unique()
# Out:
# array(['1-5_months', '12_to_23_months', '2_to_4', '6-11_months',
#        'early_neonatal', 'late_neonatal'], dtype=object)

# %%
csr.get_age_group_bins('all_ages')
# Out:
# (['early_neonatal', 'late_neonatal', '1-5_months', '6-11_months', '12_to_23_months', '2_to_4']
#  Categories (7, object): ['early_neonatal' < 'late_neonatal' < '1-5_months' < '6-11_months' < '12_to_23_months' < '2_to_4' < 'all_ages'],
#  ['all_ages']
#  Categories (7, object): ['early_neonatal' < 'late_neonatal' < '1-5_months' < '6-11_months' < '12_to_23_months' < '2_to_4' < 'all_ages'])

# %%
for age in csr.get_age_group_bins('all_ages')[0]:
    title = f'Percent treated MAM among age group {age}, by wasting state'
    fig = csp.plot_over_time_by_column_for_each_scenario(
        percent_mam_treated_by_year_age_wasting_state.query(
            f"mam_treatment=='covered' and age=={age!r}"),
        colname='wasting_state',
        ylabel='prevalence (%)',
        suptitle=title,
        uncertainty=True
    )
    figs[title]=fig

# %%
figs.keys()
# Out:
# dict_keys(['Percent treated SAM among age group early_neonatal, by wasting state', 'Percent treated SAM among age group late_neonatal, by wasting state', 'Percent treated SAM among age group 1-5_months, by wasting state', 'Percent treated SAM among age group 6-11_months, by wasting state', 'Percent treated SAM among age group 12_to_23_months, by wasting state', 'Percent treated SAM among age group 2_to_4, by wasting state', 'Percent treated MAM among age group early_neonatal, by wasting state', 'Percent treated MAM among age group late_neonatal, by wasting state', 'Percent treated MAM among age group 1-5_months, by wasting state', 'Percent treated MAM among age group 6-11_months, by wasting state', 'Percent treated MAM among age group 12_to_23_months, by wasting state', 'Percent treated MAM among age group 2_to_4, by wasting state'])

# %% [markdown]
# # Check coverage values in intervention scenarios
#
# It seems strange that all the values look lower than 90%, but actually MILD and TMREL are slightly above 90%, so it must be that the prevalence of MAM and SAM is very small, and the prevalence-weighted average comes out to 90%. Let's double-check.

# %%
vp.describe(
    percent_treated_by_year_age_wasting_state.query(
        "scenario=='wasting_treatment' and wasting_treatment=='covered' and year=='2026' and age=='2_to_4'"
    )
)
# Out:
#                                                                                                                                           count  \
# age    denominator_measure measure    multiplier numerator_measure scenario          wasting_state                wasting_treatment year
# 2_to_4 state_person_time   prevalence 100        state_person_time wasting_treatment mild_child_wasting           covered           2026   12.0
#                                                                                      moderate_acute_malnutrition  covered           2026   12.0
#                                                                                      severe_acute_malnutrition    covered           2026   12.0
#                                                                                      susceptible_to_child_wasting covered           2026   12.0
#
#                                                                                                                                                mean  \
# age    denominator_measure measure    multiplier numerator_measure scenario          wasting_state                wasting_treatment year
# 2_to_4 state_person_time   prevalence 100        state_person_time wasting_treatment mild_child_wasting           covered           2026  90.612123
#                                                                                      moderate_acute_malnutrition  covered           2026  85.985717
#                                                                                      severe_acute_malnutrition    covered           2026  84.336686
#                                                                                      susceptible_to_child_wasting covered           2026  90.248721
#
#                                                                                                                                                std  \
# age    denominator_measure measure    multiplier numerator_measure scenario          wasting_state                wasting_treatment year
# 2_to_4 state_person_time   prevalence 100        state_person_time wasting_treatment mild_child_wasting           covered           2026  0.057427
#                                                                                      moderate_acute_malnutrition  covered           2026  0.078637
#                                                                                      severe_acute_malnutrition    covered           2026  1.725048
#                                                                                      susceptible_to_child_wasting covered           2026  0.045988
#
#                                                                                                                                                 min  \
# age    denominator_measure measure    multiplier numerator_measure scenario          wasting_state                wasting_treatment year
# 2_to_4 state_person_time   prevalence 100        state_person_time wasting_treatment mild_child_wasting           covered           2026  90.532350
#                                                                                      moderate_acute_malnutrition  covered           2026  85.856107
#                                                                                      severe_acute_malnutrition    covered           2026  80.737515
#                                                                                      susceptible_to_child_wasting covered           2026  90.163577
#
#                                                                                                                                                2.5%  \
# age    denominator_measure measure    multiplier numerator_measure scenario          wasting_state                wasting_treatment year
# 2_to_4 state_person_time   prevalence 100        state_person_time wasting_treatment mild_child_wasting           covered           2026  90.533063
#                                                                                      moderate_acute_malnutrition  covered           2026  85.857683
#                                                                                      severe_acute_malnutrition    covered           2026  81.309882
#                                                                                      susceptible_to_child_wasting covered           2026  90.173305
#
#                                                                                                                                                 50%  \
# age    denominator_measure measure    multiplier numerator_measure scenario          wasting_state                wasting_treatment year
# 2_to_4 state_person_time   prevalence 100        state_person_time wasting_treatment mild_child_wasting           covered           2026  90.608873
#                                                                                      moderate_acute_malnutrition  covered           2026  86.008877
#                                                                                      severe_acute_malnutrition    covered           2026  84.575923
#                                                                                      susceptible_to_child_wasting covered           2026  90.248861
#
#                                                                                                                                               97.5%  \
# age    denominator_measure measure    multiplier numerator_measure scenario          wasting_state                wasting_treatment year
# 2_to_4 state_person_time   prevalence 100        state_person_time wasting_treatment mild_child_wasting           covered           2026  90.705708
#                                                                                      moderate_acute_malnutrition  covered           2026  86.093915
#                                                                                      severe_acute_malnutrition    covered           2026  86.690891
#                                                                                      susceptible_to_child_wasting covered           2026  90.318927
#
#                                                                                                                                                 max
# age    denominator_measure measure    multiplier numerator_measure scenario          wasting_state                wasting_treatment year
# 2_to_4 state_person_time   prevalence 100        state_person_time wasting_treatment mild_child_wasting           covered           2026  90.719821
#                                                                                      moderate_acute_malnutrition  covered           2026  86.110255
#                                                                                      severe_acute_malnutrition    covered           2026  86.882054
#                                                                                      susceptible_to_child_wasting covered           2026  90.327429

# %%
vp.describe(
    percent_treated_by_year_age_wasting_state.query(
        "scenario=='sqlns' and wasting_treatment=='covered' and year=='2026' and age=='2_to_4'"
    )
)
# Out:
#                                                                                                                                  count  \
# age    denominator_measure measure    multiplier numerator_measure scenario wasting_state                wasting_treatment year
# 2_to_4 state_person_time   prevalence 100        state_person_time sqlns    mild_child_wasting           covered           2026   12.0
#                                                                             moderate_acute_malnutrition  covered           2026   12.0
#                                                                             severe_acute_malnutrition    covered           2026   12.0
#                                                                             susceptible_to_child_wasting covered           2026   12.0
#
#                                                                                                                                       mean  \
# age    denominator_measure measure    multiplier numerator_measure scenario wasting_state                wasting_treatment year
# 2_to_4 state_person_time   prevalence 100        state_person_time sqlns    mild_child_wasting           covered           2026  90.510716
#                                                                             moderate_acute_malnutrition  covered           2026  85.806176
#                                                                             severe_acute_malnutrition    covered           2026  84.179423
#                                                                             susceptible_to_child_wasting covered           2026  90.227961
#
#                                                                                                                                       std  \
# age    denominator_measure measure    multiplier numerator_measure scenario wasting_state                wasting_treatment year
# 2_to_4 state_person_time   prevalence 100        state_person_time sqlns    mild_child_wasting           covered           2026  0.060516
#                                                                             moderate_acute_malnutrition  covered           2026  0.107547
#                                                                             severe_acute_malnutrition    covered           2026  1.813762
#                                                                             susceptible_to_child_wasting covered           2026  0.042730
#
#                                                                                                                                        min  \
# age    denominator_measure measure    multiplier numerator_measure scenario wasting_state                wasting_treatment year
# 2_to_4 state_person_time   prevalence 100        state_person_time sqlns    mild_child_wasting           covered           2026  90.422287
#                                                                             moderate_acute_malnutrition  covered           2026  85.605064
#                                                                             severe_acute_malnutrition    covered           2026  80.016987
#                                                                             susceptible_to_child_wasting covered           2026  90.137240
#
#                                                                                                                                       2.5%  \
# age    denominator_measure measure    multiplier numerator_measure scenario wasting_state                wasting_treatment year
# 2_to_4 state_person_time   prevalence 100        state_person_time sqlns    mild_child_wasting           covered           2026  90.422431
#                                                                             moderate_acute_malnutrition  covered           2026  85.631495
#                                                                             severe_acute_malnutrition    covered           2026  80.744671
#                                                                             susceptible_to_child_wasting covered           2026  90.150155
#
#                                                                                                                                        50%  \
# age    denominator_measure measure    multiplier numerator_measure scenario wasting_state                wasting_treatment year
# 2_to_4 state_person_time   prevalence 100        state_person_time sqlns    mild_child_wasting           covered           2026  90.507826
#                                                                             moderate_acute_malnutrition  covered           2026  85.812208
#                                                                             severe_acute_malnutrition    covered           2026  84.665656
#                                                                             susceptible_to_child_wasting covered           2026  90.233709
#
#                                                                                                                                      97.5%  \
# age    denominator_measure measure    multiplier numerator_measure scenario wasting_state                wasting_treatment year
# 2_to_4 state_person_time   prevalence 100        state_person_time sqlns    mild_child_wasting           covered           2026  90.601902
#                                                                             moderate_acute_malnutrition  covered           2026  85.973908
#                                                                             severe_acute_malnutrition    covered           2026  86.373154
#                                                                             susceptible_to_child_wasting covered           2026  90.282746
#
#                                                                                                                                        max
# age    denominator_measure measure    multiplier numerator_measure scenario wasting_state                wasting_treatment year
# 2_to_4 state_person_time   prevalence 100        state_person_time sqlns    mild_child_wasting           covered           2026  90.606275
#                                                                             moderate_acute_malnutrition  covered           2026  85.989786
#                                                                             severe_acute_malnutrition    covered           2026  86.554601
#                                                                             susceptible_to_child_wasting covered           2026  90.284361

# %% [markdown]
# ## Compute prevalence of wasting states

# %%
wasting_state_prevalence_by_year_age = csr.get_prevalence(
    results,
    'wasting_state',
    strata=['year', 'age']
)
wasting_state_prevalence_by_year_age
# Out:
#       year            age  input_draw           scenario  \
# 0     2022     1-5_months          29           baseline
# 1     2022     1-5_months          29           baseline
# 2     2022     1-5_months          29           baseline
# 3     2022     1-5_months          29           baseline
# ...    ...            ...         ...                ...
# 4316  2026  late_neonatal         946  wasting_treatment
# 4317  2026  late_neonatal         946  wasting_treatment
# 4318  2026  late_neonatal         946  wasting_treatment
# 4319  2026  late_neonatal         946  wasting_treatment
#
#                      wasting_state     value  numerator_measure  \
# 0               mild_child_wasting  0.205336  state_person_time
# 1      moderate_acute_malnutrition  0.088382  state_person_time
# 2        severe_acute_malnutrition  0.029572  state_person_time
# 3     susceptible_to_child_wasting  0.676710  state_person_time
# ...                            ...       ...                ...
# 4316            mild_child_wasting  0.200809  state_person_time
# 4317   moderate_acute_malnutrition  0.089108  state_person_time
# 4318     severe_acute_malnutrition  0.032706  state_person_time
# 4319  susceptible_to_child_wasting  0.677378  state_person_time
#
#      denominator_measure  multiplier     measure
# 0      state_person_time           1  prevalence
# 1      state_person_time           1  prevalence
# 2      state_person_time           1  prevalence
# 3      state_person_time           1  prevalence
# ...                  ...         ...         ...
# 4316   state_person_time           1  prevalence
# 4317   state_person_time           1  prevalence
# 4318   state_person_time           1  prevalence
# 4319   state_person_time           1  prevalence
#
# [4320 rows x 10 columns]

# %% [markdown]
# ## Compute prevalence-weighted coverage by wasting state, year, and age

# %%
weighted_coverage_by_year_age_wasting_state = (
    vp.value(wasting_state_prevalence_by_year_age, include=['year', 'age', 'wasting_state'])
    * vp.value(
        percent_treated_by_year_age_wasting_state,
        include=['year', 'age', 'wasting_state', 'wasting_treatment']
    )
)
weighted_coverage_by_year_age_wasting_state
# Out:
#                                                                                                     value
# year age           wasting_state                input_draw scenario          wasting_treatment
# 2022 1-5_months    mild_child_wasting           29         baseline          covered            10.137060
#                                                                              uncovered          10.396514
#                                                            sqlns             covered            10.137060
#                                                                              uncovered          10.396514
# ...                                                                                                   ...
# 2026 late_neonatal susceptible_to_child_wasting 946        sqlns             covered            61.015196
#                                                                              uncovered           6.722556
#                                                            wasting_treatment covered            61.015196
#                                                                              uncovered           6.722556
#
# [8640 rows x 1 columns]

# %% [markdown]
# ## Re-compute coverage by year and age by marginalizing prevalence-weighted coverage over wasting state

# %%
percent_treated_by_age_year2 = vp.marginalize(weighted_coverage_by_year_age_wasting_state, 'wasting_state')
percent_treated_by_age_year2
# Out:
#                 age  input_draw           scenario wasting_treatment  year  \
# 0        1-5_months          29           baseline           covered  2022
# 1        1-5_months          29           baseline           covered  2023
# 2        1-5_months          29           baseline           covered  2024
# 3        1-5_months          29           baseline           covered  2025
# ...             ...         ...                ...               ...   ...
# 2156  late_neonatal         946  wasting_treatment         uncovered  2023
# 2157  late_neonatal         946  wasting_treatment         uncovered  2024
# 2158  late_neonatal         946  wasting_treatment         uncovered  2025
# 2159  late_neonatal         946  wasting_treatment         uncovered  2026
#
#           value
# 0     49.502033
# 1     49.572063
# 2     49.636728
# 3     49.587077
# ...         ...
# 2156   9.927143
# 2157   9.983689
# 2158  10.002482
# 2159  10.008151
#
# [2160 rows x 6 columns]

# %% [markdown]
# ## Check the values in 'sqlns' scenario for year 2026 -- Good, these look the same as the original values we computed before

# %%
vp.describe(
    percent_treated_by_age_year2.query(
        "scenario=='sqlns' and wasting_treatment=='covered' and year=='2026'")
)
# Out:
#                                                  count       mean       std  \
# age             scenario wasting_treatment year
# 1-5_months      sqlns    covered           2026   12.0  89.996902  0.081406
# 12_to_23_months sqlns    covered           2026   12.0  90.007947  0.060248
# 2_to_4          sqlns    covered           2026   12.0  90.001625  0.035309
# 6-11_months     sqlns    covered           2026   12.0  90.000555  0.069366
# early_neonatal  sqlns    covered           2026   12.0  90.000959  0.082249
# late_neonatal   sqlns    covered           2026   12.0  90.003714  0.073166
#
#                                                        min       2.5%  \
# age             scenario wasting_treatment year
# 1-5_months      sqlns    covered           2026  89.822575  89.854715
# 12_to_23_months sqlns    covered           2026  89.919542  89.925503
# 2_to_4          sqlns    covered           2026  89.922641  89.934248
# 6-11_months     sqlns    covered           2026  89.890768  89.903457
# early_neonatal  sqlns    covered           2026  89.891099  89.896385
# late_neonatal   sqlns    covered           2026  89.887522  89.898437
#
#                                                        50%      97.5%  \
# age             scenario wasting_treatment year
# 1-5_months      sqlns    covered           2026  90.000097  90.133806
# 12_to_23_months sqlns    covered           2026  89.995615  90.118232
# 2_to_4          sqlns    covered           2026  90.006670  90.056003
# 6-11_months     sqlns    covered           2026  89.987601  90.117395
# early_neonatal  sqlns    covered           2026  90.000726  90.139377
# late_neonatal   sqlns    covered           2026  89.992527  90.139711
#
#                                                        max
# age             scenario wasting_treatment year
# 1-5_months      sqlns    covered           2026  90.160211
# 12_to_23_months sqlns    covered           2026  90.133376
# 2_to_4          sqlns    covered           2026  90.065549
# 6-11_months     sqlns    covered           2026  90.135015
# early_neonatal  sqlns    covered           2026  90.140786
# late_neonatal   sqlns    covered           2026  90.155567

# %%
vp.describe(
    percent_treated_by_age_year.query(
        "scenario=='sqlns' and wasting_treatment=='covered' and year=='2026'")
)
# Out:
#                                                                                                              count  \
# age             denominator_measure measure    multiplier numerator_measure scenario wasting_treatment year
# 1-5_months      state_person_time   prevalence 100        state_person_time sqlns    covered           2026   12.0
# 12_to_23_months state_person_time   prevalence 100        state_person_time sqlns    covered           2026   12.0
# 2_to_4          state_person_time   prevalence 100        state_person_time sqlns    covered           2026   12.0
# 6-11_months     state_person_time   prevalence 100        state_person_time sqlns    covered           2026   12.0
# early_neonatal  state_person_time   prevalence 100        state_person_time sqlns    covered           2026   12.0
# late_neonatal   state_person_time   prevalence 100        state_person_time sqlns    covered           2026   12.0
#
#                                                                                                                   mean  \
# age             denominator_measure measure    multiplier numerator_measure scenario wasting_treatment year
# 1-5_months      state_person_time   prevalence 100        state_person_time sqlns    covered           2026  89.996902
# 12_to_23_months state_person_time   prevalence 100        state_person_time sqlns    covered           2026  90.007947
# 2_to_4          state_person_time   prevalence 100        state_person_time sqlns    covered           2026  90.001625
# 6-11_months     state_person_time   prevalence 100        state_person_time sqlns    covered           2026  90.000555
# early_neonatal  state_person_time   prevalence 100        state_person_time sqlns    covered           2026  90.000959
# late_neonatal   state_person_time   prevalence 100        state_person_time sqlns    covered           2026  90.003714
#
#                                                                                                                   std  \
# age             denominator_measure measure    multiplier numerator_measure scenario wasting_treatment year
# 1-5_months      state_person_time   prevalence 100        state_person_time sqlns    covered           2026  0.081406
# 12_to_23_months state_person_time   prevalence 100        state_person_time sqlns    covered           2026  0.060248
# 2_to_4          state_person_time   prevalence 100        state_person_time sqlns    covered           2026  0.035309
# 6-11_months     state_person_time   prevalence 100        state_person_time sqlns    covered           2026  0.069366
# early_neonatal  state_person_time   prevalence 100        state_person_time sqlns    covered           2026  0.082249
# late_neonatal   state_person_time   prevalence 100        state_person_time sqlns    covered           2026  0.073166
#
#                                                                                                                    min  \
# age             denominator_measure measure    multiplier numerator_measure scenario wasting_treatment year
# 1-5_months      state_person_time   prevalence 100        state_person_time sqlns    covered           2026  89.822575
# 12_to_23_months state_person_time   prevalence 100        state_person_time sqlns    covered           2026  89.919542
# 2_to_4          state_person_time   prevalence 100        state_person_time sqlns    covered           2026  89.922641
# 6-11_months     state_person_time   prevalence 100        state_person_time sqlns    covered           2026  89.890768
# early_neonatal  state_person_time   prevalence 100        state_person_time sqlns    covered           2026  89.891099
# late_neonatal   state_person_time   prevalence 100        state_person_time sqlns    covered           2026  89.887522
#
#                                                                                                                   2.5%  \
# age             denominator_measure measure    multiplier numerator_measure scenario wasting_treatment year
# 1-5_months      state_person_time   prevalence 100        state_person_time sqlns    covered           2026  89.854715
# 12_to_23_months state_person_time   prevalence 100        state_person_time sqlns    covered           2026  89.925503
# 2_to_4          state_person_time   prevalence 100        state_person_time sqlns    covered           2026  89.934248
# 6-11_months     state_person_time   prevalence 100        state_person_time sqlns    covered           2026  89.903457
# early_neonatal  state_person_time   prevalence 100        state_person_time sqlns    covered           2026  89.896385
# late_neonatal   state_person_time   prevalence 100        state_person_time sqlns    covered           2026  89.898437
#
#                                                                                                                    50%  \
# age             denominator_measure measure    multiplier numerator_measure scenario wasting_treatment year
# 1-5_months      state_person_time   prevalence 100        state_person_time sqlns    covered           2026  90.000097
# 12_to_23_months state_person_time   prevalence 100        state_person_time sqlns    covered           2026  89.995615
# 2_to_4          state_person_time   prevalence 100        state_person_time sqlns    covered           2026  90.006670
# 6-11_months     state_person_time   prevalence 100        state_person_time sqlns    covered           2026  89.987601
# early_neonatal  state_person_time   prevalence 100        state_person_time sqlns    covered           2026  90.000726
# late_neonatal   state_person_time   prevalence 100        state_person_time sqlns    covered           2026  89.992527
#
#                                                                                                                  97.5%  \
# age             denominator_measure measure    multiplier numerator_measure scenario wasting_treatment year
# 1-5_months      state_person_time   prevalence 100        state_person_time sqlns    covered           2026  90.133806
# 12_to_23_months state_person_time   prevalence 100        state_person_time sqlns    covered           2026  90.118232
# 2_to_4          state_person_time   prevalence 100        state_person_time sqlns    covered           2026  90.056003
# 6-11_months     state_person_time   prevalence 100        state_person_time sqlns    covered           2026  90.117395
# early_neonatal  state_person_time   prevalence 100        state_person_time sqlns    covered           2026  90.139377
# late_neonatal   state_person_time   prevalence 100        state_person_time sqlns    covered           2026  90.139711
#
#                                                                                                                    max
# age             denominator_measure measure    multiplier numerator_measure scenario wasting_treatment year
# 1-5_months      state_person_time   prevalence 100        state_person_time sqlns    covered           2026  90.160211
# 12_to_23_months state_person_time   prevalence 100        state_person_time sqlns    covered           2026  90.133376
# 2_to_4          state_person_time   prevalence 100        state_person_time sqlns    covered           2026  90.065549
# 6-11_months     state_person_time   prevalence 100        state_person_time sqlns    covered           2026  90.135015
# early_neonatal  state_person_time   prevalence 100        state_person_time sqlns    covered           2026  90.140786
# late_neonatal   state_person_time   prevalence 100        state_person_time sqlns    covered           2026  90.155567

# %% [markdown]
# ## Compare all the newly computed coverage values to what we got before -- Good, they are equal

# %%
percent_treated_by_age_year
# Out:
#                 age  year  input_draw           scenario wasting_treatment  \
# 0        1-5_months  2022          29           baseline           covered
# 1        1-5_months  2022          29           baseline         uncovered
# 2        1-5_months  2022          29              sqlns           covered
# 3        1-5_months  2022          29              sqlns         uncovered
# ...             ...   ...         ...                ...               ...
# 2156  late_neonatal  2026         946              sqlns           covered
# 2157  late_neonatal  2026         946              sqlns         uncovered
# 2158  late_neonatal  2026         946  wasting_treatment           covered
# 2159  late_neonatal  2026         946  wasting_treatment         uncovered
#
#           value  numerator_measure denominator_measure  multiplier     measure
# 0     49.502033  state_person_time   state_person_time         100  prevalence
# 1     50.497967  state_person_time   state_person_time         100  prevalence
# 2     49.502033  state_person_time   state_person_time         100  prevalence
# 3     50.497967  state_person_time   state_person_time         100  prevalence
# ...         ...                ...                 ...         ...         ...
# 2156  89.991849  state_person_time   state_person_time         100  prevalence
# 2157  10.008151  state_person_time   state_person_time         100  prevalence
# 2158  89.991849  state_person_time   state_person_time         100  prevalence
# 2159  10.008151  state_person_time   state_person_time         100  prevalence
#
# [2160 rows x 10 columns]

# %%
vp.assert_values_equal(
    percent_treated_by_age_year[percent_treated_by_age_year2.columns],
    percent_treated_by_age_year2,
)
