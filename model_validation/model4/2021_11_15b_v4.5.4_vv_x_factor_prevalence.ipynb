# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
pd.set_option('display.max_rows', 8)

from scipy import stats
import collections

import warnings
# warnings.filterwarnings('ignore')
from matplotlib.backends.backend_pdf import PdfPages

from pathlib import Path
import yaml
import re

import db_queries as db
import vivarium_helpers.id_helper as idh
import gbd_mapping
from vivarium import Artifact

# Add the repo directory vivarium_research_ciff_sam/ to sys.path
import os, sys
repo_path = os.path.abspath('../..')
sys.path.append(repo_path)
# Assumes vivarium_research_ciff_sam/ is in sys.path
# import model_validation.vivarium_transformed_output as vto
# import model_validation.vivarium_raw_output as vro
import model_validation.vivarium_output_processing as vp
import model_validation.ciff_sam_results as csr
import model_validation.ciff_sam_plots as csp

# %load_ext autoreload
# %autoreload 2

# !pwd
# !whoami
# !date
# Out:
# /ihme/homes/ndbs/vivarium_research_ciff_sam/model_validation/model4
# ndbs
# Mon Nov 15 18:34:50 PST 2021

# %% [markdown]
# # Changes from 4.5.3 to 4.5.4 (x-factor PAF calculation fix and exposure implementation change):
#
# - mild->TMREL recovery rate updated from 1/27 to 1/75.
# - X-factor exposure refactored to have same propesnity as wasting state initialization propensity and exposure set to 0.32.
# - x-factor effects: i3=1, i2=3.16, i1=3.16.
# - Fix the X-factor PAF calculation bug identified by Rajan in model 4.5.3 (posted in Slack on Thu 11/4):
#   > i'm looking at the code now, and i think i am not calculating the x-factor paf correctly. it's being calculated based on an x-factor exposure of 22.155%, which i think must be an old value. the exposure should be dynamically calculated using wasting exposure and thie configurations for their effect on x-factor

# %% [markdown]
# # Load and clean data
#
# Don't add `x_factor_effect` to index columns this time since it doesn't exist in this run.

# %%
data = csr.VivariumResults.cleaned_from_model_spec('4.5.4')
data.table_names()
# Out:
# ['wasting_transition_count',
#  'wasting_state_person_time',
#  'deaths',
#  'stunting_state_person_time',
#  'population',
#  'ylls',
#  'ylds',
#  'person_time',
#  'cause_state_person_time',
#  'cause_transition_count']

# %%
#vp.set_global_index_columns(vp.INDEX_COLUMNS+['x_factor_effect'])
vp.INDEX_COLUMNS
# Out:
# ['input_draw', 'scenario']

# %% [markdown]
# # Create a dictionary to store figures to save later

# %%
figs = {}

# %%
# !ls /ihme/homes/ndbs/vivarium_results/ciff_malnutrition/verification_and_validation/
# Out:
# v2.1_gbd_2020_wasting	       v2.5_stunting
# v2.3_wasting_birth_prevalence  v4.5.2_x_factor
# v2.4_corrected_fertility       v4.5.3_x_factor_targeted_exposure

# %% [markdown]
# # Compute x-factor prevalence by age group and year

# %%
data.person_time
# Out:
#                  age  input_draw      measure           scenario     sex  \
# 0         1-5_months          29  person_time           baseline  female
# 1         1-5_months          29  person_time           baseline  female
# 2         1-5_months          29  person_time           baseline  female
# 3         1-5_months          29  person_time           baseline  female
# ...              ...         ...          ...                ...     ...
# 17276  late_neonatal         946  person_time  wasting_treatment    male
# 17277  late_neonatal         946  person_time  wasting_treatment    male
# 17278  late_neonatal         946  person_time  wasting_treatment    male
# 17279  late_neonatal         946  person_time  wasting_treatment    male
#
#           sq_lns wasting_treatment x_factor  year      value
# 0        covered           covered     cat1  2022   0.000000
# 1        covered           covered     cat1  2023   0.000000
# 2        covered           covered     cat1  2024   0.000000
# 3        covered           covered     cat1  2025   0.000000
# ...          ...               ...      ...   ...        ...
# 17276  uncovered         uncovered     cat2  2023  41.834360
# 17277  uncovered         uncovered     cat2  2024  40.670773
# 17278  uncovered         uncovered     cat2  2025  42.143737
# 17279  uncovered         uncovered     cat2  2026  42.338125
#
# [17280 rows x 10 columns]

# %%
x_factor_prevalence = csr.get_prevalence(data, 'x_factor', ['age', 'year'], multiplier=100)
x_factor_prevalence
# Out:
#                 age  year  input_draw           scenario x_factor      value  \
# 0        1-5_months  2022          29           baseline     cat1  31.940441
# 1        1-5_months  2022          29           baseline     cat2  68.059559
# 2        1-5_months  2022          29              sqlns     cat1  31.940441
# 3        1-5_months  2022          29              sqlns     cat2  68.059559
# ...             ...   ...         ...                ...      ...        ...
# 2156  late_neonatal  2026         946              sqlns     cat1  32.023779
# 2157  late_neonatal  2026         946              sqlns     cat2  67.976221
# 2158  late_neonatal  2026         946  wasting_treatment     cat1  32.023779
# 2159  late_neonatal  2026         946  wasting_treatment     cat2  67.976221
#
#       numerator_measure denominator_measure  multiplier     measure
# 0     state_person_time   state_person_time         100  prevalence
# 1     state_person_time   state_person_time         100  prevalence
# 2     state_person_time   state_person_time         100  prevalence
# 3     state_person_time   state_person_time         100  prevalence
# ...                 ...                 ...         ...         ...
# 2156  state_person_time   state_person_time         100  prevalence
# 2157  state_person_time   state_person_time         100  prevalence
# 2158  state_person_time   state_person_time         100  prevalence
# 2159  state_person_time   state_person_time         100  prevalence
#
# [2160 rows x 10 columns]

# %%
fig, ax = plt.subplots(figsize=(12,6))
# x_factor_effect=1.1
title = "Mean X-factor prevalence vs. time in baseline scenario, by age group"
csp.plot_over_time_by_column(
    x_factor_prevalence.query(f"scenario=='baseline' and x_factor=='cat1'"),
    'age',
    'X-factor prevalence (%)',
    title,
    False
)
# figs['x_factor_prevalence_by_age_group_in_baseline'] = fig
figs[title] = fig

# %%
fig, ax = plt.subplots(figsize=(12,8))
title = "X-factor prevalence vs. time in baseline scenario, by age group"
csp.plot_over_time_by_column(
    x_factor_prevalence.query("scenario=='baseline' and x_factor=='cat1'"),
    'age',
    'X-factor prevalence (%)',
    title,
    True
)
figs[title] = fig

# %%
fig, ax = plt.subplots(figsize=(12,8))
title = "X-factor prevalence (draws and mean) vs. time in baseline scenario, by age group"
csp.plot_draws_over_time_by_age(
    x_factor_prevalence.query("scenario=='baseline' and x_factor=='cat1'"),
    'X-factor prevalence (%)',
    title,
)
# figs['x_factor_prevalence_draws_by_age_group_in_baseline'] = fig
figs[title] = fig

# %%
# x_factor_effect=1.5
title = "Mean X-factor prevalence vs. time in all scenarios"
fig = csp.plot_over_time_by_column_for_each_scenario(
    x_factor_prevalence.query(f"x_factor=='cat1'"),
    'age',
    ylabel='X-factor prevalence (%)',
    suptitle=title,
    uncertainty=False,
)
# figs['x_factor_prevalence_by_age_group_in_all_scenarios'] = fig
figs[title] = fig

# %% [markdown]
# # Compute X-factor prevalence stratified by year, age, wasting state

# %%
# This computes P(X-factor | year, age, wasting_state)
x_factor_prevalence_by_wasting_state = csr.get_prevalence(
    data, 'x_factor', strata=['year', 'age', 'wasting_state'], multiplier=100
)
x_factor_prevalence_by_wasting_state
# Out:
#       year            age                 wasting_state  input_draw  \
# 0     2022     1-5_months            mild_child_wasting          29
# 1     2022     1-5_months            mild_child_wasting          29
# 2     2022     1-5_months            mild_child_wasting          29
# 3     2022     1-5_months            mild_child_wasting          29
# ...    ...            ...                           ...         ...
# 8636  2026  late_neonatal  susceptible_to_child_wasting         946
# 8637  2026  late_neonatal  susceptible_to_child_wasting         946
# 8638  2026  late_neonatal  susceptible_to_child_wasting         946
# 8639  2026  late_neonatal  susceptible_to_child_wasting         946
#
#                scenario x_factor       value  numerator_measure  \
# 0              baseline     cat1  100.000000  state_person_time
# 1              baseline     cat2    0.000000  state_person_time
# 2                 sqlns     cat1  100.000000  state_person_time
# 3                 sqlns     cat2    0.000000  state_person_time
# ...                 ...      ...         ...                ...
# 8636              sqlns     cat1    1.117293  state_person_time
# 8637              sqlns     cat2   98.882707  state_person_time
# 8638  wasting_treatment     cat1    1.117293  state_person_time
# 8639  wasting_treatment     cat2   98.882707  state_person_time
#
#      denominator_measure  multiplier     measure
# 0      state_person_time         100  prevalence
# 1      state_person_time         100  prevalence
# 2      state_person_time         100  prevalence
# 3      state_person_time         100  prevalence
# ...                  ...         ...         ...
# 8636   state_person_time         100  prevalence
# 8637   state_person_time         100  prevalence
# 8638   state_person_time         100  prevalence
# 8639   state_person_time         100  prevalence
#
# [8640 rows x 11 columns]

# %% [markdown]
# # Plot X-factor prevalence in each wasting state for each age group

# %%
title = "X-factor prevalence vs. time for all scenarios\nstratified by age and wasting state"
fig = csp.plot_over_time_by_column_for_each_wasting_state_and_scenario(
    x_factor_prevalence_by_wasting_state.query("x_factor=='cat1'"),
    colname='age',
    ylabel='X-factor prevalence (%)',
    suptitle=title
)
figs[title] = fig

# %% [markdown]
# # Compute the "reference" joint prevalence of X-factor and wasting state from the wasting state prevalence, based on the X-factor exposure initialization parameters from v4.5.3
#
# X-factor exposure by wasting state, from v4.5.3: sam=0.6, mam=0.5, mild=0.25, tmrel=0.01
#
# We'll look at these to compare with Model 4.5.3.

# %%
wasting_state_prevalence = csr.get_prevalence(
    data, 'wasting_state', ['year', 'age'], multiplier=100,
)
wasting_state_prevalence
# Out:
#       year            age  input_draw           scenario  \
# 0     2022     1-5_months          29           baseline
# 1     2022     1-5_months          29           baseline
# 2     2022     1-5_months          29           baseline
# 3     2022     1-5_months          29           baseline
# ...    ...            ...         ...                ...
# 4316  2026  late_neonatal         946  wasting_treatment
# 4317  2026  late_neonatal         946  wasting_treatment
# 4318  2026  late_neonatal         946  wasting_treatment
# 4319  2026  late_neonatal         946  wasting_treatment
#
#                      wasting_state      value  numerator_measure  \
# 0               mild_child_wasting  20.592531  state_person_time
# 1      moderate_acute_malnutrition   8.870594  state_person_time
# 2        severe_acute_malnutrition   2.871921  state_person_time
# 3     susceptible_to_child_wasting  67.664954  state_person_time
# ...                            ...        ...                ...
# 4316            mild_child_wasting  19.942760  state_person_time
# 4317   moderate_acute_malnutrition   8.977209  state_person_time
# 4318     severe_acute_malnutrition   3.336214  state_person_time
# 4319  susceptible_to_child_wasting  67.743817  state_person_time
#
#      denominator_measure  multiplier     measure
# 0      state_person_time         100  prevalence
# 1      state_person_time         100  prevalence
# 2      state_person_time         100  prevalence
# 3      state_person_time         100  prevalence
# ...                  ...         ...         ...
# 4316   state_person_time         100  prevalence
# 4317   state_person_time         100  prevalence
# 4318   state_person_time         100  prevalence
# 4319   state_person_time         100  prevalence
#
# [4320 rows x 10 columns]

# %%
wasting_state_prevalence.wasting_state.unique()
# Out:
# array(['mild_child_wasting', 'moderate_acute_malnutrition',
#        'severe_acute_malnutrition', 'susceptible_to_child_wasting'],
#       dtype=object)

# %%
# These match the values in model_specification.yaml from v4.5.3
x_factor_initial_exposures = {
    'severe_acute_malnutrition': 0.6,
    'moderate_acute_malnutrition': 0.5,
    'mild_child_wasting': 0.25,
    'susceptible_to_child_wasting': 0.01,
}

# This computes the "reference" joint prevalence of X factor and wasting state, stratified by
# year and age, i.e. the conditional probability reference_prevalence(X-factor, wasting_state | year, age),
# where the reference_prevalence measure is determined by the above fractions of each wasting state.
# See the analogous computation for the simulation results below.
x_factor_wasting_state_reference_exposure = wasting_state_prevalence.assign(
    value=lambda df: df['value'] * df['wasting_state'].map(x_factor_initial_exposures)
)
x_factor_wasting_state_reference_exposure
# Out:
#       year            age  input_draw           scenario  \
# 0     2022     1-5_months          29           baseline
# 1     2022     1-5_months          29           baseline
# 2     2022     1-5_months          29           baseline
# 3     2022     1-5_months          29           baseline
# ...    ...            ...         ...                ...
# 4316  2026  late_neonatal         946  wasting_treatment
# 4317  2026  late_neonatal         946  wasting_treatment
# 4318  2026  late_neonatal         946  wasting_treatment
# 4319  2026  late_neonatal         946  wasting_treatment
#
#                      wasting_state     value  numerator_measure  \
# 0               mild_child_wasting  5.148133  state_person_time
# 1      moderate_acute_malnutrition  4.435297  state_person_time
# 2        severe_acute_malnutrition  1.723153  state_person_time
# 3     susceptible_to_child_wasting  0.676650  state_person_time
# ...                            ...       ...                ...
# 4316            mild_child_wasting  4.985690  state_person_time
# 4317   moderate_acute_malnutrition  4.488605  state_person_time
# 4318     severe_acute_malnutrition  2.001728  state_person_time
# 4319  susceptible_to_child_wasting  0.677438  state_person_time
#
#      denominator_measure  multiplier     measure
# 0      state_person_time         100  prevalence
# 1      state_person_time         100  prevalence
# 2      state_person_time         100  prevalence
# 3      state_person_time         100  prevalence
# ...                  ...         ...         ...
# 4316   state_person_time         100  prevalence
# 4317   state_person_time         100  prevalence
# 4318   state_person_time         100  prevalence
# 4319   state_person_time         100  prevalence
#
# [4320 rows x 10 columns]

# %%
x_factor_reference_exposure = vp.marginalize(x_factor_wasting_state_reference_exposure, 'wasting_state')
x_factor_reference_exposure
# Out:
#                 age denominator_measure  input_draw     measure  multiplier  \
# 0        1-5_months   state_person_time          29  prevalence         100
# 1        1-5_months   state_person_time          29  prevalence         100
# 2        1-5_months   state_person_time          29  prevalence         100
# 3        1-5_months   state_person_time          29  prevalence         100
# ...             ...                 ...         ...         ...         ...
# 1076  late_neonatal   state_person_time         946  prevalence         100
# 1077  late_neonatal   state_person_time         946  prevalence         100
# 1078  late_neonatal   state_person_time         946  prevalence         100
# 1079  late_neonatal   state_person_time         946  prevalence         100
#
#       numerator_measure           scenario  year      value
# 0     state_person_time           baseline  2022  11.983232
# 1     state_person_time           baseline  2023  11.940846
# 2     state_person_time           baseline  2024  12.072090
# 3     state_person_time           baseline  2025  11.978475
# ...                 ...                ...   ...        ...
# 1076  state_person_time  wasting_treatment  2023  12.130690
# 1077  state_person_time  wasting_treatment  2024  12.195561
# 1078  state_person_time  wasting_treatment  2025  12.135038
# 1079  state_person_time  wasting_treatment  2026  12.153461
#
# [1080 rows x 9 columns]

# %% [markdown]
# # Plot "reference" overall X-factor exposure in each age group based on the X-factor exposure initialization parameters
#
# We can compare these plots to the plots from Model 4.5.3 to see how the "target" joint prevalence has changed.

# %%
# fig, ax = plt.subplots(figsize=(12,6))
title = "X-factor v4.5.3 reference exposures vs. time in all scenarios, by age group"
fig = csp.plot_over_time_by_column_for_each_scenario(
    x_factor_reference_exposure,
    'age',
    'X-factor prevalence (%)',
    title,
    True
);
figs[title] = fig

# %% [markdown]
# # Plot "reference" joint prevalence of X-factor and wasing state, stratified by year and age (based on X-factor exposure parametrs from v4.5.3)
#
# We can compare these plots to the plots from Model 4.5.3 to see how the "target" joint prevalence has changed.

# %%
title = "v4.5.3 reference prevalence P(X-factor, wasting state) vs. time\nfor all scenarios, stratified by age"
fig = csp.plot_over_time_by_column_for_each_wasting_state_and_scenario(
    x_factor_wasting_state_reference_exposure,
    'age',
    'P(X-factor, wasting_state) (%)',
    title,
    True
)
figs[title] = fig

# %% [markdown]
# # Compute joint (X-factor, wasting_state) prevalence stratified by year and age group, and plot it
#
# This is a different view of the conditional X-factor prevalence plotted previously, which may provide additional insights. We can also compare these plots to the plots from Model 4.5.3 to see how the joint prevalence has changed.
#
# **Plan for future code update** to `get_prevalence`: It would be more intuitive to be able to compute a joint prevalence like this by passing `['x_factor', 'wasting_state']` to `state_variable`, rather than having to pass one of the variables to `state_variable` and the other(s) to `numerator_broadcast`.

# %%
# This computes P(X-factor, wasting_state | year, age),
# i.e. P(X-factor | wasting_state, year, age) * P(wasting_state | year, age)
x_factor_wasting_state_prevalence = csr.get_prevalence(
    data, 'x_factor', strata=['year', 'age'], numerator_broadcast='wasting_state', multiplier=100
)
x_factor_wasting_state_prevalence
# Out:
#       year            age  input_draw           scenario x_factor  \
# 0     2022     1-5_months          29           baseline     cat1
# 1     2022     1-5_months          29           baseline     cat1
# 2     2022     1-5_months          29           baseline     cat1
# 3     2022     1-5_months          29           baseline     cat1
# ...    ...            ...         ...                ...      ...
# 8636  2026  late_neonatal         946  wasting_treatment     cat2
# 8637  2026  late_neonatal         946  wasting_treatment     cat2
# 8638  2026  late_neonatal         946  wasting_treatment     cat2
# 8639  2026  late_neonatal         946  wasting_treatment     cat2
#
#                      wasting_state      value  numerator_measure  \
# 0               mild_child_wasting  20.592531  state_person_time
# 1      moderate_acute_malnutrition   8.870594  state_person_time
# 2        severe_acute_malnutrition   1.607662  state_person_time
# 3     susceptible_to_child_wasting   0.869654  state_person_time
# ...                            ...        ...                ...
# 8636            mild_child_wasting   0.000000  state_person_time
# 8637   moderate_acute_malnutrition   0.000000  state_person_time
# 8638     severe_acute_malnutrition   0.989301  state_person_time
# 8639  susceptible_to_child_wasting  66.986920  state_person_time
#
#      denominator_measure  multiplier     measure
# 0      state_person_time         100  prevalence
# 1      state_person_time         100  prevalence
# 2      state_person_time         100  prevalence
# 3      state_person_time         100  prevalence
# ...                  ...         ...         ...
# 8636   state_person_time         100  prevalence
# 8637   state_person_time         100  prevalence
# 8638   state_person_time         100  prevalence
# 8639   state_person_time         100  prevalence
#
# [8640 rows x 11 columns]

# %%
title = "P(X-factor, wasting state) vs. time for all scenarios\nstratified by age"
fig = csp.plot_over_time_by_column_for_each_wasting_state_and_scenario(
    x_factor_wasting_state_prevalence.query("x_factor=='cat1'"),
    colname='age',
    ylabel='P(X-factor, wasting state) (%)',
    suptitle=title
)
figs[title] = fig

# %% [markdown]
# # Define directories for saving figures

# %%
# project_results_dir = '/ihme/costeffectiveness/results/vivarium_ciff_sam'
model_name = 'v4.5.4_x_factor_wasting_propensity'
model_timestamp = '2021_11_09_20_57_59'
username = 'ndbs'

# %%
# model_count_data_dir = f'{project_results_dir}/{model_name}/ciff_sam/{model_timestamp}/count_data/'

project_vv_directory_name = 'ciff_malnutrition/verification_and_validation'

output_dir = f'/ihme/homes/{username}/vivarium_results/{project_vv_directory_name}/{model_name}'
share_output_dir = f'/share/scratch/users/ndbs/vivarium_results/{project_vv_directory_name}/{model_name}'
j_output_dir = f'/home/j/Project/simulation_science/{project_vv_directory_name}/{model_name}'

# Create the output directories if they don't exist
# Note from Path.mkdir() documentation:
#   "If mode is given, it is combined with the process’ umask value to determine the file mode and access flags."
#
# I don't know what this notebook process' umask value will be, so I don't know if this will actually result
# in the correct (most permissive) permissions for the directories...
for directory in [output_dir, share_output_dir, j_output_dir]:
    Path(directory).mkdir(mode=0o777, parents=True, exist_ok=True)

# %%
# We'll use this function to format the figures' title strings into legitimate file names for saving.
def convert_to_variable_name(string):
    """Converts a string to a valid Python variable.
    Runs of non-word characters (regex matchs \W+) are converted to '_', and '_' is appended to the
    beginning of the string if the string starts with a digit (regex matches ^(?=\d)).
    Solution copied from here:
    https://stackoverflow.com/questions/3303312/how-do-i-convert-a-string-to-a-valid-variable-name-in-python
    """
    return re.sub('\W+|^(?=\d)', '_', string)
convert_to_variable_name(title)
# Out:
# 'P_X_factor_wasting_state_vs_time_for_all_scenarios_stratified_by_age'

# %% [markdown]
# # Save figures to my home directory and J drive

# %%
# We'll use figure titles as filenames, but we'll remove non-word characters first
list(figs.keys())
# Out:
# ['Mean X-factor prevalence vs. time in baseline scenario, by age group',
#  'X-factor prevalence vs. time in baseline scenario, by age group',
#  'X-factor prevalence (draws and mean) vs. time in baseline scenario, by age group',
#  'Mean X-factor prevalence vs. time in all scenarios',
#  'X-factor prevalence vs. time for all scenarios\nstratified by age and wasting state',
#  'X-factor v4.5.3 reference exposures vs. time in all scenarios, by age group',
#  'v4.5.3 reference prevalence P(X-factor, wasting state) vs. time\nfor all scenarios, stratified by age',
#  'P(X-factor, wasting state) vs. time for all scenarios\nstratified by age']

# %%
for figure_name, fig in figs.items():
    for directory in [output_dir, j_output_dir]: 
        fig.savefig(f"{directory}/{convert_to_variable_name(figure_name)}.pdf")

# %%
# !ls /home/j/Project/simulation_science/ciff_malnutrition/verification_and_validation/v4.5.4_x_factor_wasting_propensity/
# Out:
# Mean_X_factor_prevalence_vs_time_in_all_scenarios.pdf
# Mean_X_factor_prevalence_vs_time_in_baseline_scenario_by_age_group.pdf
# P_X_factor_wasting_state_vs_time_for_all_scenarios_stratified_by_age.pdf
# v4_5_3_reference_prevalence_P_X_factor_wasting_state_vs_time_for_all_scenarios_stratified_by_age.pdf
# X_factor_prevalence_draws_and_mean_vs_time_in_baseline_scenario_by_age_group.pdf
# X_factor_prevalence_vs_time_for_all_scenarios_stratified_by_age_and_wasting_state.pdf
# X_factor_prevalence_vs_time_in_baseline_scenario_by_age_group.pdf
# X_factor_v4_5_3_reference_exposures_vs_time_in_all_scenarios_by_age_group.pdf

# %% [markdown]
# # Load model spec yaml file to see what's in it
#
# To see the contents you can do
#
# ```Python
# print(yaml.dump(model_spec))
# ```
#
# after loading the `model_specification.yaml` file into a dictionary called `model_spec`.
#
# With the output stream parameter of `yaml.dump()` set to `None` (default) and with `default_flow_style=False` (which is the [default if the yaml data has nested collections](https://pyyaml.org/wiki/PyYAMLDocumentation#FrequentlyAskedQuestions)), calling `yaml.dump()` on the loaded dictionary returns a string that is the same as the contents of the original `.yaml` file as returned by `file.read()`.

# %%
count_data_path = csr.get_count_data_path('4.5.4')
count_data_path
# Out:
# '/ihme/costeffectiveness/results/vivarium_ciff_sam/v4.5.4_x_factor_wasting_propensity/ciff_sam/2021_11_09_20_57_59/count_data/'

# %%
output_path = count_data_path[:-len('count_data/')]
output_path
# Out:
# '/ihme/costeffectiveness/results/vivarium_ciff_sam/v4.5.4_x_factor_wasting_propensity/ciff_sam/2021_11_09_20_57_59/'

# %%
# !ls /ihme/costeffectiveness/results/vivarium_ciff_sam/v4.5.4_x_factor_wasting_propensity/ciff_sam/2021_11_09_20_57_59/
# Out:
# branches.yaml  logs			 __pycache__
# count_data     model_specification.yaml  requirements.txt
# keyspace.yaml  output.hdf		 settings.py

# %%
model_spec_path = f"{output_path}/model_specification.yaml"
with open(model_spec_path, 'r') as model_spec_file:
    model_spec = yaml.safe_load(model_spec_file) # Load contents into a nested dictionary
type(model_spec)
# Out:
# dict

# %%
# We can use yaml.dump() to produce a nicely formatted string.
# Writing this string to file would produce a valid .yaml file.
print(yaml.dump(model_spec))
# Out:
# components:
#   vivarium_ciff_sam:
#     components:
#     - ChildWasting()
#     - LowBirthWeight()
#     - ShortGestation()
#     - XFactorExposure()
#     - SQLNSTreatment()
#     - SQLNSIntervention()
#     - WastingTreatmentIntervention()
#     - DisabilityObserver('wasting')
#     - MortalityObserver('wasting')
#     - DiseaseObserver('diarrheal_diseases', 'wasting')
#     - DiseaseObserver('measles', 'wasting')
#     - DiseaseObserver('lower_respiratory_infections', 'wasting')
#     - DiseaseObserver('child_wasting', 'False', 'sq_lns', 'wasting_treatment', 'x_factor')
#     - CategoricalRiskObserver('child_stunting', 'False', 'sq_lns')
#   vivarium_public_health:
#     disease:
#     - SIS('diarrheal_diseases')
#     - SIS_fixed_duration('measles', '10.0')
#     - SIS('lower_respiratory_infections')
#     population:
#     - BasePopulation()
#     - Mortality()
#     - FertilityCrudeBirthRate()
#     risks:
#     - RiskEffect('risk_factor.child_wasting', 'cause.diarrheal_diseases.incidence_rate')
#     - RiskEffect('risk_factor.child_wasting', 'cause.measles.incidence_rate')
#     - RiskEffect('risk_factor.child_wasting', 'cause.lower_respiratory_infections.incidence_rate')
#     - Risk('risk_factor.child_stunting')
#     - RiskEffect('risk_factor.child_stunting', 'cause.diarrheal_diseases.incidence_rate')
#     - RiskEffect('risk_factor.child_stunting', 'cause.measles.incidence_rate')
#     - RiskEffect('risk_factor.child_stunting', 'cause.lower_respiratory_infections.incidence_rate')
#     - Risk('risk_factor.wasting_treatment')
#     - RiskEffect('risk_factor.wasting_treatment', 'risk_factor.severe_acute_malnutrition_to_mild_child_wasting.transition_rate')
#     - RiskEffect('risk_factor.wasting_treatment', 'risk_factor.severe_acute_malnutrition_to_moderate_acute_malnutrition.transition_rate')
#     - RiskEffect('risk_factor.wasting_treatment', 'risk_factor.moderate_acute_malnutrition_to_mild_child_wasting.transition_rate')
#     - RiskEffect('risk_factor.x_factor', 'risk_factor.mild_child_wasting.incidence_rate')
#     - RiskEffect('risk_factor.x_factor', 'risk_factor.mild_child_wasting_to_moderate_acute_malnutrition.transition_rate')
#     - RiskEffect('risk_factor.x_factor', 'risk_factor.moderate_acute_malnutrition_to_severe_acute_malnutrition.transition_rate')
#     - Risk('risk_factor.low_birth_weight_and_short_gestation')
# configuration:
#   child_wasting:
#     mild_child_wasting_untreated_recovery_time: 27
#   effect_of_x_factor_on_mild_child_wasting:
#     incidence_rate:
#       relative_risk: 1.0
#   effect_of_x_factor_on_mild_child_wasting_to_moderate_acute_malnutrition:
#     transition_rate:
#       relative_risk: 3.16
#   effect_of_x_factor_on_moderate_acute_malnutrition_to_severe_acute_malnutrition:
#     transition_rate:
#       relative_risk: 3.16
#   input_data:
#     artifact_path: /ihme/costeffectiveness/artifacts/vivarium_ciff_sam/ethiopia.hdf
#     input_draw_number: 0
#     location: Ethiopia
#   interpolation:
#     extrapolate: true
#     order: 0
#   intervention:
#     scenario: baseline
#   metrics:
#     child_stunting:
#       by_age: true
#       by_sex: true
#       by_year: true
#     child_wasting_observer:
#       by_age: true
#       by_sex: true
#       by_year: true
#     diarrheal_diseases_observer:
#       by_age: true
#       by_sex: true
#       by_year: true
#     disability:
#       by_age: true
#       by_sex: true
#       by_year: true
#     lower_respiratory_infections_observer:
#       by_age: true
#       by_sex: true
#       by_year: true
#     measles_observer:
#       by_age: true
#       by_sex: true
#       by_year: true
#     mortality:
#       by_age: true
#       by_sex: true
#       by_year: true
#   population:
#     age_end: 5
#     age_start: 0
#     exit_age: 5
#     population_size: 10000
#   randomness:
#     key_columns:
#     - entrance_time
#     - age
#     map_size: 1000000
#     random_seed: 0
#   time:
#     end:
#       day: 31
#       month: 12
#       year: 2026
#     start:
#       day: 1
#       month: 1
#       year: 2022
#     step_size: 0.5
#   x_factor:
#     exposure: 0.32
# plugins:
#   optional: {}
#   required:
#     clock:
#       builder_interface: vivarium.framework.time.TimeInterface
#       controller: vivarium.framework.time.DateTimeClock
#     component_configuration_parser:
#       builder_interface: null
#       controller: vivarium.framework.components.ComponentConfigurationParser
#     component_manager:
#       builder_interface: vivarium.framework.components.ComponentInterface
#       controller: vivarium.framework.components.ComponentManager
#     data:
#       builder_interface: vivarium.framework.artifact.ArtifactInterface
#       controller: vivarium.framework.artifact.ArtifactManager
#     lifecycle:
#       builder_interface: vivarium.framework.lifecycle.LifeCycleInterface
#       controller: vivarium.framework.lifecycle.LifeCycleManager

# %%
# Read entire file into a string to compare with yaml.dump()
# They're identical
with open(model_spec_path, 'r') as model_spec_file:
    model_spec_contents = model_spec_file.read()

model_spec_contents == yaml.dump(model_spec)
# Out:
# True

# %% [markdown]
# # See what the X-factor exposure configuration looks like in this model

# %%
model_spec['configuration'].keys()
# Out:
# dict_keys(['child_wasting', 'effect_of_x_factor_on_mild_child_wasting', 'effect_of_x_factor_on_mild_child_wasting_to_moderate_acute_malnutrition', 'effect_of_x_factor_on_moderate_acute_malnutrition_to_severe_acute_malnutrition', 'input_data', 'interpolation', 'intervention', 'metrics', 'population', 'randomness', 'time', 'x_factor'])

# %%
model_spec['configuration']['x_factor']
# Out:
# {'exposure': 0.32}
