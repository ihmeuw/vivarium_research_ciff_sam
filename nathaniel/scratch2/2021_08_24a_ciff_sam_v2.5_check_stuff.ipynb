# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
pd.set_option('display.max_rows', 8)

import collections

import warnings
# warnings.filterwarnings('ignore')
from matplotlib.backends.backend_pdf import PdfPages

from pathlib import Path

import db_queries as db
import vivarium_helpers.id_helper as idh

# Add the repo directory vivarium_research_ciff_sam/ to sys.path
import os, sys
repo_path = os.path.abspath('../..')
sys.path.append(repo_path)
# Assumes vivarium_research_ciff_sam/ is in sys.path
import model_validation.vivarium_transformed_output as vto
# import model_validation.vivarium_raw_output as vro
import model_validation.vivarium_output_processing as vo

# !pwd
# !whoami
# !date
# Out:
# /ihme/homes/ndbs/vivarium_research_ciff_sam/nathaniel/scratch__gitignore__
# ndbs
# Tue Aug 24 17:43:51 PDT 2021

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Define and create directories

# %%
project_results_dir = '/ihme/costeffectiveness/results/vivarium_ciff_sam'
model_name = 'v2.5_stunting'
model_timestamp = '2021_08_05_16_17_12'
username = 'ndbs'

# %%
model_count_data_dir = f'{project_results_dir}/{model_name}/ciff_sam/{model_timestamp}/count_data/'

project_vv_directory_name = 'ciff_malnutrition/verification_and_validation'

output_dir = f'/ihme/homes/{username}/vivarium_results/{project_vv_directory_name}/{model_name}'
share_output_dir = f'/share/scratch/users/ndbs/vivarium_results/{project_vv_directory_name}/{model_name}'
j_output_dir = f'/home/j/Project/simulation_science/{project_vv_directory_name}/{model_name}'

# Create the output directories if they don't exist
# Note from Path.mkdir() documentation:
#   "If mode is given, it is combined with the process’ umask value to determine the file mode and access flags."
#
# I don't know what this notebook process' umask value will be, so I don't know if this will actually result
# in the correct (most permissive) permissions for the directories...
for directory in [output_dir, share_output_dir, j_output_dir]:
    Path(directory).mkdir(mode=0o777, parents=True, exist_ok=True)

# %% [markdown]
# # Define a function to clean transformed data

# %%
def clean_transformed_data(data):
    """Reformat transformed count data to make more sense."""
    # Rename mislabeled 'cause' column in `wasting_state_person_time`
    wasting_state_person_time = data.wasting_state_person_time.rename(columns={'cause':'wasting_state'})
    # Rename poorly named 'cause' column in `disease_state_person_time` and add an actual cause column
    disease_state_person_time = (
        data.disease_state_person_time
        .rename(columns={'cause':'cause_state'})
        .assign(cause=lambda df: df['cause_state'].str.replace('susceptible_to_', ''))
    )
    # Define a function to make the transition count dataframes better
    def clean_transition_df(df):
        return (df
                .assign(transition=lambda df: df['measure'].str.replace('_event_count', ''))
                .assign(measure='transition_count')
               )
    # Make the wasting and disease transition count dataframes better
    wasting_transition_count, disease_transition_count = map(
        clean_transition_df, (data.wasting_transition_count, data.disease_transition_count)
    )
    # Create a dictionary with the original or cleaned dataframes and create a cleaned Output object
    data_dict = data.to_dict()
    data_dict.update(
        {'wasting_state_person_time': wasting_state_person_time,
         'disease_state_person_time': disease_state_person_time,
         'wasting_transition_count': wasting_transition_count,
         'disease_transition_count': disease_transition_count,
        }
    )
    clean_data = vto.VivariumTransformedOutput(data_dict)
    return clean_data

# %% [markdown]
# # Load and clean transformed count data

# %%
orig_data = vto.VivariumTransformedOutput.from_directory(model_count_data_dir)
data = clean_transformed_data(orig_data)
data.table_names()
# Out:
# ['wasting_transition_count',
#  'wasting_state_person_time',
#  'deaths',
#  'population',
#  'ylls',
#  'ylds',
#  'disease_state_person_time',
#  'disease_transition_count']

# %%
data.wasting_state_person_time
# Out:
#          sex  year                 wasting_state            measure  \
# 0     female  2022            mild_child_wasting  state_person_time
# 1     female  2022            mild_child_wasting  state_person_time
# 2     female  2022            mild_child_wasting  state_person_time
# 3     female  2022            mild_child_wasting  state_person_time
# ...      ...   ...                           ...                ...
# 2876    male  2026  susceptible_to_child_wasting  state_person_time
# 2877    male  2026  susceptible_to_child_wasting  state_person_time
# 2878    male  2026  susceptible_to_child_wasting  state_person_time
# 2879    male  2026  susceptible_to_child_wasting  state_person_time
#
#       input_draw  scenario          value              age
# 0             29  baseline     414.090349   early_neonatal
# 1             29  baseline    1234.535250    late_neonatal
# 2             29  baseline    8926.954141       1-5_months
# 3             29  baseline   10434.387406      6-11_months
# ...          ...       ...            ...              ...
# 2876         946  baseline   30258.041068       1-5_months
# 2877         946  baseline   35695.241615      6-11_months
# 2878         946  baseline   70879.949350  12_to_23_months
# 2879         946  baseline  215444.187543           2_to_4
#
# [2880 rows x 8 columns]

# %%
data.ylls
# Out:
#           sex  year                      cause measure  input_draw  scenario  \
# 0      female  2022         diarrheal_diseases    ylls          29  baseline
# 1      female  2022         diarrheal_diseases    ylls          29  baseline
# 2      female  2022         diarrheal_diseases    ylls          29  baseline
# 3      female  2022         diarrheal_diseases    ylls          29  baseline
# ...       ...   ...                        ...     ...         ...       ...
# 17276    male  2026  severe_acute_malnutrition    ylls         946  baseline
# 17277    male  2026  severe_acute_malnutrition    ylls         946  baseline
# 17278    male  2026  severe_acute_malnutrition    ylls         946  baseline
# 17279    male  2026  severe_acute_malnutrition    ylls         946  baseline
#
#              value stunting_state             age
# 0      2843.691511           cat4  early_neonatal
# 1         0.000000           cat3  early_neonatal
# 2         0.000000           cat2  early_neonatal
# 3         0.000000           cat1  early_neonatal
# ...            ...            ...             ...
# 17276   258.045887           cat4          2_to_4
# 17277     0.000000           cat3          2_to_4
# 17278    85.628179           cat2          2_to_4
# 17279    86.997977           cat1          2_to_4
#
# [17280 rows x 9 columns]

# %% [markdown]
# # Define some more functions

# %%
def _ensure_columns_not_levels(df, column_list=None):
    """Move Index levels into columns to enable passing index level names as well as column names."""
    if column_list is None: column_list = []
    if df.index.nlevels > 1 or df.index.name in column_list:
        df = df.reset_index()
    return df

def describe(data, **describe_kwargs):
    if 'percentiles' not in describe_kwargs:
        describe_kwargs['percentiles'] = [.025, .975]
    data = _ensure_columns_not_levels(data, [vo.DRAW_COLUMN, vo.VALUE_COLUMN])
    groupby_cols = data.columns.difference([vo.DRAW_COLUMN, vo.VALUE_COLUMN]).to_list()
    return data.groupby(groupby_cols)[vo.VALUE_COLUMN].describe(**describe_kwargs)

describe(data.wasting_state_person_time)
# Out:
#                                                                                    count  \
# age           measure           scenario sex    wasting_state                year
# 1-5_months    state_person_time baseline female mild_child_wasting           2022   12.0
#                                                                              2023   12.0
#                                                                              2024   12.0
#                                                                              2025   12.0
# ...                                                                                  ...
# late_neonatal state_person_time baseline male   susceptible_to_child_wasting 2023   12.0
#                                                                              2024   12.0
#                                                                              2025   12.0
#                                                                              2026   12.0
#
#                                                                                           mean  \
# age           measure           scenario sex    wasting_state                year
# 1-5_months    state_person_time baseline female mild_child_wasting           2022  8826.488935
#                                                                              2023  8794.313826
#                                                                              2024  8836.645562
#                                                                              2025  8808.098677
# ...                                                                                        ...
# late_neonatal state_person_time baseline male   susceptible_to_child_wasting 2023  4174.045403
#                                                                              2024  4199.450605
#                                                                              2025  4182.792494
#                                                                              2026  4172.952202
#
#                                                                                           std  \
# age           measure           scenario sex    wasting_state                year
# 1-5_months    state_person_time baseline female mild_child_wasting           2022   88.753512
#                                                                              2023  165.691577
#                                                                              2024  137.494408
#                                                                              2025  141.141967
# ...                                                                                       ...
# late_neonatal state_person_time baseline male   susceptible_to_child_wasting 2023   30.327060
#                                                                              2024   25.089339
#                                                                              2025   40.514449
#                                                                              2026   24.003145
#
#                                                                                            min  \
# age           measure           scenario sex    wasting_state                year
# 1-5_months    state_person_time baseline female mild_child_wasting           2022  8700.517454
#                                                                              2023  8607.275838
#                                                                              2024  8702.147844
#                                                                              2025  8655.026694
# ...                                                                                        ...
# late_neonatal state_person_time baseline male   susceptible_to_child_wasting 2023  4101.519507
#                                                                              2024  4152.565366
#                                                                              2025  4083.872690
#                                                                              2026  4122.913073
#
#                                                                                           2.5%  \
# age           measure           scenario sex    wasting_state                year
# 1-5_months    state_person_time baseline female mild_child_wasting           2022  8709.954415
#                                                                              2023  8615.604894
#                                                                              2024  8706.552361
#                                                                              2025  8655.982888
# ...                                                                                        ...
# late_neonatal state_person_time baseline male   susceptible_to_child_wasting 2023  4111.165024
#                                                                              2024  4159.082170
#                                                                              2025  4105.738672
#                                                                              2026  4127.741478
#
#                                                                                            50%  \
# age           measure           scenario sex    wasting_state                year
# 1-5_months    state_person_time baseline female mild_child_wasting           2022  8816.203285
#                                                                              2023  8744.853525
#                                                                              2024  8760.017112
#                                                                              2025  8790.670089
# ...                                                                                        ...
# late_neonatal state_person_time baseline male   susceptible_to_child_wasting 2023  4179.370979
#                                                                              2024  4196.355921
#                                                                              2025  4177.446270
#                                                                              2026  4179.908966
#
#                                                                                          97.5%  \
# age           measure           scenario sex    wasting_state                year
# 1-5_months    state_person_time baseline female mild_child_wasting           2022  8979.521253
#                                                                              2023  9120.758350
#                                                                              2024  9083.276899
#                                                                              2025  9095.137029
# ...                                                                                        ...
# late_neonatal state_person_time baseline male   susceptible_to_child_wasting 2023  4206.719644
#                                                                              2024  4230.899281
#                                                                              2025  4237.145277
#                                                                              2026  4205.233231
#
#                                                                                            max
# age           measure           scenario sex    wasting_state                year
# 1-5_months    state_person_time baseline female mild_child_wasting           2022  8995.934292
#                                                                              2023  9171.915127
#                                                                              2024  9116.984257
#                                                                              2025  9152.725530
# ...                                                                                        ...
# late_neonatal state_person_time baseline male   susceptible_to_child_wasting 2023  4208.154689
#                                                                              2024  4231.227926
#                                                                              2025  4244.736482
#                                                                              2026  4207.151266
#
# [240 rows x 8 columns]

# %%
def get_all_ages_person_time(person_time):
    return vo.marginalize(person_time, 'age').assign(age='all')[person_time.columns]

def get_total_person_time(data, include_all_ages=False):
    if not include_all_ages:
        person_time = vo.marginalize(data.wasting_state_person_time, 'wasting_state').assign(measure='person_time')
    else:
        person_time = get_total_person_time(data, False)
        person_time = person_time.append(get_all_ages_person_time(person_time), ignore_index=True)
    return person_time

# def get_total_person_time_with_all_ages(data):
#     person_time = get_total_person_time(data)
#     return person_time.append(get_all_ages_person_time(person_time))

person_time = get_total_person_time(data)
person_time
# Out:
#                age  input_draw      measure  scenario     sex  year  \
# 0       1-5_months          29  person_time  baseline  female  2022
# 1       1-5_months          29  person_time  baseline  female  2023
# 2       1-5_months          29  person_time  baseline  female  2024
# 3       1-5_months          29  person_time  baseline  female  2025
# ..             ...         ...          ...       ...     ...   ...
# 716  late_neonatal         946  person_time  baseline    male  2023
# 717  late_neonatal         946  person_time  baseline    male  2024
# 718  late_neonatal         946  person_time  baseline    male  2025
# 719  late_neonatal         946  person_time  baseline    male  2026
#
#             value
# 0    44140.585900
# 1    43843.549624
# 2    43946.220397
# 3    43707.561944
# ..            ...
# 716   6263.611225
# 717   6284.217659
# 718   6291.129363
# 719   6238.913073
#
# [720 rows x 7 columns]

# %%
person_time_all = get_total_person_time(data, True)
person_time_all
# Out:
#             age  input_draw      measure  scenario     sex  year  \
# 0    1-5_months          29  person_time  baseline  female  2022
# 1    1-5_months          29  person_time  baseline  female  2023
# 2    1-5_months          29  person_time  baseline  female  2024
# 3    1-5_months          29  person_time  baseline  female  2025
# ..          ...         ...          ...       ...     ...   ...
# 836         all         946  person_time  baseline    male  2023
# 837         all         946  person_time  baseline    male  2024
# 838         all         946  person_time  baseline    male  2025
# 839         all         946  person_time  baseline    male  2026
#
#              value
# 0     44140.585900
# 1     43843.549624
# 2     43946.220397
# 3     43707.561944
# ..             ...
# 836  521780.900753
# 837  529583.511294
# 838  532527.890486
# 839  532910.529774
#
# [840 rows x 7 columns]

# %% [markdown]
# # Compute death rate by wasting category

# %%
data.deaths
# Out:
#           sex  year                      cause measure  input_draw  scenario  \
# 0      female  2022         diarrheal_diseases   death          29  baseline
# 1      female  2022         diarrheal_diseases   death          29  baseline
# 2      female  2022         diarrheal_diseases   death          29  baseline
# 3      female  2022         diarrheal_diseases   death          29  baseline
# ...       ...   ...                        ...     ...         ...       ...
# 17276    male  2026  severe_acute_malnutrition   death         946  baseline
# 17277    male  2026  severe_acute_malnutrition   death         946  baseline
# 17278    male  2026  severe_acute_malnutrition   death         946  baseline
# 17279    male  2026  severe_acute_malnutrition   death         946  baseline
#
#        value stunting_state             age
# 0       32.0           cat4  early_neonatal
# 1        0.0           cat3  early_neonatal
# 2        0.0           cat2  early_neonatal
# 3        0.0           cat1  early_neonatal
# ...      ...            ...             ...
# 17276    3.0           cat4          2_to_4
# 17277    0.0           cat3          2_to_4
# 17278    1.0           cat2          2_to_4
# 17279    1.0           cat1          2_to_4
#
# [17280 rows x 9 columns]

# %%
vo.ratio(
    data.deaths,
    person_time,
    strata=['year', 'sex', 'age'],
)
# Out:
#      year     sex            age  input_draw  scenario     value  \
# 0    2022  female     1-5_months          29  baseline  0.011033
# 1    2022  female     1-5_months         223  baseline  0.012241
# 2    2022  female     1-5_months         232  baseline  0.013871
# 3    2022  female     1-5_months         357  baseline  0.013104
# ..    ...     ...            ...         ...       ...       ...
# 716  2026    male  late_neonatal         650  baseline  0.125277
# 717  2026    male  late_neonatal         680  baseline  0.086785
# 718  2026    male  late_neonatal         829  baseline  0.073546
# 719  2026    male  late_neonatal         946  baseline  0.109474
#
#     numerator_measure denominator_measure  multiplier
# 0               death         person_time           1
# 1               death         person_time           1
# 2               death         person_time           1
# 3               death         person_time           1
# ..                ...                 ...         ...
# 716             death         person_time           1
# 717             death         person_time           1
# 718             death         person_time           1
# 719             death         person_time           1
#
# [720 rows x 9 columns]

# %%
df = vo.ratio(
    data.deaths,
    person_time_all,
    strata=['year', 'sex', 'age'],
)
df
# Out:
#      year     sex            age  input_draw  scenario     value  \
# 0    2022  female     1-5_months          29  baseline  0.011033
# 1    2022  female     1-5_months         223  baseline  0.012241
# 2    2022  female     1-5_months         232  baseline  0.013871
# 3    2022  female     1-5_months         357  baseline  0.013104
# ..    ...     ...            ...         ...       ...       ...
# 836  2026    male  late_neonatal         650  baseline  0.125277
# 837  2026    male  late_neonatal         680  baseline  0.086785
# 838  2026    male  late_neonatal         829  baseline  0.073546
# 839  2026    male  late_neonatal         946  baseline  0.109474
#
#     numerator_measure denominator_measure  multiplier
# 0               death         person_time           1
# 1               death         person_time           1
# 2               death         person_time           1
# 3               death         person_time           1
# ..                ...                 ...         ...
# 836             death         person_time           1
# 837             death         person_time           1
# 838             death         person_time           1
# 839             death         person_time           1
#
# [840 rows x 9 columns]

# %%
df.query("age=='all'")
# Out:
#      year     sex  age  input_draw  scenario  value numerator_measure  \
# 48   2022  female  all          29  baseline    NaN             death
# 49   2022  female  all         223  baseline    NaN             death
# 50   2022  female  all         232  baseline    NaN             death
# 51   2022  female  all         357  baseline    NaN             death
# ..    ...     ...  ...         ...       ...    ...               ...
# 812  2026    male  all         650  baseline    NaN             death
# 813  2026    male  all         680  baseline    NaN             death
# 814  2026    male  all         829  baseline    NaN             death
# 815  2026    male  all         946  baseline    NaN             death
#
#     denominator_measure  multiplier
# 48          person_time           1
# 49          person_time           1
# 50          person_time           1
# 51          person_time           1
# ..                  ...         ...
# 812         person_time           1
# 813         person_time           1
# 814         person_time           1
# 815         person_time           1
#
# [120 rows x 9 columns]

# %%
describe(df)
# Out:
#                                                                                      count  \
# age           denominator_measure multiplier numerator_measure scenario sex    year
# 1-5_months    person_time         1          death             baseline female 2022   12.0
#                                                                                2023   12.0
#                                                                                2024   12.0
#                                                                                2025   12.0
# ...                                                                                    ...
# late_neonatal person_time         1          death             baseline male   2023   12.0
#                                                                                2024   12.0
#                                                                                2025   12.0
#                                                                                2026   12.0
#
#                                                                                          mean  \
# age           denominator_measure multiplier numerator_measure scenario sex    year
# 1-5_months    person_time         1          death             baseline female 2022  0.011934
#                                                                                2023  0.011829
#                                                                                2024  0.011811
#                                                                                2025  0.011896
# ...                                                                                       ...
# late_neonatal person_time         1          death             baseline male   2023  0.113694
#                                                                                2024  0.109721
#                                                                                2025  0.110308
#                                                                                2026  0.111706
#
#                                                                                           std  \
# age           denominator_measure multiplier numerator_measure scenario sex    year
# 1-5_months    person_time         1          death             baseline female 2022  0.001498
#                                                                                2023  0.001647
#                                                                                2024  0.001524
#                                                                                2025  0.001319
# ...                                                                                       ...
# late_neonatal person_time         1          death             baseline male   2023  0.016034
#                                                                                2024  0.017226
#                                                                                2025  0.017157
#                                                                                2026  0.017072
#
#                                                                                           min  \
# age           denominator_measure multiplier numerator_measure scenario sex    year
# 1-5_months    person_time         1          death             baseline female 2022  0.008748
#                                                                                2023  0.007448
#                                                                                2024  0.008608
#                                                                                2025  0.009072
# ...                                                                                       ...
# late_neonatal person_time         1          death             baseline male   2023  0.081422
#                                                                                2024  0.073080
#                                                                                2025  0.071757
#                                                                                2026  0.073546
#
#                                                                                          2.5%  \
# age           denominator_measure multiplier numerator_measure scenario sex    year
# 1-5_months    person_time         1          death             baseline female 2022  0.009025
#                                                                                2023  0.008403
#                                                                                2024  0.008873
#                                                                                2025  0.009597
# ...                                                                                       ...
# late_neonatal person_time         1          death             baseline male   2023  0.085886
#                                                                                2024  0.078113
#                                                                                2025  0.076400
#                                                                                2026  0.077187
#
#                                                                                           50%  \
# age           denominator_measure multiplier numerator_measure scenario sex    year
# 1-5_months    person_time         1          death             baseline female 2022  0.012231
#                                                                                2023  0.012094
#                                                                                2024  0.012301
#                                                                                2025  0.011744
# ...                                                                                       ...
# late_neonatal person_time         1          death             baseline male   2023  0.115384
#                                                                                2024  0.112671
#                                                                                2025  0.111413
#                                                                                2026  0.119364
#
#                                                                                         97.5%  \
# age           denominator_measure multiplier numerator_measure scenario sex    year
# 1-5_months    person_time         1          death             baseline female 2022  0.013704
#                                                                                2023  0.013398
#                                                                                2024  0.013427
#                                                                                2025  0.013699
# ...                                                                                       ...
# late_neonatal person_time         1          death             baseline male   2023  0.132722
#                                                                                2024  0.132363
#                                                                                2025  0.133971
#                                                                                2026  0.126029
#
#                                                                                           max
# age           denominator_measure multiplier numerator_measure scenario sex    year
# 1-5_months    person_time         1          death             baseline female 2022  0.013871
#                                                                                2023  0.013408
#                                                                                2024  0.013486
#                                                                                2025  0.013883
# ...                                                                                       ...
# late_neonatal person_time         1          death             baseline male   2023  0.132908
#                                                                                2024  0.133427
#                                                                                2025  0.136327
#                                                                                2026  0.126239
#
# [70 rows x 8 columns]

# %%
df.age.nunique()
# Out:
# 7

# %%
df.year.nunique()
# Out:
# 5
