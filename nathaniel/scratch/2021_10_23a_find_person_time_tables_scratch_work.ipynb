# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
pd.set_option('display.max_rows', 8)

from scipy import stats
import collections

import warnings
# warnings.filterwarnings('ignore')
from matplotlib.backends.backend_pdf import PdfPages

from pathlib import Path

import db_queries as db
import vivarium_helpers.id_helper as idh
import gbd_mapping
from vivarium import Artifact

# Add the repo directory vivarium_research_ciff_sam/ to sys.path
import os, sys
repo_path = os.path.abspath('../..')
sys.path.append(repo_path)
# Assumes vivarium_research_ciff_sam/ is in sys.path
# import model_validation.vivarium_transformed_output as vto
# import model_validation.vivarium_raw_output as vro
import model_validation.vivarium_output_processing as vp
import model_validation.ciff_sam_results as csr
import model_validation.ciff_sam_plots as csp

# %load_ext autoreload
# %autoreload 2

# !pwd
# !whoami
# !date
# Out:
# /ihme/homes/ndbs/vivarium_research_ciff_sam/nathaniel/scratch
# ndbs
# Sat Oct 23 13:59:46 PDT 2021

# %% [markdown]
# # Load results and set global index columns

# %%
results = csr.VivariumResults.cleaned_from_model_spec('4.5.2')
results.table_names()
# Out:
# ['wasting_transition_count',
#  'wasting_state_person_time',
#  'deaths',
#  'stunting_state_person_time',
#  'population',
#  'ylls',
#  'ylds',
#  'person_time',
#  'cause_state_person_time',
#  'cause_transition_count']

# %%
vp.set_global_index_columns(vp.INDEX_COLUMNS+['x_factor_effect'])
vp.INDEX_COLUMNS
# Out:
# ['input_draw', 'scenario', 'x_factor_effect']

# %% [markdown]
# # Test `find_person_time_tables` function

# %%
results.wasting_state_person_time
# Out:
#            sex  year                 wasting_state            measure  \
# 0       female  2022            mild_child_wasting  state_person_time
# 1       female  2022            mild_child_wasting  state_person_time
# 2       female  2022            mild_child_wasting  state_person_time
# 3       female  2022            mild_child_wasting  state_person_time
# ...        ...   ...                           ...                ...
# 345596    male  2026  susceptible_to_child_wasting  state_person_time
# 345597    male  2026  susceptible_to_child_wasting  state_person_time
# 345598    male  2026  susceptible_to_child_wasting  state_person_time
# 345599    male  2026  susceptible_to_child_wasting  state_person_time
#
#         input_draw           scenario  x_factor_effect         value x_factor  \
# 0               29           baseline              1.1      0.000000     cat2
# 1               29           baseline              1.1      0.000000     cat1
# 2               29           baseline              1.1      0.000000     cat2
# 3               29           baseline              1.1      0.000000     cat1
# ...            ...                ...              ...           ...      ...
# 345596         946  wasting_treatment              1.5  16475.270363     cat2
# 345597         946  wasting_treatment              1.5   3419.826146     cat1
# 345598         946  wasting_treatment              1.5   1704.976044     cat2
# 345599         946  wasting_treatment              1.5    384.646133     cat1
#
#            sq_lns wasting_treatment             age
# 0         covered           covered  early_neonatal
# 1         covered           covered  early_neonatal
# 2         covered         uncovered  early_neonatal
# 3         covered         uncovered  early_neonatal
# ...           ...               ...             ...
# 345596  uncovered           covered          2_to_4
# 345597  uncovered           covered          2_to_4
# 345598  uncovered         uncovered          2_to_4
# 345599  uncovered         uncovered          2_to_4
#
# [345600 rows x 12 columns]

# %%
csr.find_person_time_tables(results, 'x_factor')
# Out:
# ['wasting_state_person_time', 'person_time']

# %%
csr.find_person_time_tables(results, 'x_factor_effect')
# Out:
# ['wasting_state_person_time',
#  'stunting_state_person_time',
#  'person_time',
#  'cause_state_person_time']

# %%
csr.find_person_time_tables(results, 'cause_state')
# Out:
# ['cause_state_person_time']

# %% [markdown]
# ## Change function to a generator

# %%
csr.find_person_time_tables(results, 'x_factor')
# Out:
# <generator object find_person_time_tables.<locals>.<genexpr> at 0x2b40fcbd8970>

# %%
list(_)
# Out:
# ['wasting_state_person_time', 'person_time']

# %% [markdown]
# # Test `get_prevalence` with update to find person-time tables
#
# # Compute prevalence of SQLNS conditional on year, age, and wasting state:
#
# It worked! Woo hoo!

# %%
under_6mo, over_6mo, all_ages = map(list, csr.get_age_group_bins('6-11_months', 'all_ages'))
over_6mo
# Out:
# ['6-11_months', '12_to_23_months', '2_to_4']

# %%
prefilter_query = f"age in {over_6mo} and scenario=='sqlns'"
sqlns_prev_by_year_age_wasting1 = vp.ratio(
    results.wasting_state_person_time.query(prefilter_query),
    results.wasting_state_person_time.query(prefilter_query),
    strata=['year', 'age', 'wasting_state'],
    numerator_broadcast='sq_lns',
)
sqlns_prev_by_year_age_wasting1
# Out:
#       year              age                 wasting_state  input_draw  \
# 0     2022  12_to_23_months            mild_child_wasting          29
# 1     2022  12_to_23_months            mild_child_wasting          29
# 2     2022  12_to_23_months            mild_child_wasting          29
# 3     2022  12_to_23_months            mild_child_wasting          29
# ...    ...              ...                           ...         ...
# 7196  2026      6-11_months  susceptible_to_child_wasting         946
# 7197  2026      6-11_months  susceptible_to_child_wasting         946
# 7198  2026      6-11_months  susceptible_to_child_wasting         946
# 7199  2026      6-11_months  susceptible_to_child_wasting         946
#
#      scenario  x_factor_effect     sq_lns     value  numerator_measure  \
# 0       sqlns              1.1    covered  0.000000  state_person_time
# 1       sqlns              1.1  uncovered  1.000000  state_person_time
# 2       sqlns              1.2    covered  0.000000  state_person_time
# 3       sqlns              1.2  uncovered  1.000000  state_person_time
# ...       ...              ...        ...       ...                ...
# 7196    sqlns              1.4    covered  0.895991  state_person_time
# 7197    sqlns              1.4  uncovered  0.104009  state_person_time
# 7198    sqlns              1.5    covered  0.895979  state_person_time
# 7199    sqlns              1.5  uncovered  0.104021  state_person_time
#
#      denominator_measure  multiplier
# 0      state_person_time           1
# 1      state_person_time           1
# 2      state_person_time           1
# 3      state_person_time           1
# ...                  ...         ...
# 7196   state_person_time           1
# 7197   state_person_time           1
# 7198   state_person_time           1
# 7199   state_person_time           1
#
# [7200 rows x 11 columns]

# %%
sqlns_prev_by_year_age_wasting2 = csr.get_prevalence(
    results,
    state_variable='sq_lns',
    strata=['year', 'age', 'wasting_state'],
    prefilter_query=prefilter_query
)
sqlns_prev_by_year_age_wasting2
# Out:
#       year              age                 wasting_state  input_draw  \
# 0     2022  12_to_23_months            mild_child_wasting          29
# 1     2022  12_to_23_months            mild_child_wasting          29
# 2     2022  12_to_23_months            mild_child_wasting          29
# 3     2022  12_to_23_months            mild_child_wasting          29
# ...    ...              ...                           ...         ...
# 7196  2026      6-11_months  susceptible_to_child_wasting         946
# 7197  2026      6-11_months  susceptible_to_child_wasting         946
# 7198  2026      6-11_months  susceptible_to_child_wasting         946
# 7199  2026      6-11_months  susceptible_to_child_wasting         946
#
#      scenario  x_factor_effect     sq_lns     value  numerator_measure  \
# 0       sqlns              1.1    covered  0.000000  state_person_time
# 1       sqlns              1.1  uncovered  1.000000  state_person_time
# 2       sqlns              1.2    covered  0.000000  state_person_time
# 3       sqlns              1.2  uncovered  1.000000  state_person_time
# ...       ...              ...        ...       ...                ...
# 7196    sqlns              1.4    covered  0.895991  state_person_time
# 7197    sqlns              1.4  uncovered  0.104009  state_person_time
# 7198    sqlns              1.5    covered  0.895979  state_person_time
# 7199    sqlns              1.5  uncovered  0.104021  state_person_time
#
#      denominator_measure  multiplier     measure
# 0      state_person_time           1  prevalence
# 1      state_person_time           1  prevalence
# 2      state_person_time           1  prevalence
# 3      state_person_time           1  prevalence
# ...                  ...         ...         ...
# 7196   state_person_time           1  prevalence
# 7197   state_person_time           1  prevalence
# 7198   state_person_time           1  prevalence
# 7199   state_person_time           1  prevalence
#
# [7200 rows x 12 columns]

# %%
sqlns_prev_by_year_age_wasting1.equals(sqlns_prev_by_year_age_wasting2.drop(columns='measure'))
# Out:
# True

# %% [markdown]
# # See what happens if we can't find appropriate person-time tables
#
# We get a StopIteration Error.

# %%
csr.get_prevalence(
    results,
    state_variable='sq_lns',
    strata=['year', 'cause_state', 'wasting_state'],
    prefilter_query=prefilter_query
)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# /tmp/ipykernel_219934/3749062079.py in <module>
# ----> 1 csr.get_prevalence(
#       2     results,
#       3     state_variable='sq_lns',
#       4     strata=['year', 'cause_state', 'wasting_state'],
#       5     prefilter_query=prefilter_query
#
# ~/vivarium_research_ciff_sam/model_validation/ciff_sam_results.py in get_prevalence(data, state_variable, strata, prefilter_query, **kwargs)
#     329     else:
#     330         # Find a person-time table that contains necessary columns for numerator
# --> 331         state_person_time = data[next(find_person_time_tables(data, numerator_columns))]
#     332     # Find a person-time table that contains necessary columns for total person-time in the denominator.
#     333     # Exclude cause-state person-time because it contains total person-time muliple times,
#
# StopIteration:

# %% [markdown]
# # Use try/except to raise more useful error messages

# %%
csr.get_prevalence(
    results,
    state_variable='sq_lns',
    strata=['year', 'cause_state', 'wasting_state'],
    prefilter_query=prefilter_query
)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# ~/vivarium_research_ciff_sam/model_validation/ciff_sam_results.py in get_prevalence(data, state_variable, strata, prefilter_query, **kwargs)
#     330         try:
# --> 331             numerator_table_name = next(find_person_time_tables(data, numerator_columns))
#     332         except StopIteration:
#
# StopIteration:
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_219934/3749062079.py in <module>
# ----> 1 csr.get_prevalence(
#       2     results,
#       3     state_variable='sq_lns',
#       4     strata=['year', 'cause_state', 'wasting_state'],
#       5     prefilter_query=prefilter_query
#
# ~/vivarium_research_ciff_sam/model_validation/ciff_sam_results.py in get_prevalence(data, state_variable, strata, prefilter_query, **kwargs)
#     331             numerator_table_name = next(find_person_time_tables(data, numerator_columns))
#     332         except StopIteration:
# --> 333             raise ValueError(f"No person-time table found with numerator columns {numerator_columns}")
#     334         # Find a person-time table that contains necessary columns for numerator
#     335         state_person_time = data[numerator_table_name]
#
# ValueError: No person-time table found with numerator columns ['year', 'cause_state', 'wasting_state', 'sq_lns']

# %%
csr.get_prevalence(
    results,
    state_variable='sq_lns',
    strata=['year', 'wasting_state'],
    prefilter_query=prefilter_query,
    denominator_broadcast='cause_state'
)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# ~/vivarium_research_ciff_sam/model_validation/ciff_sam_results.py in get_prevalence(data, state_variable, strata, prefilter_query, **kwargs)
#     339     try:
# --> 340         denominator_table_name = next(find_person_time_tables(data, denominator_columns, exclude='cause_state_person_time'))
#     341     except StopIteration:
#
# StopIteration:
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_219934/3560829808.py in <module>
# ----> 1 csr.get_prevalence(
#       2     results,
#       3     state_variable='sq_lns',
#       4     strata=['year', 'wasting_state'],
#       5     prefilter_query=prefilter_query,
#
# ~/vivarium_research_ciff_sam/model_validation/ciff_sam_results.py in get_prevalence(data, state_variable, strata, prefilter_query, **kwargs)
#     340         denominator_table_name = next(find_person_time_tables(data, denominator_columns, exclude='cause_state_person_time'))
#     341     except StopIteration:
# --> 342         raise ValueError(f"No person-time table found with denominator columns {denominator_columns}")
#     343     person_time = data[denominator_table_name]
#     344     # Filter input dataframes if requested
#
# ValueError: No person-time table found with denominator columns ['year', 'wasting_state', 'cause_state']

# %% [markdown]
# # Test `get_prevalence` after deleting `default=[]` from numerator columns

# %%
results.wasting_state_person_time
# Out:
#            sex  year                 wasting_state            measure  \
# 0       female  2022            mild_child_wasting  state_person_time
# 1       female  2022            mild_child_wasting  state_person_time
# 2       female  2022            mild_child_wasting  state_person_time
# 3       female  2022            mild_child_wasting  state_person_time
# ...        ...   ...                           ...                ...
# 345596    male  2026  susceptible_to_child_wasting  state_person_time
# 345597    male  2026  susceptible_to_child_wasting  state_person_time
# 345598    male  2026  susceptible_to_child_wasting  state_person_time
# 345599    male  2026  susceptible_to_child_wasting  state_person_time
#
#         input_draw           scenario  x_factor_effect         value x_factor  \
# 0               29           baseline              1.1      0.000000     cat2
# 1               29           baseline              1.1      0.000000     cat1
# 2               29           baseline              1.1      0.000000     cat2
# 3               29           baseline              1.1      0.000000     cat1
# ...            ...                ...              ...           ...      ...
# 345596         946  wasting_treatment              1.5  16475.270363     cat2
# 345597         946  wasting_treatment              1.5   3419.826146     cat1
# 345598         946  wasting_treatment              1.5   1704.976044     cat2
# 345599         946  wasting_treatment              1.5    384.646133     cat1
#
#            sq_lns wasting_treatment             age
# 0         covered           covered  early_neonatal
# 1         covered           covered  early_neonatal
# 2         covered         uncovered  early_neonatal
# 3         covered         uncovered  early_neonatal
# ...           ...               ...             ...
# 345596  uncovered           covered          2_to_4
# 345597  uncovered           covered          2_to_4
# 345598  uncovered         uncovered          2_to_4
# 345599  uncovered         uncovered          2_to_4
#
# [345600 rows x 12 columns]

# %%
x_factor_by_year_wasting_state_sqlns = csr.get_prevalence(
    results,
    state_variable='x_factor',
    strata=['year', 'wasting_state', 'sq_lns'],
    prefilter_query=prefilter_query,
)
x_factor_by_year_wasting_state_sqlns
# Out:
#       year                 wasting_state     sq_lns  input_draw scenario  \
# 0     2022            mild_child_wasting    covered          29    sqlns
# 1     2022            mild_child_wasting    covered          29    sqlns
# 2     2022            mild_child_wasting    covered          29    sqlns
# 3     2022            mild_child_wasting    covered          29    sqlns
# ...    ...                           ...        ...         ...      ...
# 4796  2026  susceptible_to_child_wasting  uncovered         946    sqlns
# 4797  2026  susceptible_to_child_wasting  uncovered         946    sqlns
# 4798  2026  susceptible_to_child_wasting  uncovered         946    sqlns
# 4799  2026  susceptible_to_child_wasting  uncovered         946    sqlns
#
#       x_factor_effect x_factor     value  numerator_measure  \
# 0                 1.1     cat1       NaN  state_person_time
# 1                 1.1     cat2       NaN  state_person_time
# 2                 1.2     cat1       NaN  state_person_time
# 3                 1.2     cat2       NaN  state_person_time
# ...               ...      ...       ...                ...
# 4796              1.4     cat1  0.173366  state_person_time
# 4797              1.4     cat2  0.826634  state_person_time
# 4798              1.5     cat1  0.172345  state_person_time
# 4799              1.5     cat2  0.827655  state_person_time
#
#      denominator_measure  multiplier     measure
# 0      state_person_time           1  prevalence
# 1      state_person_time           1  prevalence
# 2      state_person_time           1  prevalence
# 3      state_person_time           1  prevalence
# ...                  ...         ...         ...
# 4796   state_person_time           1  prevalence
# 4797   state_person_time           1  prevalence
# 4798   state_person_time           1  prevalence
# 4799   state_person_time           1  prevalence
#
# [4800 rows x 12 columns]

# %%
vp.marginalize(x_factor_by_year_wasting_state_sqlns, 'x_factor')
# Out:
#      denominator_measure  input_draw     measure  multiplier  \
# 0      state_person_time          29  prevalence           1
# 1      state_person_time          29  prevalence           1
# 2      state_person_time          29  prevalence           1
# 3      state_person_time          29  prevalence           1
# ...                  ...         ...         ...         ...
# 2396   state_person_time         946  prevalence           1
# 2397   state_person_time         946  prevalence           1
# 2398   state_person_time         946  prevalence           1
# 2399   state_person_time         946  prevalence           1
#
#       numerator_measure scenario     sq_lns                 wasting_state  \
# 0     state_person_time    sqlns    covered            mild_child_wasting
# 1     state_person_time    sqlns    covered            mild_child_wasting
# 2     state_person_time    sqlns    covered            mild_child_wasting
# 3     state_person_time    sqlns    covered            mild_child_wasting
# ...                 ...      ...        ...                           ...
# 2396  state_person_time    sqlns  uncovered  susceptible_to_child_wasting
# 2397  state_person_time    sqlns  uncovered  susceptible_to_child_wasting
# 2398  state_person_time    sqlns  uncovered  susceptible_to_child_wasting
# 2399  state_person_time    sqlns  uncovered  susceptible_to_child_wasting
#
#       x_factor_effect  year  value
# 0                 1.1  2022    0.0
# 1                 1.1  2023    1.0
# 2                 1.1  2024    1.0
# 3                 1.1  2025    1.0
# ...               ...   ...    ...
# 2396              1.5  2023    1.0
# 2397              1.5  2024    1.0
# 2398              1.5  2025    1.0
# 2399              1.5  2026    1.0
#
# [2400 rows x 11 columns]

# %%
# Make sure prevalences are adding up to 1 (or 0)
vp.marginalize(x_factor_by_year_wasting_state_sqlns, 'x_factor').value.unique()
# Out:
# array([0., 1., 1., 1., 1.])

# %% [markdown]
# # Test `get_relative_risk` function with 'wasting_state' as risk factor
#
# Now it works since we look up the appropriate person-time table in `get_prevalence`.

# %%
csr.get_relative_risk(
    data=results,
    measure='prevalence',
    outcome='sq_lns',
    strata=['year', 'age'],
    factor='wasting_state',
    reference_category='susceptible_to_child_wasting',
    prefilter_query = f"age in {over_6mo} and scenario=='sqlns'",
)
# Out:
#       year              age     sq_lns  input_draw scenario  x_factor_effect  \
# 0     2022  12_to_23_months    covered          29    sqlns              1.1
# 1     2022  12_to_23_months    covered          29    sqlns              1.1
# 2     2022  12_to_23_months    covered          29    sqlns              1.1
# 3     2022  12_to_23_months    covered          29    sqlns              1.2
# ...    ...              ...        ...         ...      ...              ...
# 5396  2026      6-11_months  uncovered         946    sqlns              1.4
# 5397  2026      6-11_months  uncovered         946    sqlns              1.5
# 5398  2026      6-11_months  uncovered         946    sqlns              1.5
# 5399  2026      6-11_months  uncovered         946    sqlns              1.5
#
#           numerator_wasting_state     denominator_wasting_state     value  \
# 0              mild_child_wasting  susceptible_to_child_wasting       NaN
# 1     moderate_acute_malnutrition  susceptible_to_child_wasting       NaN
# 2       severe_acute_malnutrition  susceptible_to_child_wasting       NaN
# 3              mild_child_wasting  susceptible_to_child_wasting       NaN
# ...                           ...                           ...       ...
# 5396    severe_acute_malnutrition  susceptible_to_child_wasting  0.982480
# 5397           mild_child_wasting  susceptible_to_child_wasting  0.920247
# 5398  moderate_acute_malnutrition  susceptible_to_child_wasting  1.065985
# 5399    severe_acute_malnutrition  susceptible_to_child_wasting  0.955662
#
#      numerator_measure denominator_measure  multiplier        measure
# 0           prevalence          prevalence           1  relative_risk
# 1           prevalence          prevalence           1  relative_risk
# 2           prevalence          prevalence           1  relative_risk
# 3           prevalence          prevalence           1  relative_risk
# ...                ...                 ...         ...            ...
# 5396        prevalence          prevalence           1  relative_risk
# 5397        prevalence          prevalence           1  relative_risk
# 5398        prevalence          prevalence           1  relative_risk
# 5399        prevalence          prevalence           1  relative_risk
#
# [5400 rows x 13 columns]

# %% [markdown]
# # Test code after refactoring try/except into new `get_person_time_table_name` function
#
# Looks like it's working.

# %%
sqlns_prev_by_year_age_wasting3 = csr.get_prevalence(
    results,
    state_variable='sq_lns',
    strata=['year', 'age', 'wasting_state'],
    prefilter_query=prefilter_query
)
sqlns_prev_by_year_age_wasting3
# Out:
#       year              age                 wasting_state  input_draw  \
# 0     2022  12_to_23_months            mild_child_wasting          29
# 1     2022  12_to_23_months            mild_child_wasting          29
# 2     2022  12_to_23_months            mild_child_wasting          29
# 3     2022  12_to_23_months            mild_child_wasting          29
# ...    ...              ...                           ...         ...
# 7196  2026      6-11_months  susceptible_to_child_wasting         946
# 7197  2026      6-11_months  susceptible_to_child_wasting         946
# 7198  2026      6-11_months  susceptible_to_child_wasting         946
# 7199  2026      6-11_months  susceptible_to_child_wasting         946
#
#      scenario  x_factor_effect     sq_lns     value  numerator_measure  \
# 0       sqlns              1.1    covered  0.000000  state_person_time
# 1       sqlns              1.1  uncovered  1.000000  state_person_time
# 2       sqlns              1.2    covered  0.000000  state_person_time
# 3       sqlns              1.2  uncovered  1.000000  state_person_time
# ...       ...              ...        ...       ...                ...
# 7196    sqlns              1.4    covered  0.895991  state_person_time
# 7197    sqlns              1.4  uncovered  0.104009  state_person_time
# 7198    sqlns              1.5    covered  0.895979  state_person_time
# 7199    sqlns              1.5  uncovered  0.104021  state_person_time
#
#      denominator_measure  multiplier     measure
# 0      state_person_time           1  prevalence
# 1      state_person_time           1  prevalence
# 2      state_person_time           1  prevalence
# 3      state_person_time           1  prevalence
# ...                  ...         ...         ...
# 7196   state_person_time           1  prevalence
# 7197   state_person_time           1  prevalence
# 7198   state_person_time           1  prevalence
# 7199   state_person_time           1  prevalence
#
# [7200 rows x 12 columns]

# %%
sqlns_prev_by_year_age_wasting1.equals(sqlns_prev_by_year_age_wasting3.drop(columns='measure'))
# Out:
# True

# %%
csr.get_relative_risk(
    data=results,
    measure='prevalence',
    outcome='sq_lns',
    strata=['year', 'age'],
    factor='wasting_state',
    reference_category='susceptible_to_child_wasting',
    prefilter_query = f"age in {over_6mo} and scenario=='sqlns'",
)
# Out:
#       year              age     sq_lns  input_draw scenario  x_factor_effect  \
# 0     2022  12_to_23_months    covered          29    sqlns              1.1
# 1     2022  12_to_23_months    covered          29    sqlns              1.1
# 2     2022  12_to_23_months    covered          29    sqlns              1.1
# 3     2022  12_to_23_months    covered          29    sqlns              1.2
# ...    ...              ...        ...         ...      ...              ...
# 5396  2026      6-11_months  uncovered         946    sqlns              1.4
# 5397  2026      6-11_months  uncovered         946    sqlns              1.5
# 5398  2026      6-11_months  uncovered         946    sqlns              1.5
# 5399  2026      6-11_months  uncovered         946    sqlns              1.5
#
#           numerator_wasting_state     denominator_wasting_state     value  \
# 0              mild_child_wasting  susceptible_to_child_wasting       NaN
# 1     moderate_acute_malnutrition  susceptible_to_child_wasting       NaN
# 2       severe_acute_malnutrition  susceptible_to_child_wasting       NaN
# 3              mild_child_wasting  susceptible_to_child_wasting       NaN
# ...                           ...                           ...       ...
# 5396    severe_acute_malnutrition  susceptible_to_child_wasting  0.982480
# 5397           mild_child_wasting  susceptible_to_child_wasting  0.920247
# 5398  moderate_acute_malnutrition  susceptible_to_child_wasting  1.065985
# 5399    severe_acute_malnutrition  susceptible_to_child_wasting  0.955662
#
#      numerator_measure denominator_measure  multiplier        measure
# 0           prevalence          prevalence           1  relative_risk
# 1           prevalence          prevalence           1  relative_risk
# 2           prevalence          prevalence           1  relative_risk
# 3           prevalence          prevalence           1  relative_risk
# ...                ...                 ...         ...            ...
# 5396        prevalence          prevalence           1  relative_risk
# 5397        prevalence          prevalence           1  relative_risk
# 5398        prevalence          prevalence           1  relative_risk
# 5399        prevalence          prevalence           1  relative_risk
#
# [5400 rows x 13 columns]

# %%
csr.get_prevalence(
    results,
    state_variable='sq_lns',
    strata=['year', 'cause_state', 'wasting_state'],
    prefilter_query=prefilter_query
)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# ~/vivarium_research_ciff_sam/model_validation/ciff_sam_results.py in get_person_time_table_name(data, colnames, exclude)
#     316     try:
# --> 317         person_time_table_name = next(find_person_time_tables(data, colnames, exclude))
#     318     except StopIteration:
#
# StopIteration:
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_219934/3749062079.py in <module>
# ----> 1 csr.get_prevalence(
#       2     results,
#       3     state_variable='sq_lns',
#       4     strata=['year', 'cause_state', 'wasting_state'],
#       5     prefilter_query=prefilter_query
#
# ~/vivarium_research_ciff_sam/model_validation/ciff_sam_results.py in get_prevalence(data, state_variable, strata, prefilter_query, **kwargs)
#     344         # Exclude cause-state person-time because it contains total person-time multiple times,
#     345         # which would make us over-count.
# --> 346         numerator_table_name = get_person_time_table_name(data, numerator_columns, exclude='cause_state_person_time')
#     347         state_person_time = data[numerator_table_name]
#     348     # Find a person-time table that contains necessary columns for total person-time in the denominator.
#
# ~/vivarium_research_ciff_sam/model_validation/ciff_sam_results.py in get_person_time_table_name(data, colnames, exclude)
#     317         person_time_table_name = next(find_person_time_tables(data, colnames, exclude))
#     318     except StopIteration:
# --> 319         raise ValueError(f"No person-time table found with columns {colnames}."
#     320                          f" (Excluded tables: {exclude})")
#     321     return person_time_table_name
#
# ValueError: No person-time table found with columns ['year', 'cause_state', 'wasting_state', 'sq_lns']. (Excluded tables: cause_state_person_time)

# %%
csr.get_prevalence(
    results,
    state_variable='sq_lns',
    strata=['year', 'wasting_state'],
    prefilter_query=prefilter_query,
    denominator_broadcast='cause_state'
)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# ~/vivarium_research_ciff_sam/model_validation/ciff_sam_results.py in get_person_time_table_name(data, colnames, exclude)
#     316     try:
# --> 317         person_time_table_name = next(find_person_time_tables(data, colnames, exclude))
#     318     except StopIteration:
#
# StopIteration:
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_219934/3560829808.py in <module>
# ----> 1 csr.get_prevalence(
#       2     results,
#       3     state_variable='sq_lns',
#       4     strata=['year', 'wasting_state'],
#       5     prefilter_query=prefilter_query,
#
# ~/vivarium_research_ciff_sam/model_validation/ciff_sam_results.py in get_prevalence(data, state_variable, strata, prefilter_query, **kwargs)
#     349     # Exclude cause-state person-time because it contains total person-time multiple times,
#     350     # which would make us over-count.
# --> 351     denominator_table_name = get_person_time_table_name(data, denominator_columns, exclude='cause_state_person_time')
#     352     person_time = data[denominator_table_name]
#     353     # Filter input dataframes if requested
#
# ~/vivarium_research_ciff_sam/model_validation/ciff_sam_results.py in get_person_time_table_name(data, colnames, exclude)
#     317         person_time_table_name = next(find_person_time_tables(data, colnames, exclude))
#     318     except StopIteration:
# --> 319         raise ValueError(f"No person-time table found with columns {colnames}."
#     320                          f" (Excluded tables: {exclude})")
#     321     return person_time_table_name
#
# ValueError: No person-time table found with columns ['year', 'wasting_state', 'cause_state']. (Excluded tables: cause_state_person_time)
