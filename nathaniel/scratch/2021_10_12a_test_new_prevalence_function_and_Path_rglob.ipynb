# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
pd.set_option('display.max_rows', 8)

from scipy import stats
import collections

import warnings
# warnings.filterwarnings('ignore')
from matplotlib.backends.backend_pdf import PdfPages

from pathlib import Path

import db_queries as db
import vivarium_helpers.id_helper as idh
import gbd_mapping
from vivarium import Artifact

# Add the repo directory vivarium_research_ciff_sam/ to sys.path
import os, sys
repo_path = os.path.abspath('../..')
sys.path.append(repo_path)
# Assumes vivarium_research_ciff_sam/ is in sys.path
# import model_validation.vivarium_transformed_output as vto
# import model_validation.vivarium_raw_output as vro
import model_validation.vivarium_output_processing as vp
import model_validation.ciff_sam_results as csr
import model_validation.ciff_sam_plots as csp

# %load_ext autoreload
# %autoreload 2

# !pwd
# !whoami
# !date
# Out:
# /ihme/homes/ndbs/vivarium_research_ciff_sam/nathaniel/scratch
# ndbs
# Tue Oct 12 13:54:15 PDT 2021

# %% [markdown]
# # Test `get_prevalence` against `get_sqlns_coverage`
#
# They match except for the numerator measures (state person time vs. person time), because I used the `wasting_state_person_time` table in `get_sqlns_coverage` vs. the `person_time` table in `get_prevalence`.

# %%
results = csr.VivariumResults.cleaned_from_model_spec('4.1')
results.table_names()
# Out:
# ['wasting_transition_count',
#  'wasting_state_person_time',
#  'deaths',
#  'stunting_state_person_time',
#  'population',
#  'ylls',
#  'ylds',
#  'person_time',
#  'cause_state_person_time',
#  'cause_transition_count']

# %%
strata = ['age', 'year']
sqlns_prev1 = csr.get_sqlns_coverage(results, strata)
sqlns_prev2 = csr.get_prevalence(results, 'sq_lns', strata)
sqlns_prev1.drop(columns='numerator_measure').equals(sqlns_prev2.drop(columns='numerator_measure'))
# Out:
# False

# %%
sqlns_prev1
# Out:
#                 age  year  input_draw           scenario     sq_lns  value  \
# 0        1-5_months  2022          29           baseline    covered    0.0
# 1        1-5_months  2022          29           baseline  uncovered    1.0
# 2        1-5_months  2022          29              sqlns    covered    0.0
# 3        1-5_months  2022          29              sqlns  uncovered    1.0
# ...             ...   ...         ...                ...        ...    ...
# 2156  late_neonatal  2026         946              sqlns    covered    0.0
# 2157  late_neonatal  2026         946              sqlns  uncovered    1.0
# 2158  late_neonatal  2026         946  wasting_treatment    covered    0.0
# 2159  late_neonatal  2026         946  wasting_treatment  uncovered    1.0
#
#       numerator_measure denominator_measure  multiplier
# 0     state_person_time         person_time           1
# 1     state_person_time         person_time           1
# 2     state_person_time         person_time           1
# 3     state_person_time         person_time           1
# ...                 ...                 ...         ...
# 2156  state_person_time         person_time           1
# 2157  state_person_time         person_time           1
# 2158  state_person_time         person_time           1
# 2159  state_person_time         person_time           1
#
# [2160 rows x 9 columns]

# %%
sqlns_prev2
# Out:
#                 age  year  input_draw           scenario     sq_lns  value  \
# 0        1-5_months  2022          29           baseline    covered    0.0
# 1        1-5_months  2022          29           baseline  uncovered    1.0
# 2        1-5_months  2022          29              sqlns    covered    0.0
# 3        1-5_months  2022          29              sqlns  uncovered    1.0
# ...             ...   ...         ...                ...        ...    ...
# 2156  late_neonatal  2026         946              sqlns    covered    0.0
# 2157  late_neonatal  2026         946              sqlns  uncovered    1.0
# 2158  late_neonatal  2026         946  wasting_treatment    covered    0.0
# 2159  late_neonatal  2026         946  wasting_treatment  uncovered    1.0
#
#      numerator_measure denominator_measure  multiplier
# 0          person_time         person_time           1
# 1          person_time         person_time           1
# 2          person_time         person_time           1
# 3          person_time         person_time           1
# ...                ...                 ...         ...
# 2156       person_time         person_time           1
# 2157       person_time         person_time           1
# 2158       person_time         person_time           1
# 2159       person_time         person_time           1
#
# [2160 rows x 9 columns]

# %% [markdown]
# ## The assert_equal statement passes after dropping numerator measure

# %%
vp.assert_values_equal(sqlns_prev1.drop(columns='numerator_measure'), sqlns_prev2.drop(columns='numerator_measure'))

# %%
vp.compare_values(sqlns_prev1.drop(columns='numerator_measure'), sqlns_prev2.drop(columns='numerator_measure'))
# Out:
#                                                                                          value  \
#                                                                                           self
# age           denominator_measure input_draw multiplier scenario          sq_lns    year
# 1-5_months    person_time         232        1          wasting_treatment uncovered 2022   1.0
#                                   394        1          wasting_treatment uncovered 2022   1.0
#                                   524        1          baseline          uncovered 2022   1.0
#                                                         wasting_treatment uncovered 2022   1.0
# ...                                                                                        ...
# late_neonatal person_time         524        1          sqlns             uncovered 2026   1.0
#                                                         wasting_treatment uncovered 2026   1.0
#                                   602        1          baseline          uncovered 2026   1.0
#                                   650        1          baseline          uncovered 2026   1.0
#
#
#                                                                                          other
# age           denominator_measure input_draw multiplier scenario          sq_lns    year
# 1-5_months    person_time         232        1          wasting_treatment uncovered 2022   1.0
#                                   394        1          wasting_treatment uncovered 2022   1.0
#                                   524        1          baseline          uncovered 2022   1.0
#                                                         wasting_treatment uncovered 2022   1.0
# ...                                                                                        ...
# late_neonatal person_time         524        1          sqlns             uncovered 2026   1.0
#                                                         wasting_treatment uncovered 2026   1.0
#                                   602        1          baseline          uncovered 2026   1.0
#                                   650        1          baseline          uncovered 2026   1.0
#
# [242 rows x 2 columns]

# %% [markdown]
# ## Figure out why assert was failing at first
#
# Reindexing was giving all NaNs because the `numerator_measure` index columns did not match.

# %%
df1 = vp.value(sqlns_prev1)
df1
# Out:
#                                                                                                             value
# age           denominator_measure input_draw multiplier numerator_measure scenario          sq_lns    year
# 1-5_months    person_time         29         1          state_person_time baseline          covered   2022    0.0
#                                                                                             uncovered 2022    1.0
#                                                                           sqlns             covered   2022    0.0
#                                                                                             uncovered 2022    1.0
# ...                                                                                                           ...
# late_neonatal person_time         946        1          state_person_time sqlns             covered   2026    0.0
#                                                                                             uncovered 2026    1.0
#                                                                           wasting_treatment covered   2026    0.0
#                                                                                             uncovered 2026    1.0
#
# [2160 rows x 1 columns]

# %%
df2 = vp.value(sqlns_prev2)
df2
# Out:
#                                                                                                             value
# age           denominator_measure input_draw multiplier numerator_measure scenario          sq_lns    year
# 1-5_months    person_time         29         1          person_time       baseline          covered   2022    0.0
#                                                                                             uncovered 2022    1.0
#                                                                           sqlns             covered   2022    0.0
#                                                                                             uncovered 2022    1.0
# ...                                                                                                           ...
# late_neonatal person_time         946        1          person_time       sqlns             covered   2026    0.0
#                                                                                             uncovered 2026    1.0
#                                                                           wasting_treatment covered   2026    0.0
#                                                                                             uncovered 2026    1.0
#
# [2160 rows x 1 columns]

# %%
df1.reindex(df2.index)
# Out:
#                                                                                                             value
# age           denominator_measure input_draw multiplier numerator_measure scenario          sq_lns    year
# 1-5_months    person_time         29         1          person_time       baseline          covered   2022    NaN
#                                                                                             uncovered 2022    NaN
#                                                                           sqlns             covered   2022    NaN
#                                                                                             uncovered 2022    NaN
# ...                                                                                                           ...
# late_neonatal person_time         946        1          person_time       sqlns             covered   2026    NaN
#                                                                                             uncovered 2026    NaN
#                                                                           wasting_treatment covered   2026    NaN
#                                                                                             uncovered 2026    NaN
#
# [2160 rows x 1 columns]

# %%
df1.index
# Out:
# MultiIndex([(   '1-5_months', 'person_time',  29, 1, 'state_person_time', ...),
#             (   '1-5_months', 'person_time',  29, 1, 'state_person_time', ...),
#             (   '1-5_months', 'person_time',  29, 1, 'state_person_time', ...),
#             (   '1-5_months', 'person_time',  29, 1, 'state_person_time', ...),
#             (   '1-5_months', 'person_time',  29, 1, 'state_person_time', ...),
#             (   '1-5_months', 'person_time',  29, 1, 'state_person_time', ...),
#             (   '1-5_months', 'person_time', 223, 1, 'state_person_time', ...),
#             (   '1-5_months', 'person_time', 223, 1, 'state_person_time', ...),
#             (   '1-5_months', 'person_time', 223, 1, 'state_person_time', ...),
#             (   '1-5_months', 'person_time', 223, 1, 'state_person_time', ...),
#             ...
#             ('late_neonatal', 'person_time', 829, 1, 'state_person_time', ...),
#             ('late_neonatal', 'person_time', 829, 1, 'state_person_time', ...),
#             ('late_neonatal', 'person_time', 829, 1, 'state_person_time', ...),
#             ('late_neonatal', 'person_time', 829, 1, 'state_person_time', ...),
#             ('late_neonatal', 'person_time', 946, 1, 'state_person_time', ...),
#             ('late_neonatal', 'person_time', 946, 1, 'state_person_time', ...),
#             ('late_neonatal', 'person_time', 946, 1, 'state_person_time', ...),
#             ('late_neonatal', 'person_time', 946, 1, 'state_person_time', ...),
#             ('late_neonatal', 'person_time', 946, 1, 'state_person_time', ...),
#             ('late_neonatal', 'person_time', 946, 1, 'state_person_time', ...)],
#            names=['age', 'denominator_measure', 'input_draw', 'multiplier', 'numerator_measure', 'scenario', 'sq_lns', 'year'], length=2160)

# %%
df2.index
# Out:
# MultiIndex([(   '1-5_months', 'person_time',  29, 1, 'person_time', ...),
#             (   '1-5_months', 'person_time',  29, 1, 'person_time', ...),
#             (   '1-5_months', 'person_time',  29, 1, 'person_time', ...),
#             (   '1-5_months', 'person_time',  29, 1, 'person_time', ...),
#             (   '1-5_months', 'person_time',  29, 1, 'person_time', ...),
#             (   '1-5_months', 'person_time',  29, 1, 'person_time', ...),
#             (   '1-5_months', 'person_time', 223, 1, 'person_time', ...),
#             (   '1-5_months', 'person_time', 223, 1, 'person_time', ...),
#             (   '1-5_months', 'person_time', 223, 1, 'person_time', ...),
#             (   '1-5_months', 'person_time', 223, 1, 'person_time', ...),
#             ...
#             ('late_neonatal', 'person_time', 829, 1, 'person_time', ...),
#             ('late_neonatal', 'person_time', 829, 1, 'person_time', ...),
#             ('late_neonatal', 'person_time', 829, 1, 'person_time', ...),
#             ('late_neonatal', 'person_time', 829, 1, 'person_time', ...),
#             ('late_neonatal', 'person_time', 946, 1, 'person_time', ...),
#             ('late_neonatal', 'person_time', 946, 1, 'person_time', ...),
#             ('late_neonatal', 'person_time', 946, 1, 'person_time', ...),
#             ('late_neonatal', 'person_time', 946, 1, 'person_time', ...),
#             ('late_neonatal', 'person_time', 946, 1, 'person_time', ...),
#             ('late_neonatal', 'person_time', 946, 1, 'person_time', ...)],
#            names=['age', 'denominator_measure', 'input_draw', 'multiplier', 'numerator_measure', 'scenario', 'sq_lns', 'year'], length=2160)

# %% [markdown]
# ## It looks like most values are 0 and 1...

# %%
df1.describe()
# Out:
#             value
# count  2160.00000
# mean      0.50000
# std       0.48797
# min       0.00000
# 25%       0.00000
# 50%       0.50000
# 75%       1.00000
# max       1.00000

# %% [markdown]
# ## Check that we actually get something besides 1s and 0s when we filter to nonzero coverage

# %%
sqlns_prev1.query("age == '2_to_4' and scenario=='sqlns' and year>'2022'")
# Out:
#          age  year  input_draw scenario     sq_lns     value  \
# 794   2_to_4  2023          29    sqlns    covered  0.900364
# 795   2_to_4  2023          29    sqlns  uncovered  0.099636
# 800   2_to_4  2023         223    sqlns    covered  0.900166
# 801   2_to_4  2023         223    sqlns  uncovered  0.099834
# ...      ...   ...         ...      ...        ...       ...
# 1070  2_to_4  2026         829    sqlns    covered  0.899814
# 1071  2_to_4  2026         829    sqlns  uncovered  0.100186
# 1076  2_to_4  2026         946    sqlns    covered  0.899756
# 1077  2_to_4  2026         946    sqlns  uncovered  0.100244
#
#       numerator_measure denominator_measure  multiplier
# 794   state_person_time         person_time           1
# 795   state_person_time         person_time           1
# 800   state_person_time         person_time           1
# 801   state_person_time         person_time           1
# ...                 ...                 ...         ...
# 1070  state_person_time         person_time           1
# 1071  state_person_time         person_time           1
# 1076  state_person_time         person_time           1
# 1077  state_person_time         person_time           1
#
# [96 rows x 9 columns]

# %%
sqlns_prev2.query("age == '2_to_4' and scenario=='sqlns' and year>'2022'")
# Out:
#          age  year  input_draw scenario     sq_lns     value  \
# 794   2_to_4  2023          29    sqlns    covered  0.900364
# 795   2_to_4  2023          29    sqlns  uncovered  0.099636
# 800   2_to_4  2023         223    sqlns    covered  0.900166
# 801   2_to_4  2023         223    sqlns  uncovered  0.099834
# ...      ...   ...         ...      ...        ...       ...
# 1070  2_to_4  2026         829    sqlns    covered  0.899814
# 1071  2_to_4  2026         829    sqlns  uncovered  0.100186
# 1076  2_to_4  2026         946    sqlns    covered  0.899756
# 1077  2_to_4  2026         946    sqlns  uncovered  0.100244
#
#      numerator_measure denominator_measure  multiplier
# 794        person_time         person_time           1
# 795        person_time         person_time           1
# 800        person_time         person_time           1
# 801        person_time         person_time           1
# ...                ...                 ...         ...
# 1070       person_time         person_time           1
# 1071       person_time         person_time           1
# 1076       person_time         person_time           1
# 1077       person_time         person_time           1
#
# [96 rows x 9 columns]

# %% [markdown]
# # Test `get_prevalence` against `get_x_factor_prevalence`
#
# They match, and in fact they're exacly equal because I computed them in the same way.

# %%
results45 = csr.VivariumResults.cleaned_from_model_spec('4.5.2')
results45.table_names()
# Out:
# ['wasting_transition_count',
#  'wasting_state_person_time',
#  'deaths',
#  'stunting_state_person_time',
#  'population',
#  'ylls',
#  'ylds',
#  'person_time',
#  'cause_state_person_time',
#  'cause_transition_count']

# %%
strata = ['age', 'year']
xfactor_prev1 = csr.get_x_factor_prevalence(results45, strata)
xfactor_prev2 = csr.get_prevalence(results45, 'x_factor', strata)
xfactor_prev1.equals(xfactor_prev2)
# Out:
# True

# %%
xfactor_prev1
# Out:
#                 age  year  input_draw           scenario x_factor     value  \
# 0        1-5_months  2022          29           baseline     cat1  0.192696
# 1        1-5_months  2022          29           baseline     cat2  0.807304
# 2        1-5_months  2022          29              sqlns     cat1  0.192696
# 3        1-5_months  2022          29              sqlns     cat2  0.807304
# ...             ...   ...         ...                ...      ...       ...
# 2156  late_neonatal  2026         946              sqlns     cat1  0.184549
# 2157  late_neonatal  2026         946              sqlns     cat2  0.815451
# 2158  late_neonatal  2026         946  wasting_treatment     cat1  0.184549
# 2159  late_neonatal  2026         946  wasting_treatment     cat2  0.815451
#
#      numerator_measure denominator_measure  multiplier
# 0          person_time         person_time           1
# 1          person_time         person_time           1
# 2          person_time         person_time           1
# 3          person_time         person_time           1
# ...                ...                 ...         ...
# 2156       person_time         person_time           1
# 2157       person_time         person_time           1
# 2158       person_time         person_time           1
# 2159       person_time         person_time           1
#
# [2160 rows x 9 columns]

# %%
xfactor_prev2
# Out:
#                 age  year  input_draw           scenario x_factor     value  \
# 0        1-5_months  2022          29           baseline     cat1  0.192696
# 1        1-5_months  2022          29           baseline     cat2  0.807304
# 2        1-5_months  2022          29              sqlns     cat1  0.192696
# 3        1-5_months  2022          29              sqlns     cat2  0.807304
# ...             ...   ...         ...                ...      ...       ...
# 2156  late_neonatal  2026         946              sqlns     cat1  0.184549
# 2157  late_neonatal  2026         946              sqlns     cat2  0.815451
# 2158  late_neonatal  2026         946  wasting_treatment     cat1  0.184549
# 2159  late_neonatal  2026         946  wasting_treatment     cat2  0.815451
#
#      numerator_measure denominator_measure  multiplier
# 0          person_time         person_time           1
# 1          person_time         person_time           1
# 2          person_time         person_time           1
# 3          person_time         person_time           1
# ...                ...                 ...         ...
# 2156       person_time         person_time           1
# 2157       person_time         person_time           1
# 2158       person_time         person_time           1
# 2159       person_time         person_time           1
#
# [2160 rows x 9 columns]

# %% [markdown]
# # Check that new `get_prevalence` still works with risks and causes

# %%
wasting_prev = csr.get_prevalence(results, 'wasting_state', ['age', 'year'])
wasting_prev
# Out:
#                 age  year  input_draw           scenario  \
# 0        1-5_months  2022          29           baseline
# 1        1-5_months  2022          29           baseline
# 2        1-5_months  2022          29           baseline
# 3        1-5_months  2022          29           baseline
# ...             ...   ...         ...                ...
# 4316  late_neonatal  2026         946  wasting_treatment
# 4317  late_neonatal  2026         946  wasting_treatment
# 4318  late_neonatal  2026         946  wasting_treatment
# 4319  late_neonatal  2026         946  wasting_treatment
#
#                      wasting_state     value  numerator_measure  \
# 0               mild_child_wasting  0.205336  state_person_time
# 1      moderate_acute_malnutrition  0.088382  state_person_time
# 2        severe_acute_malnutrition  0.029572  state_person_time
# 3     susceptible_to_child_wasting  0.676710  state_person_time
# ...                            ...       ...                ...
# 4316            mild_child_wasting  0.200809  state_person_time
# 4317   moderate_acute_malnutrition  0.089108  state_person_time
# 4318     severe_acute_malnutrition  0.032706  state_person_time
# 4319  susceptible_to_child_wasting  0.677378  state_person_time
#
#      denominator_measure  multiplier
# 0            person_time           1
# 1            person_time           1
# 2            person_time           1
# 3            person_time           1
# ...                  ...         ...
# 4316         person_time           1
# 4317         person_time           1
# 4318         person_time           1
# 4319         person_time           1
#
# [4320 rows x 9 columns]

# %%
np.allclose(vp.marginalize(wasting_prev, 'wasting_state').value, 1)
# Out:
# True

# %%
stunting_prev = csr.get_prevalence(results, 'stunting_state', ['age', 'sex', 'year'])
stunting_prev
# Out:
#                 age     sex  year  input_draw           scenario  \
# 0        1-5_months  female  2022          29           baseline
# 1        1-5_months  female  2022          29           baseline
# 2        1-5_months  female  2022          29           baseline
# 3        1-5_months  female  2022          29           baseline
# ...             ...     ...   ...         ...                ...
# 8636  late_neonatal    male  2026         946  wasting_treatment
# 8637  late_neonatal    male  2026         946  wasting_treatment
# 8638  late_neonatal    male  2026         946  wasting_treatment
# 8639  late_neonatal    male  2026         946  wasting_treatment
#
#      stunting_state     value  numerator_measure denominator_measure  \
# 0              cat1  0.040926  state_person_time         person_time
# 1              cat2  0.110236  state_person_time         person_time
# 2              cat3  0.202617  state_person_time         person_time
# 3              cat4  0.646220  state_person_time         person_time
# ...             ...       ...                ...                 ...
# 8636           cat1  0.000000  state_person_time         person_time
# 8637           cat2  0.000000  state_person_time         person_time
# 8638           cat3  0.000000  state_person_time         person_time
# 8639           cat4  1.000000  state_person_time         person_time
#
#       multiplier
# 0              1
# 1              1
# 2              1
# 3              1
# ...          ...
# 8636           1
# 8637           1
# 8638           1
# 8639           1
#
# [8640 rows x 10 columns]

# %%
np.allclose(vp.marginalize(stunting_prev, 'stunting_state').value, 1)
# Out:
# True

# %%
cause_prev = csr.get_prevalence(results, 'cause_state', 'year')
cause_prev
# Out:
#       year  input_draw           scenario  \
# 0     2022          29           baseline
# 1     2022          29           baseline
# 2     2022          29           baseline
# 3     2022          29           baseline
# ...    ...         ...                ...
# 1076  2026         946  wasting_treatment
# 1077  2026         946  wasting_treatment
# 1078  2026         946  wasting_treatment
# 1079  2026         946  wasting_treatment
#
#                                       cause_state     value  \
# 0                              diarrheal_diseases  0.027868
# 1                    lower_respiratory_infections  0.001924
# 2                                         measles  0.000291
# 3               susceptible_to_diarrheal_diseases  0.972132
# ...                                           ...       ...
# 1076                                      measles  0.000152
# 1077            susceptible_to_diarrheal_diseases  0.976326
# 1078  susceptible_to_lower_respiratory_infections  0.997947
# 1079                       susceptible_to_measles  0.999848
#
#       numerator_measure denominator_measure  multiplier
# 0     state_person_time         person_time           1
# 1     state_person_time         person_time           1
# 2     state_person_time         person_time           1
# 3     state_person_time         person_time           1
# ...                 ...                 ...         ...
# 1076  state_person_time         person_time           1
# 1077  state_person_time         person_time           1
# 1078  state_person_time         person_time           1
# 1079  state_person_time         person_time           1
#
# [1080 rows x 8 columns]

# %%
np.allclose(vp.marginalize(cause_prev, 'cause_state').value, 3)
# Out:
# True

# %% [markdown]
# # Test `Path.rglob` to find `output.hdf` files
#
# ## It's really slow... I don't understand why because this directory subtree is not very big
#
# I should just try writing my own recursive search routine and see how that works...

# %%
csr.get_count_data_path(4.1)
# Out:
# '/ihme/costeffectiveness/results/vivarium_ciff_sam/v4.1_wasting_treatment/ciff_sam/2021_09_24_16_36_30/count_data/'

# %%
# !ls /ihme/costeffectiveness/results/vivarium_ciff_sam/v4.1_wasting_treatment/ciff_sam
# Out:
# 2021_09_22_12_12_41  2021_09_23_10_08_40
# 2021_09_22_17_40_59  2021_09_24_16_36_30

# %%
path41 = Path('/ihme/costeffectiveness/results/vivarium_ciff_sam/v4.1_wasting_treatment')
path41
# Out:
# PosixPath('/ihme/costeffectiveness/results/vivarium_ciff_sam/v4.1_wasting_treatment')

# %%
result = path41.rglob('output.hdf')
result
# Out:
# <generator object Path.rglob at 0x2b494b7b8200>

# %%
# %time list(result)
# Out:
# CPU times: user 1.28 s, sys: 4.6 s, total: 5.88 s
# Wall time: 1min 6s
# [PosixPath('/ihme/costeffectiveness/results/vivarium_ciff_sam/v4.1_wasting_treatment/ciff_sam/2021_09_23_10_08_40/output.hdf'),
#  PosixPath('/ihme/costeffectiveness/results/vivarium_ciff_sam/v4.1_wasting_treatment/ciff_sam/2021_09_24_16_36_30/output.hdf'),
#  PosixPath('/ihme/costeffectiveness/results/vivarium_ciff_sam/v4.1_wasting_treatment/ciff_sam/2021_09_22_17_40_59/output.hdf'),
#  PosixPath('/ihme/costeffectiveness/results/vivarium_ciff_sam/v4.1_wasting_treatment/ciff_sam/2021_09_22_12_12_41/output.hdf')]

# %%
result = path41.rglob('count_data')
# %time list(result)
# Out:
# CPU times: user 796 ms, sys: 4.25 s, total: 5.05 s
# Wall time: 56.7 s
# [PosixPath('/ihme/costeffectiveness/results/vivarium_ciff_sam/v4.1_wasting_treatment/ciff_sam/2021_09_24_16_36_30/count_data')]
